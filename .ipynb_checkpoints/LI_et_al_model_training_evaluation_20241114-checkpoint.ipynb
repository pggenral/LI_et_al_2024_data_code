# %% [markdown]
# # Import packages

# %%
import numpy as np
from numpy import mean
from numpy import std
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import SelectPercentile, f_classif
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import ParameterGrid
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import shap
import xgboost as xgb
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.compose import make_column_selector as selector
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import time
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.neighbors import BallTree
# %matplotlib inline
mpl.rcParams['font.sans-serif'] = "Arial"
mpl.rcParams['font.family'] = "sans-serif"
mpl.rcParams['mathtext.fontset'] = 'custom'
mpl.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
mpl.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
mpl.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
mpl.rcParams['legend.numpoints'] = 1
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('./data/LI_et_al_well_parameter_dataset.csv')
df.columns = df.columns.astype(str)
df = df.loc[:, ~df.columns.isin(['Unnamed: 0'])]

# %% [markdown]
# # Split training and test set

# %%
# Specify predictors and the target variable
X = df.copy()
y = df['scp_and_or_cvf']

# Split training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify = y, shuffle=True, random_state=1)
X_train = X_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %% [markdown]
# # Function to create geospatial metrics (well count and well distance)

# %%
# DataFrame: the dataframe containing the wells for which we are calculating geospatial metrics
# DataFrame_ball: the dataframe we use to generate the Ball Tree
def calc_count_dist(DataFrame, DataFrame_ball, radii):
    df= DataFrame.reset_index(drop=True)
    df_ball = DataFrame_ball.reset_index(drop=True)
    
    for column in ["latitude", "longitude"]:
        df[f'{column}_rad'] = np.deg2rad(df[column].values)
        df_ball[f'{column}_rad'] = np.deg2rad(df_ball[column].values)
        
    earth_r_km = 6371 # the radius of earth in km  
    df_ball_all = df_ball.copy()
    ball_all = BallTree(df_ball_all[["latitude_rad", "longitude_rad"]].values, metric='haversine')# BallTree of all wells in df_ball
    df_ball_faulty = df_ball.loc[df_ball['scp_and_or_cvf'],:].reset_index(drop=True)
    ball_faulty = BallTree(df_ball_faulty[["latitude_rad", "longitude_rad"]].values, metric='haversine')# BallTree of only faulty wells in df_ball
    df_ball_nonFaulty = df_ball.loc[~df_ball['scp_and_or_cvf'],:].reset_index(drop=True)
    ball_nonFaulty = BallTree(df_ball_nonFaulty[["latitude_rad", "longitude_rad"]].values, metric='haversine')# BallTree of only non-faulty wells in df_ball
    ball_list = [ball_all, ball_faulty, ball_nonFaulty]
    df_list = [df_ball_all, df_ball_faulty, df_ball_nonFaulty]
    ball_labels = ['well', 'faulty_well', 'nonFaulty_well']
    nb_dist_cols = ['distance_to_nearest_well_km', 'distance_to_nearest_faulty_well_km','distance_to_nearest_nonFaulty_well_km']
    
    for ball_i in range(len(ball_list)):
        
        # 1. calculate distance to the nearest neighbour:
        ball = ball_list[ball_i]
        df_ball_cur = df_list[ball_i]
        ball_label = ball_labels[ball_i]
        dist_knn, ind_knn = ball.query(df[["latitude_rad", "longitude_rad"]], k = 2)
        dist_knn = dist_knn * earth_r_km # calculate distance to nearest neighbor    
        # ind responds to row number in df_ball_cur
        # We test if the nearest neighbour is the queried well itself by comparing their API numbers. If that's the case, we use the 2nd nearest neighbour instead.
        df_ind_knn = pd.DataFrame(ind_knn)
        ind_first = df_ind_knn.iloc[:,0]
        ind_second = df_ind_knn.iloc[:,1]
        api_ind_first = df_ball_cur.iloc[ind_first,df_ball.columns.get_loc('api')].reset_index(drop=True)
        api_ind_second = df_ball_cur.iloc[ind_second,df_ball.columns.get_loc('api')].reset_index(drop=True)
        nearest_is_self = api_ind_first == df.loc[:,'api'].reset_index(drop=True)
        # Calculate distance to nearest neighbour, excluding self:    
        df_dist_knn = pd.DataFrame(dist_knn).round(3)
        dist_nb = df_dist_knn.iloc[:, 0] # distance to the nearest neighbour
        dist_nb.loc[nearest_is_self] = df_dist_knn.loc[nearest_is_self, 1]
        dist_col_name = 'distance_to_nearest_' + ball_label + '_km'
        df[dist_col_name] = dist_nb        
        api_nb = api_ind_first # API number of the nearest neighbour
        api_nb.loc[nearest_is_self] = api_ind_second
        api_col_name = 'API_of_nearest_' + ball_label
        
        # 2. calculate well counts within a radius:       
        for rad_i in range(len(radii)): 
            radius = radii[rad_i]
            radius_rad = radius/earth_r_km
            count_list = []
            queries = ball.query_radius(df[["latitude_rad", "longitude_rad"]], r=radius_rad)
            for ind,q in enumerate(queries):
                # The index in q is just the order, instead of the original index in df_ball_cur, so df_ball_cur needs to reset its index
                # Exclude the index of self
                self_api = df.iloc[ind, df.columns.get_loc("api")]            
                count = 0
                for i in q:
                    neighbor_api = df_ball_cur.iloc[i,df_ball_cur.columns.get_loc("api")]
                    if neighbor_api != self_api:
                        count += 1
                count_list.append(count)
            df['count_'+ball_label+f"_within_{radius}km"] = count_list  
            # Calculate the incremental well count for the current radius
            # e.g., increment_count_1km = count_1km - count_0.1 km
            if rad_i > 0:
                prev_radius = radii[rad_i - 1]
                df['count_' + ball_label + f"_between_{prev_radius}_and_{radius}km"] = df['count_'+ball_label+f"_within_{radius}km"] - df['count_'+ball_label+f"_within_{prev_radius}km"]
        # Drop the columns of well count within radius (non-incremental)
        radius_metric_to_remove = []
        for drop_i in range(1, len(radii)):
            radius = radii[drop_i]
            radius_metric_to_remove.append('count_'+ball_label+f"_within_{radius}km")
        df = df.drop(radius_metric_to_remove, axis = 1)
    # drop rad columns
    for column in ["latitude", "longitude"]:
        df = df.drop(f'{column}_rad', axis=1)
    return df

# %% [markdown]
# # Split the training set into Cross-Validation (CV) training sets and CV validation sets, and append geospatial metrics

# %%
radii  = [0.005,0.01,0.1,1,2,5,10]
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
splits = cv.split(X_train, y_train)

X_cv_train_self_lst = [] # 'self' indicates only using physical parameters of the well itself as predictors
X_cv_train_spatial_lst = [] # 'spatial' indicates also using geospatial metrics
X_cv_val_self_lst = []
X_cv_val_spatial_lst = []
y_cv_train_lst = []
y_cv_val_lst = []

for cv_train_index, cv_val_index in splits:
    X_cv_train_self = X_train.iloc[cv_train_index,:].reset_index(drop=True)
    X_cv_val_self = X_train.iloc[cv_val_index,:].reset_index(drop=True)
    y_cv_train = y_train.iloc[cv_train_index].reset_index(drop=True)
    y_cv_val = y_train.iloc[cv_val_index].reset_index(drop=True)
    X_cv_train_spatial = calc_count_dist(DataFrame=X_cv_train_self, DataFrame_ball = X_cv_train_self, radii=radii)
    X_cv_val_spatial = calc_count_dist(DataFrame=X_cv_val_self, DataFrame_ball=X_cv_train_self, radii=radii)
     
    X_cv_train_spatial = X_cv_train_spatial.drop(['scp_and_or_cvf','api'], axis = 1)
    X_cv_val_spatial = X_cv_val_spatial.drop(['scp_and_or_cvf', 'api'], axis = 1)
    X_cv_train_self = X_cv_train_self.drop(['latitude', 'longitude','scp_and_or_cvf','api'], axis = 1)
    X_cv_val_self = X_cv_val_self.drop(['latitude', 'longitude','scp_and_or_cvf','api'], axis = 1)
    
    X_cv_train_self_lst.append(X_cv_train_self)
    X_cv_val_self_lst.append(X_cv_val_self)
    X_cv_train_spatial_lst.append(X_cv_train_spatial)
    X_cv_val_spatial_lst.append(X_cv_val_spatial)
    y_cv_train_lst.append(y_cv_train)
    y_cv_val_lst.append(y_cv_val)

# %% [markdown]
# # Append geospatial metrics to the complete training set and test set

# %%
X_train_self = X_train.copy()
X_train_spatial = calc_count_dist(DataFrame = X_train_self, DataFrame_ball=X_train_self, radii=radii)
X_train_spatial =X_train_spatial.drop(['scp_and_or_cvf','api'], axis = 1)
X_train_self = X_train_self.drop(['latitude', 'longitude','scp_and_or_cvf','api'], axis = 1)

X_test_self = X_test.copy()
X_test_spatial = calc_count_dist(DataFrame = X_test_self, DataFrame_ball = X_train, radii = radii)
X_test_spatial =X_test_spatial.drop(['scp_and_or_cvf','api'], axis = 1)
X_test_self = X_test_self.drop(['latitude', 'longitude','scp_and_or_cvf','api'], axis = 1)

# %% [markdown]
# # Function to evaluate a model (pipeline) on each CV train and val set

# %%
def cv_evaluation(pipeline, param_grid, X_train, y_train, X_cv_train_lst, y_cv_train_lst, X_cv_val_lst, y_cv_val_lst):
    params=[]
    cv_mean_score = []
    cv_std_score = []
    grid = ParameterGrid(param_grid)
    total_param_comb = len(grid)
    count_comb = 0
    for g in grid:
        params.append(g)
        pipeline_g = pipeline.set_params(**g)
        scores_g = []
        for i in range(len(X_cv_train_lst)):
            X_cv_train = X_cv_train_lst[i]
            y_cv_train = y_cv_train_lst[i]
            X_cv_val = X_cv_val_lst[i]
            y_cv_val = y_cv_val_lst[i]
            pipeline_fitted = pipeline_g.fit(X_cv_train, y_cv_train)
            y_cv_val_pred = pipeline_fitted.predict(X_cv_val)
            y_cv_val_pred_prob = pipeline_fitted.predict_proba(X_cv_val)[:,1]  
            score_cur = roc_auc_score(y_cv_val,y_cv_val_pred_prob) # Use ROC_AUC as evaluation metric
            scores_g.append(score_cur)
        np_scores_g = np.array(scores_g)
        mean_scores_g = np.mean(np_scores_g)
        cv_mean_score.append(mean_scores_g)
        std_scores_g = np.std(np_scores_g)
        cv_std_score.append(std_scores_g)
        count_comb+=1
        print(f'Finished evaluating {count_comb}/{total_param_comb} hyperparameter combinations.')
        
    cv_grid_results = pd.DataFrame({'Params':params, 'mean_score': cv_mean_score, 'std_score': cv_std_score})
    max_score_idx = cv_grid_results['mean_score'].idxmax()
    best_mean_score = cv_grid_results.loc[max_score_idx, 'mean_score']
    best_std_score = cv_grid_results.loc[max_score_idx, 'std_score']
    best_param = cv_grid_results.loc[max_score_idx, 'Params']
    best_pipeline = pipeline.set_params(**best_param)
    best_pipeline = best_pipeline.fit(X_train, y_train) # re-fit the best model on the whole training set
    
    return cv_grid_results, best_mean_score, best_std_score,best_param,best_pipeline

# %% [markdown]
# # Preprocessor to be used in pipeline

# %%
def create_preprocessor():

    numeric_transformer = Pipeline(
        steps=[("imputer", SimpleImputer(strategy="median"))]
    )

    categorical_transformer = Pipeline(
        steps=[
            ("encoder", OneHotEncoder(handle_unknown="ignore"))
        ]
    )

    preprocessor = ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, selector(dtype_exclude=["object", 'bool'])),
            ("cat", categorical_transformer, selector(dtype_include=["object"])),
        ],
        sparse_threshold = 0,
        remainder = 'passthrough'
    )
    
    return preprocessor

# %% [markdown]
# # Train and evaluate machine learning models

# %% [markdown]
# ## 1. Estimator = Random Forrest

# %% [markdown]
# ### Using all features (i.e., local and geospatial features)

# %%
rng = np.random.RandomState(0)

rf_steps = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", RandomForestClassifier(random_state=rng,n_jobs=-1))
]

rf_clf_pl = Pipeline(steps = rf_steps)

rf_param_grid = {"UniSlct__percentile" : [80, 90, 100],
 'est__max_depth': [ 5, 50, 100,500, 1000, None],
 'est__max_features': ['sqrt', 'log2'],
 'est__n_estimators': [100, 200, 1000, 2000]}

# Train and evaluate model using CV
start_time_rf = time.perf_counter()
cv_table_rf, score_rf, std_rf,param_rf,pipeline_rf = cv_evaluation(rf_clf_pl, rf_param_grid, X_train_spatial, y_train, X_cv_train_spatial_lst,y_cv_train_lst,X_cv_val_spatial_lst,y_cv_val_lst)
end_time_rf = time.perf_counter()
elapsed_time_rf = end_time_rf - start_time_rf
print("Elapsed time in sec: ", elapsed_time_rf)
# Out:
# Finished evaluating 1/144 hyperparameter combinations.
# Finished evaluating 2/144 hyperparameter combinations.
# Finished evaluating 3/144 hyperparameter combinations.
# Finished evaluating 4/144 hyperparameter combinations.
# Finished evaluating 5/144 hyperparameter combinations.
# Finished evaluating 6/144 hyperparameter combinations.
# Finished evaluating 7/144 hyperparameter combinations.
# Finished evaluating 8/144 hyperparameter combinations.
# Finished evaluating 9/144 hyperparameter combinations.
# Finished evaluating 10/144 hyperparameter combinations.
# Finished evaluating 11/144 hyperparameter combinations.
# Finished evaluating 12/144 hyperparameter combinations.
# Finished evaluating 13/144 hyperparameter combinations.
# Finished evaluating 14/144 hyperparameter combinations.
# Finished evaluating 15/144 hyperparameter combinations.
# Finished evaluating 16/144 hyperparameter combinations.
# Finished evaluating 17/144 hyperparameter combinations.
# Finished evaluating 18/144 hyperparameter combinations.
# Finished evaluating 19/144 hyperparameter combinations.
# Finished evaluating 20/144 hyperparameter combinations.
# Finished evaluating 21/144 hyperparameter combinations.
# Finished evaluating 22/144 hyperparameter combinations.
# Finished evaluating 23/144 hyperparameter combinations.
# Finished evaluating 24/144 hyperparameter combinations.
# Finished evaluating 25/144 hyperparameter combinations.
# Finished evaluating 26/144 hyperparameter combinations.
# Finished evaluating 27/144 hyperparameter combinations.
# Finished evaluating 28/144 hyperparameter combinations.
# Finished evaluating 29/144 hyperparameter combinations.
# Finished evaluating 30/144 hyperparameter combinations.
# Finished evaluating 31/144 hyperparameter combinations.
# Finished evaluating 32/144 hyperparameter combinations.
# Finished evaluating 33/144 hyperparameter combinations.
# Finished evaluating 34/144 hyperparameter combinations.
# Finished evaluating 35/144 hyperparameter combinations.
# Finished evaluating 36/144 hyperparameter combinations.
# Finished evaluating 37/144 hyperparameter combinations.
# Finished evaluating 38/144 hyperparameter combinations.
# Finished evaluating 39/144 hyperparameter combinations.
# Finished evaluating 40/144 hyperparameter combinations.
# Finished evaluating 41/144 hyperparameter combinations.
# Finished evaluating 42/144 hyperparameter combinations.
# Finished evaluating 43/144 hyperparameter combinations.
# Finished evaluating 44/144 hyperparameter combinations.
# Finished evaluating 45/144 hyperparameter combinations.
# Finished evaluating 46/144 hyperparameter combinations.
# Finished evaluating 47/144 hyperparameter combinations.
# Finished evaluating 48/144 hyperparameter combinations.
# Finished evaluating 49/144 hyperparameter combinations.
# Finished evaluating 50/144 hyperparameter combinations.
# Finished evaluating 51/144 hyperparameter combinations.
# Finished evaluating 52/144 hyperparameter combinations.
# Finished evaluating 53/144 hyperparameter combinations.
# Finished evaluating 54/144 hyperparameter combinations.
# Finished evaluating 55/144 hyperparameter combinations.
# Finished evaluating 56/144 hyperparameter combinations.
# Finished evaluating 57/144 hyperparameter combinations.
# Finished evaluating 58/144 hyperparameter combinations.
# Finished evaluating 59/144 hyperparameter combinations.
# Finished evaluating 60/144 hyperparameter combinations.
# Finished evaluating 61/144 hyperparameter combinations.
# Finished evaluating 62/144 hyperparameter combinations.
# Finished evaluating 63/144 hyperparameter combinations.
# Finished evaluating 64/144 hyperparameter combinations.
# Finished evaluating 65/144 hyperparameter combinations.
# Finished evaluating 66/144 hyperparameter combinations.
# Finished evaluating 67/144 hyperparameter combinations.
# Finished evaluating 68/144 hyperparameter combinations.
# Finished evaluating 69/144 hyperparameter combinations.
# Finished evaluating 70/144 hyperparameter combinations.
# Finished evaluating 71/144 hyperparameter combinations.
# Finished evaluating 72/144 hyperparameter combinations.
# Finished evaluating 73/144 hyperparameter combinations.
# Finished evaluating 74/144 hyperparameter combinations.
# Finished evaluating 75/144 hyperparameter combinations.
# Finished evaluating 76/144 hyperparameter combinations.
# Finished evaluating 77/144 hyperparameter combinations.
# Finished evaluating 78/144 hyperparameter combinations.
# Finished evaluating 79/144 hyperparameter combinations.
# Finished evaluating 80/144 hyperparameter combinations.
# Finished evaluating 81/144 hyperparameter combinations.
# Finished evaluating 82/144 hyperparameter combinations.
# Finished evaluating 83/144 hyperparameter combinations.
# Finished evaluating 84/144 hyperparameter combinations.
# Finished evaluating 85/144 hyperparameter combinations.
# Finished evaluating 86/144 hyperparameter combinations.
# Finished evaluating 87/144 hyperparameter combinations.
# Finished evaluating 88/144 hyperparameter combinations.
# Finished evaluating 89/144 hyperparameter combinations.
# Finished evaluating 90/144 hyperparameter combinations.
# Finished evaluating 91/144 hyperparameter combinations.
# Finished evaluating 92/144 hyperparameter combinations.
# Finished evaluating 93/144 hyperparameter combinations.
# Finished evaluating 94/144 hyperparameter combinations.
# Finished evaluating 95/144 hyperparameter combinations.
# Finished evaluating 96/144 hyperparameter combinations.
# Finished evaluating 97/144 hyperparameter combinations.
# Finished evaluating 98/144 hyperparameter combinations.
# Finished evaluating 99/144 hyperparameter combinations.
# Finished evaluating 100/144 hyperparameter combinations.
# Finished evaluating 101/144 hyperparameter combinations.
# Finished evaluating 102/144 hyperparameter combinations.
# Finished evaluating 103/144 hyperparameter combinations.
# Finished evaluating 104/144 hyperparameter combinations.
# Finished evaluating 105/144 hyperparameter combinations.
# Finished evaluating 106/144 hyperparameter combinations.
# Finished evaluating 107/144 hyperparameter combinations.
# Finished evaluating 108/144 hyperparameter combinations.
# Finished evaluating 109/144 hyperparameter combinations.
# Finished evaluating 110/144 hyperparameter combinations.
# Finished evaluating 111/144 hyperparameter combinations.
# Finished evaluating 112/144 hyperparameter combinations.
# Finished evaluating 113/144 hyperparameter combinations.
# Finished evaluating 114/144 hyperparameter combinations.
# Finished evaluating 115/144 hyperparameter combinations.
# Finished evaluating 116/144 hyperparameter combinations.
# Finished evaluating 117/144 hyperparameter combinations.
# Finished evaluating 118/144 hyperparameter combinations.
# Finished evaluating 119/144 hyperparameter combinations.
# Finished evaluating 120/144 hyperparameter combinations.
# Finished evaluating 121/144 hyperparameter combinations.
# Finished evaluating 122/144 hyperparameter combinations.
# Finished evaluating 123/144 hyperparameter combinations.
# Finished evaluating 124/144 hyperparameter combinations.
# Finished evaluating 125/144 hyperparameter combinations.
# Finished evaluating 126/144 hyperparameter combinations.
# Finished evaluating 127/144 hyperparameter combinations.
# Finished evaluating 128/144 hyperparameter combinations.
# Finished evaluating 129/144 hyperparameter combinations.
# Finished evaluating 130/144 hyperparameter combinations.
# Finished evaluating 131/144 hyperparameter combinations.
# Finished evaluating 132/144 hyperparameter combinations.
# Finished evaluating 133/144 hyperparameter combinations.
# Finished evaluating 134/144 hyperparameter combinations.
# Finished evaluating 135/144 hyperparameter combinations.
# Finished evaluating 136/144 hyperparameter combinations.
# Finished evaluating 137/144 hyperparameter combinations.
# Finished evaluating 138/144 hyperparameter combinations.
# Finished evaluating 139/144 hyperparameter combinations.
# Finished evaluating 140/144 hyperparameter combinations.
# Finished evaluating 141/144 hyperparameter combinations.
# Finished evaluating 142/144 hyperparameter combinations.
# Finished evaluating 143/144 hyperparameter combinations.
# Finished evaluating 144/144 hyperparameter combinations.
# Elapsed time in sec:  538.402750083

# %%
print('Using physical and geospatial features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_rf, param_rf))
# Out:
# Using physical and geospatial features, the best CV score during hyper-parameter search is 0.7596879256066593, while the selected hyper-parameters are: {'UniSlct__percentile': 100, 'est__max_depth': 1000, 'est__max_features': 'sqrt', 'est__n_estimators': 2000}

# %% [markdown]
# ### Excluding geospatial features (i.e., only concerning local features of the well itself)

# %%
rng = np.random.RandomState(0)# Reset the random states

rf_steps_self = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", RandomForestClassifier(random_state=rng, n_jobs=-1))
]

rf_clf_pl_self = Pipeline(steps = rf_steps_self)

rf_param_grid_self = {"UniSlct__percentile" : [ 80, 90, 100],
 'est__max_depth': [5, 50, 100,300, 500, 700, None],
 'est__max_features': ['sqrt', 'log2'],
 'est__n_estimators': [100, 200, 1000, 2000, 4000]}

start_time_rf = time.perf_counter()
cv_table_rf_self, score_rf_self, std_rf_self,param_rf_self,pipeline_rf_self = cv_evaluation(rf_clf_pl_self, rf_param_grid_self, X_train_self, y_train, X_cv_train_self_lst,y_cv_train_lst,X_cv_val_self_lst,y_cv_val_lst)
end_time_rf = time.perf_counter()
elapsed_time_rf = end_time_rf - start_time_rf
print("Elapsed time in sec: ", elapsed_time_rf)
# Out:
# Finished evaluating 1/210 hyperparameter combinations.
# Finished evaluating 2/210 hyperparameter combinations.
# Finished evaluating 3/210 hyperparameter combinations.
# Finished evaluating 4/210 hyperparameter combinations.
# Finished evaluating 5/210 hyperparameter combinations.
# Finished evaluating 6/210 hyperparameter combinations.
# Finished evaluating 7/210 hyperparameter combinations.
# Finished evaluating 8/210 hyperparameter combinations.
# Finished evaluating 9/210 hyperparameter combinations.
# Finished evaluating 10/210 hyperparameter combinations.
# Finished evaluating 11/210 hyperparameter combinations.
# Finished evaluating 12/210 hyperparameter combinations.
# Finished evaluating 13/210 hyperparameter combinations.
# Finished evaluating 14/210 hyperparameter combinations.
# Finished evaluating 15/210 hyperparameter combinations.
# Finished evaluating 16/210 hyperparameter combinations.
# Finished evaluating 17/210 hyperparameter combinations.
# Finished evaluating 18/210 hyperparameter combinations.
# Finished evaluating 19/210 hyperparameter combinations.
# Finished evaluating 20/210 hyperparameter combinations.
# Finished evaluating 21/210 hyperparameter combinations.
# Finished evaluating 22/210 hyperparameter combinations.
# Finished evaluating 23/210 hyperparameter combinations.
# Finished evaluating 24/210 hyperparameter combinations.
# Finished evaluating 25/210 hyperparameter combinations.
# Finished evaluating 26/210 hyperparameter combinations.
# Finished evaluating 27/210 hyperparameter combinations.
# Finished evaluating 28/210 hyperparameter combinations.
# Finished evaluating 29/210 hyperparameter combinations.
# Finished evaluating 30/210 hyperparameter combinations.
# Finished evaluating 31/210 hyperparameter combinations.
# Finished evaluating 32/210 hyperparameter combinations.
# Finished evaluating 33/210 hyperparameter combinations.
# Finished evaluating 34/210 hyperparameter combinations.
# Finished evaluating 35/210 hyperparameter combinations.
# Finished evaluating 36/210 hyperparameter combinations.
# Finished evaluating 37/210 hyperparameter combinations.
# Finished evaluating 38/210 hyperparameter combinations.
# Finished evaluating 39/210 hyperparameter combinations.
# Finished evaluating 40/210 hyperparameter combinations.
# Finished evaluating 41/210 hyperparameter combinations.
# Finished evaluating 42/210 hyperparameter combinations.
# Finished evaluating 43/210 hyperparameter combinations.
# Finished evaluating 44/210 hyperparameter combinations.
# Finished evaluating 45/210 hyperparameter combinations.
# Finished evaluating 46/210 hyperparameter combinations.
# Finished evaluating 47/210 hyperparameter combinations.
# Finished evaluating 48/210 hyperparameter combinations.
# Finished evaluating 49/210 hyperparameter combinations.
# Finished evaluating 50/210 hyperparameter combinations.
# Finished evaluating 51/210 hyperparameter combinations.
# Finished evaluating 52/210 hyperparameter combinations.
# Finished evaluating 53/210 hyperparameter combinations.
# Finished evaluating 54/210 hyperparameter combinations.
# Finished evaluating 55/210 hyperparameter combinations.
# Finished evaluating 56/210 hyperparameter combinations.
# Finished evaluating 57/210 hyperparameter combinations.
# Finished evaluating 58/210 hyperparameter combinations.
# Finished evaluating 59/210 hyperparameter combinations.
# Finished evaluating 60/210 hyperparameter combinations.
# Finished evaluating 61/210 hyperparameter combinations.
# Finished evaluating 62/210 hyperparameter combinations.
# Finished evaluating 63/210 hyperparameter combinations.
# Finished evaluating 64/210 hyperparameter combinations.
# Finished evaluating 65/210 hyperparameter combinations.
# Finished evaluating 66/210 hyperparameter combinations.
# Finished evaluating 67/210 hyperparameter combinations.
# Finished evaluating 68/210 hyperparameter combinations.
# Finished evaluating 69/210 hyperparameter combinations.
# Finished evaluating 70/210 hyperparameter combinations.
# Finished evaluating 71/210 hyperparameter combinations.
# Finished evaluating 72/210 hyperparameter combinations.
# Finished evaluating 73/210 hyperparameter combinations.
# Finished evaluating 74/210 hyperparameter combinations.
# Finished evaluating 75/210 hyperparameter combinations.
# Finished evaluating 76/210 hyperparameter combinations.
# Finished evaluating 77/210 hyperparameter combinations.
# Finished evaluating 78/210 hyperparameter combinations.
# Finished evaluating 79/210 hyperparameter combinations.
# Finished evaluating 80/210 hyperparameter combinations.
# Finished evaluating 81/210 hyperparameter combinations.
# Finished evaluating 82/210 hyperparameter combinations.
# Finished evaluating 83/210 hyperparameter combinations.
# Finished evaluating 84/210 hyperparameter combinations.
# Finished evaluating 85/210 hyperparameter combinations.
# Finished evaluating 86/210 hyperparameter combinations.
# Finished evaluating 87/210 hyperparameter combinations.
# Finished evaluating 88/210 hyperparameter combinations.
# Finished evaluating 89/210 hyperparameter combinations.
# Finished evaluating 90/210 hyperparameter combinations.
# Finished evaluating 91/210 hyperparameter combinations.
# Finished evaluating 92/210 hyperparameter combinations.
# Finished evaluating 93/210 hyperparameter combinations.
# Finished evaluating 94/210 hyperparameter combinations.
# Finished evaluating 95/210 hyperparameter combinations.
# Finished evaluating 96/210 hyperparameter combinations.
# Finished evaluating 97/210 hyperparameter combinations.
# Finished evaluating 98/210 hyperparameter combinations.
# Finished evaluating 99/210 hyperparameter combinations.
# Finished evaluating 100/210 hyperparameter combinations.
# Finished evaluating 101/210 hyperparameter combinations.
# Finished evaluating 102/210 hyperparameter combinations.
# Finished evaluating 103/210 hyperparameter combinations.
# Finished evaluating 104/210 hyperparameter combinations.
# Finished evaluating 105/210 hyperparameter combinations.
# Finished evaluating 106/210 hyperparameter combinations.
# Finished evaluating 107/210 hyperparameter combinations.
# Finished evaluating 108/210 hyperparameter combinations.
# Finished evaluating 109/210 hyperparameter combinations.
# Finished evaluating 110/210 hyperparameter combinations.
# Finished evaluating 111/210 hyperparameter combinations.
# Finished evaluating 112/210 hyperparameter combinations.
# Finished evaluating 113/210 hyperparameter combinations.
# Finished evaluating 114/210 hyperparameter combinations.
# Finished evaluating 115/210 hyperparameter combinations.
# Finished evaluating 116/210 hyperparameter combinations.
# Finished evaluating 117/210 hyperparameter combinations.
# Finished evaluating 118/210 hyperparameter combinations.
# Finished evaluating 119/210 hyperparameter combinations.
# Finished evaluating 120/210 hyperparameter combinations.
# Finished evaluating 121/210 hyperparameter combinations.
# Finished evaluating 122/210 hyperparameter combinations.
# Finished evaluating 123/210 hyperparameter combinations.
# Finished evaluating 124/210 hyperparameter combinations.
# Finished evaluating 125/210 hyperparameter combinations.
# Finished evaluating 126/210 hyperparameter combinations.
# Finished evaluating 127/210 hyperparameter combinations.
# Finished evaluating 128/210 hyperparameter combinations.
# Finished evaluating 129/210 hyperparameter combinations.
# Finished evaluating 130/210 hyperparameter combinations.
# Finished evaluating 131/210 hyperparameter combinations.
# Finished evaluating 132/210 hyperparameter combinations.
# Finished evaluating 133/210 hyperparameter combinations.
# Finished evaluating 134/210 hyperparameter combinations.
# Finished evaluating 135/210 hyperparameter combinations.
# Finished evaluating 136/210 hyperparameter combinations.
# Finished evaluating 137/210 hyperparameter combinations.
# Finished evaluating 138/210 hyperparameter combinations.
# Finished evaluating 139/210 hyperparameter combinations.
# Finished evaluating 140/210 hyperparameter combinations.
# Finished evaluating 141/210 hyperparameter combinations.
# Finished evaluating 142/210 hyperparameter combinations.
# Finished evaluating 143/210 hyperparameter combinations.
# Finished evaluating 144/210 hyperparameter combinations.
# Finished evaluating 145/210 hyperparameter combinations.
# Finished evaluating 146/210 hyperparameter combinations.
# Finished evaluating 147/210 hyperparameter combinations.
# Finished evaluating 148/210 hyperparameter combinations.
# Finished evaluating 149/210 hyperparameter combinations.
# Finished evaluating 150/210 hyperparameter combinations.
# Finished evaluating 151/210 hyperparameter combinations.
# Finished evaluating 152/210 hyperparameter combinations.
# Finished evaluating 153/210 hyperparameter combinations.
# Finished evaluating 154/210 hyperparameter combinations.
# Finished evaluating 155/210 hyperparameter combinations.
# Finished evaluating 156/210 hyperparameter combinations.
# Finished evaluating 157/210 hyperparameter combinations.
# Finished evaluating 158/210 hyperparameter combinations.
# Finished evaluating 159/210 hyperparameter combinations.
# Finished evaluating 160/210 hyperparameter combinations.
# Finished evaluating 161/210 hyperparameter combinations.
# Finished evaluating 162/210 hyperparameter combinations.
# Finished evaluating 163/210 hyperparameter combinations.
# Finished evaluating 164/210 hyperparameter combinations.
# Finished evaluating 165/210 hyperparameter combinations.
# Finished evaluating 166/210 hyperparameter combinations.
# Finished evaluating 167/210 hyperparameter combinations.
# Finished evaluating 168/210 hyperparameter combinations.
# Finished evaluating 169/210 hyperparameter combinations.
# Finished evaluating 170/210 hyperparameter combinations.
# Finished evaluating 171/210 hyperparameter combinations.
# Finished evaluating 172/210 hyperparameter combinations.
# Finished evaluating 173/210 hyperparameter combinations.
# Finished evaluating 174/210 hyperparameter combinations.
# Finished evaluating 175/210 hyperparameter combinations.
# Finished evaluating 176/210 hyperparameter combinations.
# Finished evaluating 177/210 hyperparameter combinations.
# Finished evaluating 178/210 hyperparameter combinations.
# Finished evaluating 179/210 hyperparameter combinations.
# Finished evaluating 180/210 hyperparameter combinations.
# Finished evaluating 181/210 hyperparameter combinations.
# Finished evaluating 182/210 hyperparameter combinations.
# Finished evaluating 183/210 hyperparameter combinations.
# Finished evaluating 184/210 hyperparameter combinations.
# Finished evaluating 185/210 hyperparameter combinations.
# Finished evaluating 186/210 hyperparameter combinations.
# Finished evaluating 187/210 hyperparameter combinations.
# Finished evaluating 188/210 hyperparameter combinations.
# Finished evaluating 189/210 hyperparameter combinations.
# Finished evaluating 190/210 hyperparameter combinations.
# Finished evaluating 191/210 hyperparameter combinations.
# Finished evaluating 192/210 hyperparameter combinations.
# Finished evaluating 193/210 hyperparameter combinations.
# Finished evaluating 194/210 hyperparameter combinations.
# Finished evaluating 195/210 hyperparameter combinations.
# Finished evaluating 196/210 hyperparameter combinations.
# Finished evaluating 197/210 hyperparameter combinations.
# Finished evaluating 198/210 hyperparameter combinations.
# Finished evaluating 199/210 hyperparameter combinations.
# Finished evaluating 200/210 hyperparameter combinations.
# Finished evaluating 201/210 hyperparameter combinations.
# Finished evaluating 202/210 hyperparameter combinations.
# Finished evaluating 203/210 hyperparameter combinations.
# Finished evaluating 204/210 hyperparameter combinations.
# Finished evaluating 205/210 hyperparameter combinations.
# Finished evaluating 206/210 hyperparameter combinations.
# Finished evaluating 207/210 hyperparameter combinations.
# Finished evaluating 208/210 hyperparameter combinations.
# Finished evaluating 209/210 hyperparameter combinations.
# Finished evaluating 210/210 hyperparameter combinations.
# Elapsed time in sec:  1336.066527375

# %%
print('Using only physical features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_rf_self, param_rf_self))
# Out:
# Using only physical features, the best CV score during hyper-parameter search is 0.7288542769967731, while the selected hyper-parameters are: {'UniSlct__percentile': 100, 'est__max_depth': 700, 'est__max_features': 'sqrt', 'est__n_estimators': 200}

# %% [markdown]
# ## 2. Estimator = XGBoost

# %% [markdown]
# ### Using all features

# %%
rng = np.random.RandomState(0)
xgb_estimator = xgb.XGBClassifier(objective='binary:logistic', 
                             random_state=rng,
                             subsample=0.9,
                             colsample_bytree=0.5)

xgb_steps = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", xgb_estimator)
]

xgb_clf_pl = Pipeline(steps = xgb_steps)

xgb_param_grid = {
     "UniSlct__percentile" : [80, 90, 100],
     'est__max_depth': [ 30, 40, 50, 60, 70],
     'est__learning_rate': [ 1e-4,1e-3,1e-2, 1e-1],
     'est__gamma': [0, 1e-2, 1e-1, 1],
     'est__reg_lambda': [0, 1e-9, 1e-6]
    }

start_time_xgb = time.perf_counter()
cv_table_xgb,score_xgb, std_xgb,param_xgb,pipeline_xgb = cv_evaluation(xgb_clf_pl, xgb_param_grid, X_train_spatial, y_train, X_cv_train_spatial_lst,y_cv_train_lst,X_cv_val_spatial_lst,y_cv_val_lst)
end_time_xgb = time.perf_counter()
elapsed_time_xgb = end_time_xgb - start_time_xgb
print("Elapsed time in sec: ", elapsed_time_xgb)
# Out:
# Finished evaluating 1/720 hyperparameter combinations.
# Finished evaluating 2/720 hyperparameter combinations.
# Finished evaluating 3/720 hyperparameter combinations.
# Finished evaluating 4/720 hyperparameter combinations.
# Finished evaluating 5/720 hyperparameter combinations.
# Finished evaluating 6/720 hyperparameter combinations.
# Finished evaluating 7/720 hyperparameter combinations.
# Finished evaluating 8/720 hyperparameter combinations.
# Finished evaluating 9/720 hyperparameter combinations.
# Finished evaluating 10/720 hyperparameter combinations.
# Finished evaluating 11/720 hyperparameter combinations.
# Finished evaluating 12/720 hyperparameter combinations.
# Finished evaluating 13/720 hyperparameter combinations.
# Finished evaluating 14/720 hyperparameter combinations.
# Finished evaluating 15/720 hyperparameter combinations.
# Finished evaluating 16/720 hyperparameter combinations.
# Finished evaluating 17/720 hyperparameter combinations.
# Finished evaluating 18/720 hyperparameter combinations.
# Finished evaluating 19/720 hyperparameter combinations.
# Finished evaluating 20/720 hyperparameter combinations.
# Finished evaluating 21/720 hyperparameter combinations.
# Finished evaluating 22/720 hyperparameter combinations.
# Finished evaluating 23/720 hyperparameter combinations.
# Finished evaluating 24/720 hyperparameter combinations.
# Finished evaluating 25/720 hyperparameter combinations.
# Finished evaluating 26/720 hyperparameter combinations.
# Finished evaluating 27/720 hyperparameter combinations.
# Finished evaluating 28/720 hyperparameter combinations.
# Finished evaluating 29/720 hyperparameter combinations.
# Finished evaluating 30/720 hyperparameter combinations.
# Finished evaluating 31/720 hyperparameter combinations.
# Finished evaluating 32/720 hyperparameter combinations.
# Finished evaluating 33/720 hyperparameter combinations.
# Finished evaluating 34/720 hyperparameter combinations.
# Finished evaluating 35/720 hyperparameter combinations.
# Finished evaluating 36/720 hyperparameter combinations.
# Finished evaluating 37/720 hyperparameter combinations.
# Finished evaluating 38/720 hyperparameter combinations.
# Finished evaluating 39/720 hyperparameter combinations.
# Finished evaluating 40/720 hyperparameter combinations.
# Finished evaluating 41/720 hyperparameter combinations.
# Finished evaluating 42/720 hyperparameter combinations.
# Finished evaluating 43/720 hyperparameter combinations.
# Finished evaluating 44/720 hyperparameter combinations.
# Finished evaluating 45/720 hyperparameter combinations.
# Finished evaluating 46/720 hyperparameter combinations.
# Finished evaluating 47/720 hyperparameter combinations.
# Finished evaluating 48/720 hyperparameter combinations.
# Finished evaluating 49/720 hyperparameter combinations.
# Finished evaluating 50/720 hyperparameter combinations.
# Finished evaluating 51/720 hyperparameter combinations.
# Finished evaluating 52/720 hyperparameter combinations.
# Finished evaluating 53/720 hyperparameter combinations.
# Finished evaluating 54/720 hyperparameter combinations.
# Finished evaluating 55/720 hyperparameter combinations.
# Finished evaluating 56/720 hyperparameter combinations.
# Finished evaluating 57/720 hyperparameter combinations.
# Finished evaluating 58/720 hyperparameter combinations.
# Finished evaluating 59/720 hyperparameter combinations.
# Finished evaluating 60/720 hyperparameter combinations.
# Finished evaluating 61/720 hyperparameter combinations.
# Finished evaluating 62/720 hyperparameter combinations.
# Finished evaluating 63/720 hyperparameter combinations.
# Finished evaluating 64/720 hyperparameter combinations.
# Finished evaluating 65/720 hyperparameter combinations.
# Finished evaluating 66/720 hyperparameter combinations.
# Finished evaluating 67/720 hyperparameter combinations.
# Finished evaluating 68/720 hyperparameter combinations.
# Finished evaluating 69/720 hyperparameter combinations.
# Finished evaluating 70/720 hyperparameter combinations.
# Finished evaluating 71/720 hyperparameter combinations.
# Finished evaluating 72/720 hyperparameter combinations.
# Finished evaluating 73/720 hyperparameter combinations.
# Finished evaluating 74/720 hyperparameter combinations.
# Finished evaluating 75/720 hyperparameter combinations.
# Finished evaluating 76/720 hyperparameter combinations.
# Finished evaluating 77/720 hyperparameter combinations.
# Finished evaluating 78/720 hyperparameter combinations.
# Finished evaluating 79/720 hyperparameter combinations.
# Finished evaluating 80/720 hyperparameter combinations.
# Finished evaluating 81/720 hyperparameter combinations.
# Finished evaluating 82/720 hyperparameter combinations.
# Finished evaluating 83/720 hyperparameter combinations.
# Finished evaluating 84/720 hyperparameter combinations.
# Finished evaluating 85/720 hyperparameter combinations.
# Finished evaluating 86/720 hyperparameter combinations.
# Finished evaluating 87/720 hyperparameter combinations.
# Finished evaluating 88/720 hyperparameter combinations.
# Finished evaluating 89/720 hyperparameter combinations.
# Finished evaluating 90/720 hyperparameter combinations.
# Finished evaluating 91/720 hyperparameter combinations.
# Finished evaluating 92/720 hyperparameter combinations.
# Finished evaluating 93/720 hyperparameter combinations.
# Finished evaluating 94/720 hyperparameter combinations.
# Finished evaluating 95/720 hyperparameter combinations.
# Finished evaluating 96/720 hyperparameter combinations.
# Finished evaluating 97/720 hyperparameter combinations.
# Finished evaluating 98/720 hyperparameter combinations.
# Finished evaluating 99/720 hyperparameter combinations.
# Finished evaluating 100/720 hyperparameter combinations.
# Finished evaluating 101/720 hyperparameter combinations.
# Finished evaluating 102/720 hyperparameter combinations.
# Finished evaluating 103/720 hyperparameter combinations.
# Finished evaluating 104/720 hyperparameter combinations.
# Finished evaluating 105/720 hyperparameter combinations.
# Finished evaluating 106/720 hyperparameter combinations.
# Finished evaluating 107/720 hyperparameter combinations.
# Finished evaluating 108/720 hyperparameter combinations.
# Finished evaluating 109/720 hyperparameter combinations.
# Finished evaluating 110/720 hyperparameter combinations.
# Finished evaluating 111/720 hyperparameter combinations.
# Finished evaluating 112/720 hyperparameter combinations.
# Finished evaluating 113/720 hyperparameter combinations.
# Finished evaluating 114/720 hyperparameter combinations.
# Finished evaluating 115/720 hyperparameter combinations.
# Finished evaluating 116/720 hyperparameter combinations.
# Finished evaluating 117/720 hyperparameter combinations.
# Finished evaluating 118/720 hyperparameter combinations.
# Finished evaluating 119/720 hyperparameter combinations.
# Finished evaluating 120/720 hyperparameter combinations.
# Finished evaluating 121/720 hyperparameter combinations.
# Finished evaluating 122/720 hyperparameter combinations.
# Finished evaluating 123/720 hyperparameter combinations.
# Finished evaluating 124/720 hyperparameter combinations.
# Finished evaluating 125/720 hyperparameter combinations.
# Finished evaluating 126/720 hyperparameter combinations.
# Finished evaluating 127/720 hyperparameter combinations.
# Finished evaluating 128/720 hyperparameter combinations.
# Finished evaluating 129/720 hyperparameter combinations.
# Finished evaluating 130/720 hyperparameter combinations.
# Finished evaluating 131/720 hyperparameter combinations.
# Finished evaluating 132/720 hyperparameter combinations.
# Finished evaluating 133/720 hyperparameter combinations.
# Finished evaluating 134/720 hyperparameter combinations.
# Finished evaluating 135/720 hyperparameter combinations.
# Finished evaluating 136/720 hyperparameter combinations.
# Finished evaluating 137/720 hyperparameter combinations.
# Finished evaluating 138/720 hyperparameter combinations.
# Finished evaluating 139/720 hyperparameter combinations.
# Finished evaluating 140/720 hyperparameter combinations.
# Finished evaluating 141/720 hyperparameter combinations.
# Finished evaluating 142/720 hyperparameter combinations.
# Finished evaluating 143/720 hyperparameter combinations.
# Finished evaluating 144/720 hyperparameter combinations.
# Finished evaluating 145/720 hyperparameter combinations.
# Finished evaluating 146/720 hyperparameter combinations.
# Finished evaluating 147/720 hyperparameter combinations.
# Finished evaluating 148/720 hyperparameter combinations.
# Finished evaluating 149/720 hyperparameter combinations.
# Finished evaluating 150/720 hyperparameter combinations.
# Finished evaluating 151/720 hyperparameter combinations.
# Finished evaluating 152/720 hyperparameter combinations.
# Finished evaluating 153/720 hyperparameter combinations.
# Finished evaluating 154/720 hyperparameter combinations.
# Finished evaluating 155/720 hyperparameter combinations.
# Finished evaluating 156/720 hyperparameter combinations.
# Finished evaluating 157/720 hyperparameter combinations.
# Finished evaluating 158/720 hyperparameter combinations.
# Finished evaluating 159/720 hyperparameter combinations.
# Finished evaluating 160/720 hyperparameter combinations.
# Finished evaluating 161/720 hyperparameter combinations.
# Finished evaluating 162/720 hyperparameter combinations.
# Finished evaluating 163/720 hyperparameter combinations.
# Finished evaluating 164/720 hyperparameter combinations.
# Finished evaluating 165/720 hyperparameter combinations.
# Finished evaluating 166/720 hyperparameter combinations.
# Finished evaluating 167/720 hyperparameter combinations.
# Finished evaluating 168/720 hyperparameter combinations.
# Finished evaluating 169/720 hyperparameter combinations.
# Finished evaluating 170/720 hyperparameter combinations.
# Finished evaluating 171/720 hyperparameter combinations.
# Finished evaluating 172/720 hyperparameter combinations.
# Finished evaluating 173/720 hyperparameter combinations.
# Finished evaluating 174/720 hyperparameter combinations.
# Finished evaluating 175/720 hyperparameter combinations.
# Finished evaluating 176/720 hyperparameter combinations.
# Finished evaluating 177/720 hyperparameter combinations.
# Finished evaluating 178/720 hyperparameter combinations.
# Finished evaluating 179/720 hyperparameter combinations.
# Finished evaluating 180/720 hyperparameter combinations.
# Finished evaluating 181/720 hyperparameter combinations.
# Finished evaluating 182/720 hyperparameter combinations.
# Finished evaluating 183/720 hyperparameter combinations.
# Finished evaluating 184/720 hyperparameter combinations.
# Finished evaluating 185/720 hyperparameter combinations.
# Finished evaluating 186/720 hyperparameter combinations.
# Finished evaluating 187/720 hyperparameter combinations.
# Finished evaluating 188/720 hyperparameter combinations.
# Finished evaluating 189/720 hyperparameter combinations.
# Finished evaluating 190/720 hyperparameter combinations.
# Finished evaluating 191/720 hyperparameter combinations.
# Finished evaluating 192/720 hyperparameter combinations.
# Finished evaluating 193/720 hyperparameter combinations.
# Finished evaluating 194/720 hyperparameter combinations.
# Finished evaluating 195/720 hyperparameter combinations.
# Finished evaluating 196/720 hyperparameter combinations.
# Finished evaluating 197/720 hyperparameter combinations.
# Finished evaluating 198/720 hyperparameter combinations.
# Finished evaluating 199/720 hyperparameter combinations.
# Finished evaluating 200/720 hyperparameter combinations.
# Finished evaluating 201/720 hyperparameter combinations.
# Finished evaluating 202/720 hyperparameter combinations.
# Finished evaluating 203/720 hyperparameter combinations.
# Finished evaluating 204/720 hyperparameter combinations.
# Finished evaluating 205/720 hyperparameter combinations.
# Finished evaluating 206/720 hyperparameter combinations.
# Finished evaluating 207/720 hyperparameter combinations.
# Finished evaluating 208/720 hyperparameter combinations.
# Finished evaluating 209/720 hyperparameter combinations.
# Finished evaluating 210/720 hyperparameter combinations.
# Finished evaluating 211/720 hyperparameter combinations.
# Finished evaluating 212/720 hyperparameter combinations.
# Finished evaluating 213/720 hyperparameter combinations.
# Finished evaluating 214/720 hyperparameter combinations.
# Finished evaluating 215/720 hyperparameter combinations.
# Finished evaluating 216/720 hyperparameter combinations.
# Finished evaluating 217/720 hyperparameter combinations.
# Finished evaluating 218/720 hyperparameter combinations.
# Finished evaluating 219/720 hyperparameter combinations.
# Finished evaluating 220/720 hyperparameter combinations.
# Finished evaluating 221/720 hyperparameter combinations.
# Finished evaluating 222/720 hyperparameter combinations.
# Finished evaluating 223/720 hyperparameter combinations.
# Finished evaluating 224/720 hyperparameter combinations.
# Finished evaluating 225/720 hyperparameter combinations.
# Finished evaluating 226/720 hyperparameter combinations.
# Finished evaluating 227/720 hyperparameter combinations.
# Finished evaluating 228/720 hyperparameter combinations.
# Finished evaluating 229/720 hyperparameter combinations.
# Finished evaluating 230/720 hyperparameter combinations.
# Finished evaluating 231/720 hyperparameter combinations.
# Finished evaluating 232/720 hyperparameter combinations.
# Finished evaluating 233/720 hyperparameter combinations.
# Finished evaluating 234/720 hyperparameter combinations.
# Finished evaluating 235/720 hyperparameter combinations.
# Finished evaluating 236/720 hyperparameter combinations.
# Finished evaluating 237/720 hyperparameter combinations.
# Finished evaluating 238/720 hyperparameter combinations.
# Finished evaluating 239/720 hyperparameter combinations.
# Finished evaluating 240/720 hyperparameter combinations.
# Finished evaluating 241/720 hyperparameter combinations.
# Finished evaluating 242/720 hyperparameter combinations.
# Finished evaluating 243/720 hyperparameter combinations.
# Finished evaluating 244/720 hyperparameter combinations.
# Finished evaluating 245/720 hyperparameter combinations.
# Finished evaluating 246/720 hyperparameter combinations.
# Finished evaluating 247/720 hyperparameter combinations.
# Finished evaluating 248/720 hyperparameter combinations.
# Finished evaluating 249/720 hyperparameter combinations.
# Finished evaluating 250/720 hyperparameter combinations.
# Finished evaluating 251/720 hyperparameter combinations.
# Finished evaluating 252/720 hyperparameter combinations.
# Finished evaluating 253/720 hyperparameter combinations.
# Finished evaluating 254/720 hyperparameter combinations.
# Finished evaluating 255/720 hyperparameter combinations.
# Finished evaluating 256/720 hyperparameter combinations.
# Finished evaluating 257/720 hyperparameter combinations.
# Finished evaluating 258/720 hyperparameter combinations.
# Finished evaluating 259/720 hyperparameter combinations.
# Finished evaluating 260/720 hyperparameter combinations.
# Finished evaluating 261/720 hyperparameter combinations.
# Finished evaluating 262/720 hyperparameter combinations.
# Finished evaluating 263/720 hyperparameter combinations.
# Finished evaluating 264/720 hyperparameter combinations.
# Finished evaluating 265/720 hyperparameter combinations.
# Finished evaluating 266/720 hyperparameter combinations.
# Finished evaluating 267/720 hyperparameter combinations.
# Finished evaluating 268/720 hyperparameter combinations.
# Finished evaluating 269/720 hyperparameter combinations.
# Finished evaluating 270/720 hyperparameter combinations.
# Finished evaluating 271/720 hyperparameter combinations.
# Finished evaluating 272/720 hyperparameter combinations.
# Finished evaluating 273/720 hyperparameter combinations.
# Finished evaluating 274/720 hyperparameter combinations.
# Finished evaluating 275/720 hyperparameter combinations.
# Finished evaluating 276/720 hyperparameter combinations.
# Finished evaluating 277/720 hyperparameter combinations.
# Finished evaluating 278/720 hyperparameter combinations.
# Finished evaluating 279/720 hyperparameter combinations.
# Finished evaluating 280/720 hyperparameter combinations.
# Finished evaluating 281/720 hyperparameter combinations.
# Finished evaluating 282/720 hyperparameter combinations.
# Finished evaluating 283/720 hyperparameter combinations.
# Finished evaluating 284/720 hyperparameter combinations.
# Finished evaluating 285/720 hyperparameter combinations.
# Finished evaluating 286/720 hyperparameter combinations.
# Finished evaluating 287/720 hyperparameter combinations.
# Finished evaluating 288/720 hyperparameter combinations.
# Finished evaluating 289/720 hyperparameter combinations.
# Finished evaluating 290/720 hyperparameter combinations.
# Finished evaluating 291/720 hyperparameter combinations.
# Finished evaluating 292/720 hyperparameter combinations.
# Finished evaluating 293/720 hyperparameter combinations.
# Finished evaluating 294/720 hyperparameter combinations.
# Finished evaluating 295/720 hyperparameter combinations.
# Finished evaluating 296/720 hyperparameter combinations.
# Finished evaluating 297/720 hyperparameter combinations.
# Finished evaluating 298/720 hyperparameter combinations.
# Finished evaluating 299/720 hyperparameter combinations.
# Finished evaluating 300/720 hyperparameter combinations.
# Finished evaluating 301/720 hyperparameter combinations.
# Finished evaluating 302/720 hyperparameter combinations.
# Finished evaluating 303/720 hyperparameter combinations.
# Finished evaluating 304/720 hyperparameter combinations.
# Finished evaluating 305/720 hyperparameter combinations.
# Finished evaluating 306/720 hyperparameter combinations.
# Finished evaluating 307/720 hyperparameter combinations.
# Finished evaluating 308/720 hyperparameter combinations.
# Finished evaluating 309/720 hyperparameter combinations.
# Finished evaluating 310/720 hyperparameter combinations.
# Finished evaluating 311/720 hyperparameter combinations.
# Finished evaluating 312/720 hyperparameter combinations.
# Finished evaluating 313/720 hyperparameter combinations.
# Finished evaluating 314/720 hyperparameter combinations.
# Finished evaluating 315/720 hyperparameter combinations.
# Finished evaluating 316/720 hyperparameter combinations.
# Finished evaluating 317/720 hyperparameter combinations.
# Finished evaluating 318/720 hyperparameter combinations.
# Finished evaluating 319/720 hyperparameter combinations.
# Finished evaluating 320/720 hyperparameter combinations.
# Finished evaluating 321/720 hyperparameter combinations.
# Finished evaluating 322/720 hyperparameter combinations.
# Finished evaluating 323/720 hyperparameter combinations.
# Finished evaluating 324/720 hyperparameter combinations.
# Finished evaluating 325/720 hyperparameter combinations.
# Finished evaluating 326/720 hyperparameter combinations.
# Finished evaluating 327/720 hyperparameter combinations.
# Finished evaluating 328/720 hyperparameter combinations.
# Finished evaluating 329/720 hyperparameter combinations.
# Finished evaluating 330/720 hyperparameter combinations.
# Finished evaluating 331/720 hyperparameter combinations.
# Finished evaluating 332/720 hyperparameter combinations.
# Finished evaluating 333/720 hyperparameter combinations.
# Finished evaluating 334/720 hyperparameter combinations.
# Finished evaluating 335/720 hyperparameter combinations.
# Finished evaluating 336/720 hyperparameter combinations.
# Finished evaluating 337/720 hyperparameter combinations.
# Finished evaluating 338/720 hyperparameter combinations.
# Finished evaluating 339/720 hyperparameter combinations.
# Finished evaluating 340/720 hyperparameter combinations.
# Finished evaluating 341/720 hyperparameter combinations.
# Finished evaluating 342/720 hyperparameter combinations.
# Finished evaluating 343/720 hyperparameter combinations.
# Finished evaluating 344/720 hyperparameter combinations.
# Finished evaluating 345/720 hyperparameter combinations.
# Finished evaluating 346/720 hyperparameter combinations.
# Finished evaluating 347/720 hyperparameter combinations.
# Finished evaluating 348/720 hyperparameter combinations.
# Finished evaluating 349/720 hyperparameter combinations.
# Finished evaluating 350/720 hyperparameter combinations.
# Finished evaluating 351/720 hyperparameter combinations.
# Finished evaluating 352/720 hyperparameter combinations.
# Finished evaluating 353/720 hyperparameter combinations.
# Finished evaluating 354/720 hyperparameter combinations.
# Finished evaluating 355/720 hyperparameter combinations.
# Finished evaluating 356/720 hyperparameter combinations.
# Finished evaluating 357/720 hyperparameter combinations.
# Finished evaluating 358/720 hyperparameter combinations.
# Finished evaluating 359/720 hyperparameter combinations.
# Finished evaluating 360/720 hyperparameter combinations.
# Finished evaluating 361/720 hyperparameter combinations.
# Finished evaluating 362/720 hyperparameter combinations.
# Finished evaluating 363/720 hyperparameter combinations.
# Finished evaluating 364/720 hyperparameter combinations.
# Finished evaluating 365/720 hyperparameter combinations.
# Finished evaluating 366/720 hyperparameter combinations.
# Finished evaluating 367/720 hyperparameter combinations.
# Finished evaluating 368/720 hyperparameter combinations.
# Finished evaluating 369/720 hyperparameter combinations.
# Finished evaluating 370/720 hyperparameter combinations.
# Finished evaluating 371/720 hyperparameter combinations.
# Finished evaluating 372/720 hyperparameter combinations.
# Finished evaluating 373/720 hyperparameter combinations.
# Finished evaluating 374/720 hyperparameter combinations.
# Finished evaluating 375/720 hyperparameter combinations.
# Finished evaluating 376/720 hyperparameter combinations.
# Finished evaluating 377/720 hyperparameter combinations.
# Finished evaluating 378/720 hyperparameter combinations.
# Finished evaluating 379/720 hyperparameter combinations.
# Finished evaluating 380/720 hyperparameter combinations.
# Finished evaluating 381/720 hyperparameter combinations.
# Finished evaluating 382/720 hyperparameter combinations.
# Finished evaluating 383/720 hyperparameter combinations.
# Finished evaluating 384/720 hyperparameter combinations.
# Finished evaluating 385/720 hyperparameter combinations.
# Finished evaluating 386/720 hyperparameter combinations.
# Finished evaluating 387/720 hyperparameter combinations.
# Finished evaluating 388/720 hyperparameter combinations.
# Finished evaluating 389/720 hyperparameter combinations.
# Finished evaluating 390/720 hyperparameter combinations.
# Finished evaluating 391/720 hyperparameter combinations.
# Finished evaluating 392/720 hyperparameter combinations.
# Finished evaluating 393/720 hyperparameter combinations.
# Finished evaluating 394/720 hyperparameter combinations.
# Finished evaluating 395/720 hyperparameter combinations.
# Finished evaluating 396/720 hyperparameter combinations.
# Finished evaluating 397/720 hyperparameter combinations.
# Finished evaluating 398/720 hyperparameter combinations.
# Finished evaluating 399/720 hyperparameter combinations.
# Finished evaluating 400/720 hyperparameter combinations.
# Finished evaluating 401/720 hyperparameter combinations.
# Finished evaluating 402/720 hyperparameter combinations.
# Finished evaluating 403/720 hyperparameter combinations.
# Finished evaluating 404/720 hyperparameter combinations.
# Finished evaluating 405/720 hyperparameter combinations.
# Finished evaluating 406/720 hyperparameter combinations.
# Finished evaluating 407/720 hyperparameter combinations.
# Finished evaluating 408/720 hyperparameter combinations.
# Finished evaluating 409/720 hyperparameter combinations.
# Finished evaluating 410/720 hyperparameter combinations.
# Finished evaluating 411/720 hyperparameter combinations.
# Finished evaluating 412/720 hyperparameter combinations.
# Finished evaluating 413/720 hyperparameter combinations.
# Finished evaluating 414/720 hyperparameter combinations.
# Finished evaluating 415/720 hyperparameter combinations.
# Finished evaluating 416/720 hyperparameter combinations.
# Finished evaluating 417/720 hyperparameter combinations.
# Finished evaluating 418/720 hyperparameter combinations.
# Finished evaluating 419/720 hyperparameter combinations.
# Finished evaluating 420/720 hyperparameter combinations.
# Finished evaluating 421/720 hyperparameter combinations.
# Finished evaluating 422/720 hyperparameter combinations.
# Finished evaluating 423/720 hyperparameter combinations.
# Finished evaluating 424/720 hyperparameter combinations.
# Finished evaluating 425/720 hyperparameter combinations.
# Finished evaluating 426/720 hyperparameter combinations.
# Finished evaluating 427/720 hyperparameter combinations.
# Finished evaluating 428/720 hyperparameter combinations.
# Finished evaluating 429/720 hyperparameter combinations.
# Finished evaluating 430/720 hyperparameter combinations.
# Finished evaluating 431/720 hyperparameter combinations.
# Finished evaluating 432/720 hyperparameter combinations.
# Finished evaluating 433/720 hyperparameter combinations.
# Finished evaluating 434/720 hyperparameter combinations.
# Finished evaluating 435/720 hyperparameter combinations.
# Finished evaluating 436/720 hyperparameter combinations.
# Finished evaluating 437/720 hyperparameter combinations.
# Finished evaluating 438/720 hyperparameter combinations.
# Finished evaluating 439/720 hyperparameter combinations.
# Finished evaluating 440/720 hyperparameter combinations.
# Finished evaluating 441/720 hyperparameter combinations.
# Finished evaluating 442/720 hyperparameter combinations.
# Finished evaluating 443/720 hyperparameter combinations.
# Finished evaluating 444/720 hyperparameter combinations.
# Finished evaluating 445/720 hyperparameter combinations.
# Finished evaluating 446/720 hyperparameter combinations.
# Finished evaluating 447/720 hyperparameter combinations.
# Finished evaluating 448/720 hyperparameter combinations.
# Finished evaluating 449/720 hyperparameter combinations.
# Finished evaluating 450/720 hyperparameter combinations.
# Finished evaluating 451/720 hyperparameter combinations.
# Finished evaluating 452/720 hyperparameter combinations.
# Finished evaluating 453/720 hyperparameter combinations.
# Finished evaluating 454/720 hyperparameter combinations.
# Finished evaluating 455/720 hyperparameter combinations.
# Finished evaluating 456/720 hyperparameter combinations.
# Finished evaluating 457/720 hyperparameter combinations.
# Finished evaluating 458/720 hyperparameter combinations.
# Finished evaluating 459/720 hyperparameter combinations.
# Finished evaluating 460/720 hyperparameter combinations.
# Finished evaluating 461/720 hyperparameter combinations.
# Finished evaluating 462/720 hyperparameter combinations.
# Finished evaluating 463/720 hyperparameter combinations.
# Finished evaluating 464/720 hyperparameter combinations.
# Finished evaluating 465/720 hyperparameter combinations.
# Finished evaluating 466/720 hyperparameter combinations.
# Finished evaluating 467/720 hyperparameter combinations.
# Finished evaluating 468/720 hyperparameter combinations.
# Finished evaluating 469/720 hyperparameter combinations.
# Finished evaluating 470/720 hyperparameter combinations.
# Finished evaluating 471/720 hyperparameter combinations.
# Finished evaluating 472/720 hyperparameter combinations.
# Finished evaluating 473/720 hyperparameter combinations.
# Finished evaluating 474/720 hyperparameter combinations.
# Finished evaluating 475/720 hyperparameter combinations.
# Finished evaluating 476/720 hyperparameter combinations.
# Finished evaluating 477/720 hyperparameter combinations.
# Finished evaluating 478/720 hyperparameter combinations.
# Finished evaluating 479/720 hyperparameter combinations.
# Finished evaluating 480/720 hyperparameter combinations.
# Finished evaluating 481/720 hyperparameter combinations.
# Finished evaluating 482/720 hyperparameter combinations.
# Finished evaluating 483/720 hyperparameter combinations.
# Finished evaluating 484/720 hyperparameter combinations.
# Finished evaluating 485/720 hyperparameter combinations.
# Finished evaluating 486/720 hyperparameter combinations.
# Finished evaluating 487/720 hyperparameter combinations.
# Finished evaluating 488/720 hyperparameter combinations.
# Finished evaluating 489/720 hyperparameter combinations.
# Finished evaluating 490/720 hyperparameter combinations.
# Finished evaluating 491/720 hyperparameter combinations.
# Finished evaluating 492/720 hyperparameter combinations.
# Finished evaluating 493/720 hyperparameter combinations.
# Finished evaluating 494/720 hyperparameter combinations.
# Finished evaluating 495/720 hyperparameter combinations.
# Finished evaluating 496/720 hyperparameter combinations.
# Finished evaluating 497/720 hyperparameter combinations.
# Finished evaluating 498/720 hyperparameter combinations.
# Finished evaluating 499/720 hyperparameter combinations.
# Finished evaluating 500/720 hyperparameter combinations.
# Finished evaluating 501/720 hyperparameter combinations.
# Finished evaluating 502/720 hyperparameter combinations.
# Finished evaluating 503/720 hyperparameter combinations.
# Finished evaluating 504/720 hyperparameter combinations.
# Finished evaluating 505/720 hyperparameter combinations.
# Finished evaluating 506/720 hyperparameter combinations.
# Finished evaluating 507/720 hyperparameter combinations.
# Finished evaluating 508/720 hyperparameter combinations.
# Finished evaluating 509/720 hyperparameter combinations.
# Finished evaluating 510/720 hyperparameter combinations.
# Finished evaluating 511/720 hyperparameter combinations.
# Finished evaluating 512/720 hyperparameter combinations.
# Finished evaluating 513/720 hyperparameter combinations.
# Finished evaluating 514/720 hyperparameter combinations.
# Finished evaluating 515/720 hyperparameter combinations.
# Finished evaluating 516/720 hyperparameter combinations.
# Finished evaluating 517/720 hyperparameter combinations.
# Finished evaluating 518/720 hyperparameter combinations.
# Finished evaluating 519/720 hyperparameter combinations.
# Finished evaluating 520/720 hyperparameter combinations.
# Finished evaluating 521/720 hyperparameter combinations.
# Finished evaluating 522/720 hyperparameter combinations.
# Finished evaluating 523/720 hyperparameter combinations.
# Finished evaluating 524/720 hyperparameter combinations.
# Finished evaluating 525/720 hyperparameter combinations.
# Finished evaluating 526/720 hyperparameter combinations.
# Finished evaluating 527/720 hyperparameter combinations.
# Finished evaluating 528/720 hyperparameter combinations.
# Finished evaluating 529/720 hyperparameter combinations.
# Finished evaluating 530/720 hyperparameter combinations.
# Finished evaluating 531/720 hyperparameter combinations.
# Finished evaluating 532/720 hyperparameter combinations.
# Finished evaluating 533/720 hyperparameter combinations.
# Finished evaluating 534/720 hyperparameter combinations.
# Finished evaluating 535/720 hyperparameter combinations.
# Finished evaluating 536/720 hyperparameter combinations.
# Finished evaluating 537/720 hyperparameter combinations.
# Finished evaluating 538/720 hyperparameter combinations.
# Finished evaluating 539/720 hyperparameter combinations.
# Finished evaluating 540/720 hyperparameter combinations.
# Finished evaluating 541/720 hyperparameter combinations.
# Finished evaluating 542/720 hyperparameter combinations.
# Finished evaluating 543/720 hyperparameter combinations.
# Finished evaluating 544/720 hyperparameter combinations.
# Finished evaluating 545/720 hyperparameter combinations.
# Finished evaluating 546/720 hyperparameter combinations.
# Finished evaluating 547/720 hyperparameter combinations.
# Finished evaluating 548/720 hyperparameter combinations.
# Finished evaluating 549/720 hyperparameter combinations.
# Finished evaluating 550/720 hyperparameter combinations.
# Finished evaluating 551/720 hyperparameter combinations.
# Finished evaluating 552/720 hyperparameter combinations.
# Finished evaluating 553/720 hyperparameter combinations.
# Finished evaluating 554/720 hyperparameter combinations.
# Finished evaluating 555/720 hyperparameter combinations.
# Finished evaluating 556/720 hyperparameter combinations.
# Finished evaluating 557/720 hyperparameter combinations.
# Finished evaluating 558/720 hyperparameter combinations.
# Finished evaluating 559/720 hyperparameter combinations.
# Finished evaluating 560/720 hyperparameter combinations.
# Finished evaluating 561/720 hyperparameter combinations.
# Finished evaluating 562/720 hyperparameter combinations.
# Finished evaluating 563/720 hyperparameter combinations.
# Finished evaluating 564/720 hyperparameter combinations.
# Finished evaluating 565/720 hyperparameter combinations.
# Finished evaluating 566/720 hyperparameter combinations.
# Finished evaluating 567/720 hyperparameter combinations.
# Finished evaluating 568/720 hyperparameter combinations.
# Finished evaluating 569/720 hyperparameter combinations.
# Finished evaluating 570/720 hyperparameter combinations.
# Finished evaluating 571/720 hyperparameter combinations.
# Finished evaluating 572/720 hyperparameter combinations.
# Finished evaluating 573/720 hyperparameter combinations.
# Finished evaluating 574/720 hyperparameter combinations.
# Finished evaluating 575/720 hyperparameter combinations.
# Finished evaluating 576/720 hyperparameter combinations.
# Finished evaluating 577/720 hyperparameter combinations.
# Finished evaluating 578/720 hyperparameter combinations.
# Finished evaluating 579/720 hyperparameter combinations.
# Finished evaluating 580/720 hyperparameter combinations.
# Finished evaluating 581/720 hyperparameter combinations.
# Finished evaluating 582/720 hyperparameter combinations.
# Finished evaluating 583/720 hyperparameter combinations.
# Finished evaluating 584/720 hyperparameter combinations.
# Finished evaluating 585/720 hyperparameter combinations.
# Finished evaluating 586/720 hyperparameter combinations.
# Finished evaluating 587/720 hyperparameter combinations.
# Finished evaluating 588/720 hyperparameter combinations.
# Finished evaluating 589/720 hyperparameter combinations.
# Finished evaluating 590/720 hyperparameter combinations.
# Finished evaluating 591/720 hyperparameter combinations.
# Finished evaluating 592/720 hyperparameter combinations.
# Finished evaluating 593/720 hyperparameter combinations.
# Finished evaluating 594/720 hyperparameter combinations.
# Finished evaluating 595/720 hyperparameter combinations.
# Finished evaluating 596/720 hyperparameter combinations.
# Finished evaluating 597/720 hyperparameter combinations.
# Finished evaluating 598/720 hyperparameter combinations.
# Finished evaluating 599/720 hyperparameter combinations.
# Finished evaluating 600/720 hyperparameter combinations.
# Finished evaluating 601/720 hyperparameter combinations.
# Finished evaluating 602/720 hyperparameter combinations.
# Finished evaluating 603/720 hyperparameter combinations.
# Finished evaluating 604/720 hyperparameter combinations.
# Finished evaluating 605/720 hyperparameter combinations.
# Finished evaluating 606/720 hyperparameter combinations.
# Finished evaluating 607/720 hyperparameter combinations.
# Finished evaluating 608/720 hyperparameter combinations.
# Finished evaluating 609/720 hyperparameter combinations.
# Finished evaluating 610/720 hyperparameter combinations.
# Finished evaluating 611/720 hyperparameter combinations.
# Finished evaluating 612/720 hyperparameter combinations.
# Finished evaluating 613/720 hyperparameter combinations.
# Finished evaluating 614/720 hyperparameter combinations.
# Finished evaluating 615/720 hyperparameter combinations.
# Finished evaluating 616/720 hyperparameter combinations.
# Finished evaluating 617/720 hyperparameter combinations.
# Finished evaluating 618/720 hyperparameter combinations.
# Finished evaluating 619/720 hyperparameter combinations.
# Finished evaluating 620/720 hyperparameter combinations.
# Finished evaluating 621/720 hyperparameter combinations.
# Finished evaluating 622/720 hyperparameter combinations.
# Finished evaluating 623/720 hyperparameter combinations.
# Finished evaluating 624/720 hyperparameter combinations.
# Finished evaluating 625/720 hyperparameter combinations.
# Finished evaluating 626/720 hyperparameter combinations.
# Finished evaluating 627/720 hyperparameter combinations.
# Finished evaluating 628/720 hyperparameter combinations.
# Finished evaluating 629/720 hyperparameter combinations.
# Finished evaluating 630/720 hyperparameter combinations.
# Finished evaluating 631/720 hyperparameter combinations.
# Finished evaluating 632/720 hyperparameter combinations.
# Finished evaluating 633/720 hyperparameter combinations.
# Finished evaluating 634/720 hyperparameter combinations.
# Finished evaluating 635/720 hyperparameter combinations.
# Finished evaluating 636/720 hyperparameter combinations.
# Finished evaluating 637/720 hyperparameter combinations.
# Finished evaluating 638/720 hyperparameter combinations.
# Finished evaluating 639/720 hyperparameter combinations.
# Finished evaluating 640/720 hyperparameter combinations.
# Finished evaluating 641/720 hyperparameter combinations.
# Finished evaluating 642/720 hyperparameter combinations.
# Finished evaluating 643/720 hyperparameter combinations.
# Finished evaluating 644/720 hyperparameter combinations.
# Finished evaluating 645/720 hyperparameter combinations.
# Finished evaluating 646/720 hyperparameter combinations.
# Finished evaluating 647/720 hyperparameter combinations.
# Finished evaluating 648/720 hyperparameter combinations.
# Finished evaluating 649/720 hyperparameter combinations.
# Finished evaluating 650/720 hyperparameter combinations.
# Finished evaluating 651/720 hyperparameter combinations.
# Finished evaluating 652/720 hyperparameter combinations.
# Finished evaluating 653/720 hyperparameter combinations.
# Finished evaluating 654/720 hyperparameter combinations.
# Finished evaluating 655/720 hyperparameter combinations.
# Finished evaluating 656/720 hyperparameter combinations.
# Finished evaluating 657/720 hyperparameter combinations.
# Finished evaluating 658/720 hyperparameter combinations.
# Finished evaluating 659/720 hyperparameter combinations.
# Finished evaluating 660/720 hyperparameter combinations.
# Finished evaluating 661/720 hyperparameter combinations.
# Finished evaluating 662/720 hyperparameter combinations.
# Finished evaluating 663/720 hyperparameter combinations.
# Finished evaluating 664/720 hyperparameter combinations.
# Finished evaluating 665/720 hyperparameter combinations.
# Finished evaluating 666/720 hyperparameter combinations.
# Finished evaluating 667/720 hyperparameter combinations.
# Finished evaluating 668/720 hyperparameter combinations.
# Finished evaluating 669/720 hyperparameter combinations.
# Finished evaluating 670/720 hyperparameter combinations.
# Finished evaluating 671/720 hyperparameter combinations.
# Finished evaluating 672/720 hyperparameter combinations.
# Finished evaluating 673/720 hyperparameter combinations.
# Finished evaluating 674/720 hyperparameter combinations.
# Finished evaluating 675/720 hyperparameter combinations.
# Finished evaluating 676/720 hyperparameter combinations.
# Finished evaluating 677/720 hyperparameter combinations.
# Finished evaluating 678/720 hyperparameter combinations.
# Finished evaluating 679/720 hyperparameter combinations.
# Finished evaluating 680/720 hyperparameter combinations.
# Finished evaluating 681/720 hyperparameter combinations.
# Finished evaluating 682/720 hyperparameter combinations.
# Finished evaluating 683/720 hyperparameter combinations.
# Finished evaluating 684/720 hyperparameter combinations.
# Finished evaluating 685/720 hyperparameter combinations.
# Finished evaluating 686/720 hyperparameter combinations.
# Finished evaluating 687/720 hyperparameter combinations.
# Finished evaluating 688/720 hyperparameter combinations.
# Finished evaluating 689/720 hyperparameter combinations.
# Finished evaluating 690/720 hyperparameter combinations.
# Finished evaluating 691/720 hyperparameter combinations.
# Finished evaluating 692/720 hyperparameter combinations.
# Finished evaluating 693/720 hyperparameter combinations.
# Finished evaluating 694/720 hyperparameter combinations.
# Finished evaluating 695/720 hyperparameter combinations.
# Finished evaluating 696/720 hyperparameter combinations.
# Finished evaluating 697/720 hyperparameter combinations.
# Finished evaluating 698/720 hyperparameter combinations.
# Finished evaluating 699/720 hyperparameter combinations.
# Finished evaluating 700/720 hyperparameter combinations.
# Finished evaluating 701/720 hyperparameter combinations.
# Finished evaluating 702/720 hyperparameter combinations.
# Finished evaluating 703/720 hyperparameter combinations.
# Finished evaluating 704/720 hyperparameter combinations.
# Finished evaluating 705/720 hyperparameter combinations.
# Finished evaluating 706/720 hyperparameter combinations.
# Finished evaluating 707/720 hyperparameter combinations.
# Finished evaluating 708/720 hyperparameter combinations.
# Finished evaluating 709/720 hyperparameter combinations.
# Finished evaluating 710/720 hyperparameter combinations.
# Finished evaluating 711/720 hyperparameter combinations.
# Finished evaluating 712/720 hyperparameter combinations.
# Finished evaluating 713/720 hyperparameter combinations.
# Finished evaluating 714/720 hyperparameter combinations.
# Finished evaluating 715/720 hyperparameter combinations.
# Finished evaluating 716/720 hyperparameter combinations.
# Finished evaluating 717/720 hyperparameter combinations.
# Finished evaluating 718/720 hyperparameter combinations.
# Finished evaluating 719/720 hyperparameter combinations.
# Finished evaluating 720/720 hyperparameter combinations.
# Elapsed time in sec:  827.2796920830001

# %%
print('Using physical and geospatial features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_xgb, param_xgb))
# Out:
# Using physical and geospatial features, the best CV score during hyper-parameter search is 0.7543396248916556, while the selected hyper-parameters are: {'UniSlct__percentile': 80, 'est__gamma': 1, 'est__learning_rate': 0.01, 'est__max_depth': 50, 'est__reg_lambda': 0}

# %% [markdown]
# ### Excluding geospatial features

# %%
rng = np.random.RandomState(0)
xgb_estimator_self = xgb.XGBClassifier(objective='binary:logistic', 
                             random_state=rng,
                             subsample=0.9,
                             colsample_bytree=0.5)

xgb_steps_self = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", xgb_estimator_self)
]

xgb_clf_pl_self = Pipeline(steps = xgb_steps_self)

xgb_param_grid_self = {
     "UniSlct__percentile" : [70, 80, 90, 100],
     'est__max_depth': [ 10, 20, 30, 40],
     'est__learning_rate': [1e-7,1e-6,1e-5,1e-4],
     'est__gamma': [1e-8, 1e-7,1e-6,1e-5],
     'est__reg_lambda':  [1e-4, 1e-3, 1e-2, 1e-1],
    }

start_time_xgb = time.perf_counter()
cv_table_xgb_self, score_xgb_self, std_xgb_self,param_xgb_self,pipeline_xgb_self = cv_evaluation(xgb_clf_pl_self, xgb_param_grid_self, X_train_self, y_train, X_cv_train_self_lst,y_cv_train_lst,X_cv_val_self_lst,y_cv_val_lst)
end_time_xgb = time.perf_counter()
elapsed_time_xgb = end_time_xgb - start_time_xgb
print("Elapsed time in sec: ", elapsed_time_xgb)
# Out:
# Finished evaluating 1/1024 hyperparameter combinations.
# Finished evaluating 2/1024 hyperparameter combinations.
# Finished evaluating 3/1024 hyperparameter combinations.
# Finished evaluating 4/1024 hyperparameter combinations.
# Finished evaluating 5/1024 hyperparameter combinations.
# Finished evaluating 6/1024 hyperparameter combinations.
# Finished evaluating 7/1024 hyperparameter combinations.
# Finished evaluating 8/1024 hyperparameter combinations.
# Finished evaluating 9/1024 hyperparameter combinations.
# Finished evaluating 10/1024 hyperparameter combinations.
# Finished evaluating 11/1024 hyperparameter combinations.
# Finished evaluating 12/1024 hyperparameter combinations.
# Finished evaluating 13/1024 hyperparameter combinations.
# Finished evaluating 14/1024 hyperparameter combinations.
# Finished evaluating 15/1024 hyperparameter combinations.
# Finished evaluating 16/1024 hyperparameter combinations.
# Finished evaluating 17/1024 hyperparameter combinations.
# Finished evaluating 18/1024 hyperparameter combinations.
# Finished evaluating 19/1024 hyperparameter combinations.
# Finished evaluating 20/1024 hyperparameter combinations.
# Finished evaluating 21/1024 hyperparameter combinations.
# Finished evaluating 22/1024 hyperparameter combinations.
# Finished evaluating 23/1024 hyperparameter combinations.
# Finished evaluating 24/1024 hyperparameter combinations.
# Finished evaluating 25/1024 hyperparameter combinations.
# Finished evaluating 26/1024 hyperparameter combinations.
# Finished evaluating 27/1024 hyperparameter combinations.
# Finished evaluating 28/1024 hyperparameter combinations.
# Finished evaluating 29/1024 hyperparameter combinations.
# Finished evaluating 30/1024 hyperparameter combinations.
# Finished evaluating 31/1024 hyperparameter combinations.
# Finished evaluating 32/1024 hyperparameter combinations.
# Finished evaluating 33/1024 hyperparameter combinations.
# Finished evaluating 34/1024 hyperparameter combinations.
# Finished evaluating 35/1024 hyperparameter combinations.
# Finished evaluating 36/1024 hyperparameter combinations.
# Finished evaluating 37/1024 hyperparameter combinations.
# Finished evaluating 38/1024 hyperparameter combinations.
# Finished evaluating 39/1024 hyperparameter combinations.
# Finished evaluating 40/1024 hyperparameter combinations.
# Finished evaluating 41/1024 hyperparameter combinations.
# Finished evaluating 42/1024 hyperparameter combinations.
# Finished evaluating 43/1024 hyperparameter combinations.
# Finished evaluating 44/1024 hyperparameter combinations.
# Finished evaluating 45/1024 hyperparameter combinations.
# Finished evaluating 46/1024 hyperparameter combinations.
# Finished evaluating 47/1024 hyperparameter combinations.
# Finished evaluating 48/1024 hyperparameter combinations.
# Finished evaluating 49/1024 hyperparameter combinations.
# Finished evaluating 50/1024 hyperparameter combinations.
# Finished evaluating 51/1024 hyperparameter combinations.
# Finished evaluating 52/1024 hyperparameter combinations.
# Finished evaluating 53/1024 hyperparameter combinations.
# Finished evaluating 54/1024 hyperparameter combinations.
# Finished evaluating 55/1024 hyperparameter combinations.
# Finished evaluating 56/1024 hyperparameter combinations.
# Finished evaluating 57/1024 hyperparameter combinations.
# Finished evaluating 58/1024 hyperparameter combinations.
# Finished evaluating 59/1024 hyperparameter combinations.
# Finished evaluating 60/1024 hyperparameter combinations.
# Finished evaluating 61/1024 hyperparameter combinations.
# Finished evaluating 62/1024 hyperparameter combinations.
# Finished evaluating 63/1024 hyperparameter combinations.
# Finished evaluating 64/1024 hyperparameter combinations.
# Finished evaluating 65/1024 hyperparameter combinations.
# Finished evaluating 66/1024 hyperparameter combinations.
# Finished evaluating 67/1024 hyperparameter combinations.
# Finished evaluating 68/1024 hyperparameter combinations.
# Finished evaluating 69/1024 hyperparameter combinations.
# Finished evaluating 70/1024 hyperparameter combinations.
# Finished evaluating 71/1024 hyperparameter combinations.
# Finished evaluating 72/1024 hyperparameter combinations.
# Finished evaluating 73/1024 hyperparameter combinations.
# Finished evaluating 74/1024 hyperparameter combinations.
# Finished evaluating 75/1024 hyperparameter combinations.
# Finished evaluating 76/1024 hyperparameter combinations.
# Finished evaluating 77/1024 hyperparameter combinations.
# Finished evaluating 78/1024 hyperparameter combinations.
# Finished evaluating 79/1024 hyperparameter combinations.
# Finished evaluating 80/1024 hyperparameter combinations.
# Finished evaluating 81/1024 hyperparameter combinations.
# Finished evaluating 82/1024 hyperparameter combinations.
# Finished evaluating 83/1024 hyperparameter combinations.
# Finished evaluating 84/1024 hyperparameter combinations.
# Finished evaluating 85/1024 hyperparameter combinations.
# Finished evaluating 86/1024 hyperparameter combinations.
# Finished evaluating 87/1024 hyperparameter combinations.
# Finished evaluating 88/1024 hyperparameter combinations.
# Finished evaluating 89/1024 hyperparameter combinations.
# Finished evaluating 90/1024 hyperparameter combinations.
# Finished evaluating 91/1024 hyperparameter combinations.
# Finished evaluating 92/1024 hyperparameter combinations.
# Finished evaluating 93/1024 hyperparameter combinations.
# Finished evaluating 94/1024 hyperparameter combinations.
# Finished evaluating 95/1024 hyperparameter combinations.
# Finished evaluating 96/1024 hyperparameter combinations.
# Finished evaluating 97/1024 hyperparameter combinations.
# Finished evaluating 98/1024 hyperparameter combinations.
# Finished evaluating 99/1024 hyperparameter combinations.
# Finished evaluating 100/1024 hyperparameter combinations.
# Finished evaluating 101/1024 hyperparameter combinations.
# Finished evaluating 102/1024 hyperparameter combinations.
# Finished evaluating 103/1024 hyperparameter combinations.
# Finished evaluating 104/1024 hyperparameter combinations.
# Finished evaluating 105/1024 hyperparameter combinations.
# Finished evaluating 106/1024 hyperparameter combinations.
# Finished evaluating 107/1024 hyperparameter combinations.
# Finished evaluating 108/1024 hyperparameter combinations.
# Finished evaluating 109/1024 hyperparameter combinations.
# Finished evaluating 110/1024 hyperparameter combinations.
# Finished evaluating 111/1024 hyperparameter combinations.
# Finished evaluating 112/1024 hyperparameter combinations.
# Finished evaluating 113/1024 hyperparameter combinations.
# Finished evaluating 114/1024 hyperparameter combinations.
# Finished evaluating 115/1024 hyperparameter combinations.
# Finished evaluating 116/1024 hyperparameter combinations.
# Finished evaluating 117/1024 hyperparameter combinations.
# Finished evaluating 118/1024 hyperparameter combinations.
# Finished evaluating 119/1024 hyperparameter combinations.
# Finished evaluating 120/1024 hyperparameter combinations.
# Finished evaluating 121/1024 hyperparameter combinations.
# Finished evaluating 122/1024 hyperparameter combinations.
# Finished evaluating 123/1024 hyperparameter combinations.
# Finished evaluating 124/1024 hyperparameter combinations.
# Finished evaluating 125/1024 hyperparameter combinations.
# Finished evaluating 126/1024 hyperparameter combinations.
# Finished evaluating 127/1024 hyperparameter combinations.
# Finished evaluating 128/1024 hyperparameter combinations.
# Finished evaluating 129/1024 hyperparameter combinations.
# Finished evaluating 130/1024 hyperparameter combinations.
# Finished evaluating 131/1024 hyperparameter combinations.
# Finished evaluating 132/1024 hyperparameter combinations.
# Finished evaluating 133/1024 hyperparameter combinations.
# Finished evaluating 134/1024 hyperparameter combinations.
# Finished evaluating 135/1024 hyperparameter combinations.
# Finished evaluating 136/1024 hyperparameter combinations.
# Finished evaluating 137/1024 hyperparameter combinations.
# Finished evaluating 138/1024 hyperparameter combinations.
# Finished evaluating 139/1024 hyperparameter combinations.
# Finished evaluating 140/1024 hyperparameter combinations.
# Finished evaluating 141/1024 hyperparameter combinations.
# Finished evaluating 142/1024 hyperparameter combinations.
# Finished evaluating 143/1024 hyperparameter combinations.
# Finished evaluating 144/1024 hyperparameter combinations.
# Finished evaluating 145/1024 hyperparameter combinations.
# Finished evaluating 146/1024 hyperparameter combinations.
# Finished evaluating 147/1024 hyperparameter combinations.
# Finished evaluating 148/1024 hyperparameter combinations.
# Finished evaluating 149/1024 hyperparameter combinations.
# Finished evaluating 150/1024 hyperparameter combinations.
# Finished evaluating 151/1024 hyperparameter combinations.
# Finished evaluating 152/1024 hyperparameter combinations.
# Finished evaluating 153/1024 hyperparameter combinations.
# Finished evaluating 154/1024 hyperparameter combinations.
# Finished evaluating 155/1024 hyperparameter combinations.
# Finished evaluating 156/1024 hyperparameter combinations.
# Finished evaluating 157/1024 hyperparameter combinations.
# Finished evaluating 158/1024 hyperparameter combinations.
# Finished evaluating 159/1024 hyperparameter combinations.
# Finished evaluating 160/1024 hyperparameter combinations.
# Finished evaluating 161/1024 hyperparameter combinations.
# Finished evaluating 162/1024 hyperparameter combinations.
# Finished evaluating 163/1024 hyperparameter combinations.
# Finished evaluating 164/1024 hyperparameter combinations.
# Finished evaluating 165/1024 hyperparameter combinations.
# Finished evaluating 166/1024 hyperparameter combinations.
# Finished evaluating 167/1024 hyperparameter combinations.
# Finished evaluating 168/1024 hyperparameter combinations.
# Finished evaluating 169/1024 hyperparameter combinations.
# Finished evaluating 170/1024 hyperparameter combinations.
# Finished evaluating 171/1024 hyperparameter combinations.
# Finished evaluating 172/1024 hyperparameter combinations.
# Finished evaluating 173/1024 hyperparameter combinations.
# Finished evaluating 174/1024 hyperparameter combinations.
# Finished evaluating 175/1024 hyperparameter combinations.
# Finished evaluating 176/1024 hyperparameter combinations.
# Finished evaluating 177/1024 hyperparameter combinations.
# Finished evaluating 178/1024 hyperparameter combinations.
# Finished evaluating 179/1024 hyperparameter combinations.
# Finished evaluating 180/1024 hyperparameter combinations.
# Finished evaluating 181/1024 hyperparameter combinations.
# Finished evaluating 182/1024 hyperparameter combinations.
# Finished evaluating 183/1024 hyperparameter combinations.
# Finished evaluating 184/1024 hyperparameter combinations.
# Finished evaluating 185/1024 hyperparameter combinations.
# Finished evaluating 186/1024 hyperparameter combinations.
# Finished evaluating 187/1024 hyperparameter combinations.
# Finished evaluating 188/1024 hyperparameter combinations.
# Finished evaluating 189/1024 hyperparameter combinations.
# Finished evaluating 190/1024 hyperparameter combinations.
# Finished evaluating 191/1024 hyperparameter combinations.
# Finished evaluating 192/1024 hyperparameter combinations.
# Finished evaluating 193/1024 hyperparameter combinations.
# Finished evaluating 194/1024 hyperparameter combinations.
# Finished evaluating 195/1024 hyperparameter combinations.
# Finished evaluating 196/1024 hyperparameter combinations.
# Finished evaluating 197/1024 hyperparameter combinations.
# Finished evaluating 198/1024 hyperparameter combinations.
# Finished evaluating 199/1024 hyperparameter combinations.
# Finished evaluating 200/1024 hyperparameter combinations.
# Finished evaluating 201/1024 hyperparameter combinations.
# Finished evaluating 202/1024 hyperparameter combinations.
# Finished evaluating 203/1024 hyperparameter combinations.
# Finished evaluating 204/1024 hyperparameter combinations.
# Finished evaluating 205/1024 hyperparameter combinations.
# Finished evaluating 206/1024 hyperparameter combinations.
# Finished evaluating 207/1024 hyperparameter combinations.
# Finished evaluating 208/1024 hyperparameter combinations.
# Finished evaluating 209/1024 hyperparameter combinations.
# Finished evaluating 210/1024 hyperparameter combinations.
# Finished evaluating 211/1024 hyperparameter combinations.
# Finished evaluating 212/1024 hyperparameter combinations.
# Finished evaluating 213/1024 hyperparameter combinations.
# Finished evaluating 214/1024 hyperparameter combinations.
# Finished evaluating 215/1024 hyperparameter combinations.
# Finished evaluating 216/1024 hyperparameter combinations.
# Finished evaluating 217/1024 hyperparameter combinations.
# Finished evaluating 218/1024 hyperparameter combinations.
# Finished evaluating 219/1024 hyperparameter combinations.
# Finished evaluating 220/1024 hyperparameter combinations.
# Finished evaluating 221/1024 hyperparameter combinations.
# Finished evaluating 222/1024 hyperparameter combinations.
# Finished evaluating 223/1024 hyperparameter combinations.
# Finished evaluating 224/1024 hyperparameter combinations.
# Finished evaluating 225/1024 hyperparameter combinations.
# Finished evaluating 226/1024 hyperparameter combinations.
# Finished evaluating 227/1024 hyperparameter combinations.
# Finished evaluating 228/1024 hyperparameter combinations.
# Finished evaluating 229/1024 hyperparameter combinations.
# Finished evaluating 230/1024 hyperparameter combinations.
# Finished evaluating 231/1024 hyperparameter combinations.
# Finished evaluating 232/1024 hyperparameter combinations.
# Finished evaluating 233/1024 hyperparameter combinations.
# Finished evaluating 234/1024 hyperparameter combinations.
# Finished evaluating 235/1024 hyperparameter combinations.
# Finished evaluating 236/1024 hyperparameter combinations.
# Finished evaluating 237/1024 hyperparameter combinations.
# Finished evaluating 238/1024 hyperparameter combinations.
# Finished evaluating 239/1024 hyperparameter combinations.
# Finished evaluating 240/1024 hyperparameter combinations.
# Finished evaluating 241/1024 hyperparameter combinations.
# Finished evaluating 242/1024 hyperparameter combinations.
# Finished evaluating 243/1024 hyperparameter combinations.
# Finished evaluating 244/1024 hyperparameter combinations.
# Finished evaluating 245/1024 hyperparameter combinations.
# Finished evaluating 246/1024 hyperparameter combinations.
# Finished evaluating 247/1024 hyperparameter combinations.
# Finished evaluating 248/1024 hyperparameter combinations.
# Finished evaluating 249/1024 hyperparameter combinations.
# Finished evaluating 250/1024 hyperparameter combinations.
# Finished evaluating 251/1024 hyperparameter combinations.
# Finished evaluating 252/1024 hyperparameter combinations.
# Finished evaluating 253/1024 hyperparameter combinations.
# Finished evaluating 254/1024 hyperparameter combinations.
# Finished evaluating 255/1024 hyperparameter combinations.
# Finished evaluating 256/1024 hyperparameter combinations.
# Finished evaluating 257/1024 hyperparameter combinations.
# Finished evaluating 258/1024 hyperparameter combinations.
# Finished evaluating 259/1024 hyperparameter combinations.
# Finished evaluating 260/1024 hyperparameter combinations.
# Finished evaluating 261/1024 hyperparameter combinations.
# Finished evaluating 262/1024 hyperparameter combinations.
# Finished evaluating 263/1024 hyperparameter combinations.
# Finished evaluating 264/1024 hyperparameter combinations.
# Finished evaluating 265/1024 hyperparameter combinations.
# Finished evaluating 266/1024 hyperparameter combinations.
# Finished evaluating 267/1024 hyperparameter combinations.
# Finished evaluating 268/1024 hyperparameter combinations.
# Finished evaluating 269/1024 hyperparameter combinations.
# Finished evaluating 270/1024 hyperparameter combinations.
# Finished evaluating 271/1024 hyperparameter combinations.
# Finished evaluating 272/1024 hyperparameter combinations.
# Finished evaluating 273/1024 hyperparameter combinations.
# Finished evaluating 274/1024 hyperparameter combinations.
# Finished evaluating 275/1024 hyperparameter combinations.
# Finished evaluating 276/1024 hyperparameter combinations.
# Finished evaluating 277/1024 hyperparameter combinations.
# Finished evaluating 278/1024 hyperparameter combinations.
# Finished evaluating 279/1024 hyperparameter combinations.
# Finished evaluating 280/1024 hyperparameter combinations.
# Finished evaluating 281/1024 hyperparameter combinations.
# Finished evaluating 282/1024 hyperparameter combinations.
# Finished evaluating 283/1024 hyperparameter combinations.
# Finished evaluating 284/1024 hyperparameter combinations.
# Finished evaluating 285/1024 hyperparameter combinations.
# Finished evaluating 286/1024 hyperparameter combinations.
# Finished evaluating 287/1024 hyperparameter combinations.
# Finished evaluating 288/1024 hyperparameter combinations.
# Finished evaluating 289/1024 hyperparameter combinations.
# Finished evaluating 290/1024 hyperparameter combinations.
# Finished evaluating 291/1024 hyperparameter combinations.
# Finished evaluating 292/1024 hyperparameter combinations.
# Finished evaluating 293/1024 hyperparameter combinations.
# Finished evaluating 294/1024 hyperparameter combinations.
# Finished evaluating 295/1024 hyperparameter combinations.
# Finished evaluating 296/1024 hyperparameter combinations.
# Finished evaluating 297/1024 hyperparameter combinations.
# Finished evaluating 298/1024 hyperparameter combinations.
# Finished evaluating 299/1024 hyperparameter combinations.
# Finished evaluating 300/1024 hyperparameter combinations.
# Finished evaluating 301/1024 hyperparameter combinations.
# Finished evaluating 302/1024 hyperparameter combinations.
# Finished evaluating 303/1024 hyperparameter combinations.
# Finished evaluating 304/1024 hyperparameter combinations.
# Finished evaluating 305/1024 hyperparameter combinations.
# Finished evaluating 306/1024 hyperparameter combinations.
# Finished evaluating 307/1024 hyperparameter combinations.
# Finished evaluating 308/1024 hyperparameter combinations.
# Finished evaluating 309/1024 hyperparameter combinations.
# Finished evaluating 310/1024 hyperparameter combinations.
# Finished evaluating 311/1024 hyperparameter combinations.
# Finished evaluating 312/1024 hyperparameter combinations.
# Finished evaluating 313/1024 hyperparameter combinations.
# Finished evaluating 314/1024 hyperparameter combinations.
# Finished evaluating 315/1024 hyperparameter combinations.
# Finished evaluating 316/1024 hyperparameter combinations.
# Finished evaluating 317/1024 hyperparameter combinations.
# Finished evaluating 318/1024 hyperparameter combinations.
# Finished evaluating 319/1024 hyperparameter combinations.
# Finished evaluating 320/1024 hyperparameter combinations.
# Finished evaluating 321/1024 hyperparameter combinations.
# Finished evaluating 322/1024 hyperparameter combinations.
# Finished evaluating 323/1024 hyperparameter combinations.
# Finished evaluating 324/1024 hyperparameter combinations.
# Finished evaluating 325/1024 hyperparameter combinations.
# Finished evaluating 326/1024 hyperparameter combinations.
# Finished evaluating 327/1024 hyperparameter combinations.
# Finished evaluating 328/1024 hyperparameter combinations.
# Finished evaluating 329/1024 hyperparameter combinations.
# Finished evaluating 330/1024 hyperparameter combinations.
# Finished evaluating 331/1024 hyperparameter combinations.
# Finished evaluating 332/1024 hyperparameter combinations.
# Finished evaluating 333/1024 hyperparameter combinations.
# Finished evaluating 334/1024 hyperparameter combinations.
# Finished evaluating 335/1024 hyperparameter combinations.
# Finished evaluating 336/1024 hyperparameter combinations.
# Finished evaluating 337/1024 hyperparameter combinations.
# Finished evaluating 338/1024 hyperparameter combinations.
# Finished evaluating 339/1024 hyperparameter combinations.
# Finished evaluating 340/1024 hyperparameter combinations.
# Finished evaluating 341/1024 hyperparameter combinations.
# Finished evaluating 342/1024 hyperparameter combinations.
# Finished evaluating 343/1024 hyperparameter combinations.
# Finished evaluating 344/1024 hyperparameter combinations.
# Finished evaluating 345/1024 hyperparameter combinations.
# Finished evaluating 346/1024 hyperparameter combinations.
# Finished evaluating 347/1024 hyperparameter combinations.
# Finished evaluating 348/1024 hyperparameter combinations.
# Finished evaluating 349/1024 hyperparameter combinations.
# Finished evaluating 350/1024 hyperparameter combinations.
# Finished evaluating 351/1024 hyperparameter combinations.
# Finished evaluating 352/1024 hyperparameter combinations.
# Finished evaluating 353/1024 hyperparameter combinations.
# Finished evaluating 354/1024 hyperparameter combinations.
# Finished evaluating 355/1024 hyperparameter combinations.
# Finished evaluating 356/1024 hyperparameter combinations.
# Finished evaluating 357/1024 hyperparameter combinations.
# Finished evaluating 358/1024 hyperparameter combinations.
# Finished evaluating 359/1024 hyperparameter combinations.
# Finished evaluating 360/1024 hyperparameter combinations.
# Finished evaluating 361/1024 hyperparameter combinations.
# Finished evaluating 362/1024 hyperparameter combinations.
# Finished evaluating 363/1024 hyperparameter combinations.
# Finished evaluating 364/1024 hyperparameter combinations.
# Finished evaluating 365/1024 hyperparameter combinations.
# Finished evaluating 366/1024 hyperparameter combinations.
# Finished evaluating 367/1024 hyperparameter combinations.
# Finished evaluating 368/1024 hyperparameter combinations.
# Finished evaluating 369/1024 hyperparameter combinations.
# Finished evaluating 370/1024 hyperparameter combinations.
# Finished evaluating 371/1024 hyperparameter combinations.
# Finished evaluating 372/1024 hyperparameter combinations.
# Finished evaluating 373/1024 hyperparameter combinations.
# Finished evaluating 374/1024 hyperparameter combinations.
# Finished evaluating 375/1024 hyperparameter combinations.
# Finished evaluating 376/1024 hyperparameter combinations.
# Finished evaluating 377/1024 hyperparameter combinations.
# Finished evaluating 378/1024 hyperparameter combinations.
# Finished evaluating 379/1024 hyperparameter combinations.
# Finished evaluating 380/1024 hyperparameter combinations.
# Finished evaluating 381/1024 hyperparameter combinations.
# Finished evaluating 382/1024 hyperparameter combinations.
# Finished evaluating 383/1024 hyperparameter combinations.
# Finished evaluating 384/1024 hyperparameter combinations.
# Finished evaluating 385/1024 hyperparameter combinations.
# Finished evaluating 386/1024 hyperparameter combinations.
# Finished evaluating 387/1024 hyperparameter combinations.
# Finished evaluating 388/1024 hyperparameter combinations.
# Finished evaluating 389/1024 hyperparameter combinations.
# Finished evaluating 390/1024 hyperparameter combinations.
# Finished evaluating 391/1024 hyperparameter combinations.
# Finished evaluating 392/1024 hyperparameter combinations.
# Finished evaluating 393/1024 hyperparameter combinations.
# Finished evaluating 394/1024 hyperparameter combinations.
# Finished evaluating 395/1024 hyperparameter combinations.
# Finished evaluating 396/1024 hyperparameter combinations.
# Finished evaluating 397/1024 hyperparameter combinations.
# Finished evaluating 398/1024 hyperparameter combinations.
# Finished evaluating 399/1024 hyperparameter combinations.
# Finished evaluating 400/1024 hyperparameter combinations.
# Finished evaluating 401/1024 hyperparameter combinations.
# Finished evaluating 402/1024 hyperparameter combinations.
# Finished evaluating 403/1024 hyperparameter combinations.
# Finished evaluating 404/1024 hyperparameter combinations.
# Finished evaluating 405/1024 hyperparameter combinations.
# Finished evaluating 406/1024 hyperparameter combinations.
# Finished evaluating 407/1024 hyperparameter combinations.
# Finished evaluating 408/1024 hyperparameter combinations.
# Finished evaluating 409/1024 hyperparameter combinations.
# Finished evaluating 410/1024 hyperparameter combinations.
# Finished evaluating 411/1024 hyperparameter combinations.
# Finished evaluating 412/1024 hyperparameter combinations.
# Finished evaluating 413/1024 hyperparameter combinations.
# Finished evaluating 414/1024 hyperparameter combinations.
# Finished evaluating 415/1024 hyperparameter combinations.
# Finished evaluating 416/1024 hyperparameter combinations.
# Finished evaluating 417/1024 hyperparameter combinations.
# Finished evaluating 418/1024 hyperparameter combinations.
# Finished evaluating 419/1024 hyperparameter combinations.
# Finished evaluating 420/1024 hyperparameter combinations.
# Finished evaluating 421/1024 hyperparameter combinations.
# Finished evaluating 422/1024 hyperparameter combinations.
# Finished evaluating 423/1024 hyperparameter combinations.
# Finished evaluating 424/1024 hyperparameter combinations.
# Finished evaluating 425/1024 hyperparameter combinations.
# Finished evaluating 426/1024 hyperparameter combinations.
# Finished evaluating 427/1024 hyperparameter combinations.
# Finished evaluating 428/1024 hyperparameter combinations.
# Finished evaluating 429/1024 hyperparameter combinations.
# Finished evaluating 430/1024 hyperparameter combinations.
# Finished evaluating 431/1024 hyperparameter combinations.
# Finished evaluating 432/1024 hyperparameter combinations.
# Finished evaluating 433/1024 hyperparameter combinations.
# Finished evaluating 434/1024 hyperparameter combinations.
# Finished evaluating 435/1024 hyperparameter combinations.
# Finished evaluating 436/1024 hyperparameter combinations.
# Finished evaluating 437/1024 hyperparameter combinations.
# Finished evaluating 438/1024 hyperparameter combinations.
# Finished evaluating 439/1024 hyperparameter combinations.
# Finished evaluating 440/1024 hyperparameter combinations.
# Finished evaluating 441/1024 hyperparameter combinations.
# Finished evaluating 442/1024 hyperparameter combinations.
# Finished evaluating 443/1024 hyperparameter combinations.
# Finished evaluating 444/1024 hyperparameter combinations.
# Finished evaluating 445/1024 hyperparameter combinations.
# Finished evaluating 446/1024 hyperparameter combinations.
# Finished evaluating 447/1024 hyperparameter combinations.
# Finished evaluating 448/1024 hyperparameter combinations.
# Finished evaluating 449/1024 hyperparameter combinations.
# Finished evaluating 450/1024 hyperparameter combinations.
# Finished evaluating 451/1024 hyperparameter combinations.
# Finished evaluating 452/1024 hyperparameter combinations.
# Finished evaluating 453/1024 hyperparameter combinations.
# Finished evaluating 454/1024 hyperparameter combinations.
# Finished evaluating 455/1024 hyperparameter combinations.
# Finished evaluating 456/1024 hyperparameter combinations.
# Finished evaluating 457/1024 hyperparameter combinations.
# Finished evaluating 458/1024 hyperparameter combinations.
# Finished evaluating 459/1024 hyperparameter combinations.
# Finished evaluating 460/1024 hyperparameter combinations.
# Finished evaluating 461/1024 hyperparameter combinations.
# Finished evaluating 462/1024 hyperparameter combinations.
# Finished evaluating 463/1024 hyperparameter combinations.
# Finished evaluating 464/1024 hyperparameter combinations.
# Finished evaluating 465/1024 hyperparameter combinations.
# Finished evaluating 466/1024 hyperparameter combinations.
# Finished evaluating 467/1024 hyperparameter combinations.
# Finished evaluating 468/1024 hyperparameter combinations.
# Finished evaluating 469/1024 hyperparameter combinations.
# Finished evaluating 470/1024 hyperparameter combinations.
# Finished evaluating 471/1024 hyperparameter combinations.
# Finished evaluating 472/1024 hyperparameter combinations.
# Finished evaluating 473/1024 hyperparameter combinations.
# Finished evaluating 474/1024 hyperparameter combinations.
# Finished evaluating 475/1024 hyperparameter combinations.
# Finished evaluating 476/1024 hyperparameter combinations.
# Finished evaluating 477/1024 hyperparameter combinations.
# Finished evaluating 478/1024 hyperparameter combinations.
# Finished evaluating 479/1024 hyperparameter combinations.
# Finished evaluating 480/1024 hyperparameter combinations.
# Finished evaluating 481/1024 hyperparameter combinations.
# Finished evaluating 482/1024 hyperparameter combinations.
# Finished evaluating 483/1024 hyperparameter combinations.
# Finished evaluating 484/1024 hyperparameter combinations.
# Finished evaluating 485/1024 hyperparameter combinations.
# Finished evaluating 486/1024 hyperparameter combinations.
# Finished evaluating 487/1024 hyperparameter combinations.
# Finished evaluating 488/1024 hyperparameter combinations.
# Finished evaluating 489/1024 hyperparameter combinations.
# Finished evaluating 490/1024 hyperparameter combinations.
# Finished evaluating 491/1024 hyperparameter combinations.
# Finished evaluating 492/1024 hyperparameter combinations.
# Finished evaluating 493/1024 hyperparameter combinations.
# Finished evaluating 494/1024 hyperparameter combinations.
# Finished evaluating 495/1024 hyperparameter combinations.
# Finished evaluating 496/1024 hyperparameter combinations.
# Finished evaluating 497/1024 hyperparameter combinations.
# Finished evaluating 498/1024 hyperparameter combinations.
# Finished evaluating 499/1024 hyperparameter combinations.
# Finished evaluating 500/1024 hyperparameter combinations.
# Finished evaluating 501/1024 hyperparameter combinations.
# Finished evaluating 502/1024 hyperparameter combinations.
# Finished evaluating 503/1024 hyperparameter combinations.
# Finished evaluating 504/1024 hyperparameter combinations.
# Finished evaluating 505/1024 hyperparameter combinations.
# Finished evaluating 506/1024 hyperparameter combinations.
# Finished evaluating 507/1024 hyperparameter combinations.
# Finished evaluating 508/1024 hyperparameter combinations.
# Finished evaluating 509/1024 hyperparameter combinations.
# Finished evaluating 510/1024 hyperparameter combinations.
# Finished evaluating 511/1024 hyperparameter combinations.
# Finished evaluating 512/1024 hyperparameter combinations.
# Finished evaluating 513/1024 hyperparameter combinations.
# Finished evaluating 514/1024 hyperparameter combinations.
# Finished evaluating 515/1024 hyperparameter combinations.
# Finished evaluating 516/1024 hyperparameter combinations.
# Finished evaluating 517/1024 hyperparameter combinations.
# Finished evaluating 518/1024 hyperparameter combinations.
# Finished evaluating 519/1024 hyperparameter combinations.
# Finished evaluating 520/1024 hyperparameter combinations.
# Finished evaluating 521/1024 hyperparameter combinations.
# Finished evaluating 522/1024 hyperparameter combinations.
# Finished evaluating 523/1024 hyperparameter combinations.
# Finished evaluating 524/1024 hyperparameter combinations.
# Finished evaluating 525/1024 hyperparameter combinations.
# Finished evaluating 526/1024 hyperparameter combinations.
# Finished evaluating 527/1024 hyperparameter combinations.
# Finished evaluating 528/1024 hyperparameter combinations.
# Finished evaluating 529/1024 hyperparameter combinations.
# Finished evaluating 530/1024 hyperparameter combinations.
# Finished evaluating 531/1024 hyperparameter combinations.
# Finished evaluating 532/1024 hyperparameter combinations.
# Finished evaluating 533/1024 hyperparameter combinations.
# Finished evaluating 534/1024 hyperparameter combinations.
# Finished evaluating 535/1024 hyperparameter combinations.
# Finished evaluating 536/1024 hyperparameter combinations.
# Finished evaluating 537/1024 hyperparameter combinations.
# Finished evaluating 538/1024 hyperparameter combinations.
# Finished evaluating 539/1024 hyperparameter combinations.
# Finished evaluating 540/1024 hyperparameter combinations.
# Finished evaluating 541/1024 hyperparameter combinations.
# Finished evaluating 542/1024 hyperparameter combinations.
# Finished evaluating 543/1024 hyperparameter combinations.
# Finished evaluating 544/1024 hyperparameter combinations.
# Finished evaluating 545/1024 hyperparameter combinations.
# Finished evaluating 546/1024 hyperparameter combinations.
# Finished evaluating 547/1024 hyperparameter combinations.
# Finished evaluating 548/1024 hyperparameter combinations.
# Finished evaluating 549/1024 hyperparameter combinations.
# Finished evaluating 550/1024 hyperparameter combinations.
# Finished evaluating 551/1024 hyperparameter combinations.
# Finished evaluating 552/1024 hyperparameter combinations.
# Finished evaluating 553/1024 hyperparameter combinations.
# Finished evaluating 554/1024 hyperparameter combinations.
# Finished evaluating 555/1024 hyperparameter combinations.
# Finished evaluating 556/1024 hyperparameter combinations.
# Finished evaluating 557/1024 hyperparameter combinations.
# Finished evaluating 558/1024 hyperparameter combinations.
# Finished evaluating 559/1024 hyperparameter combinations.
# Finished evaluating 560/1024 hyperparameter combinations.
# Finished evaluating 561/1024 hyperparameter combinations.
# Finished evaluating 562/1024 hyperparameter combinations.
# Finished evaluating 563/1024 hyperparameter combinations.
# Finished evaluating 564/1024 hyperparameter combinations.
# Finished evaluating 565/1024 hyperparameter combinations.
# Finished evaluating 566/1024 hyperparameter combinations.
# Finished evaluating 567/1024 hyperparameter combinations.
# Finished evaluating 568/1024 hyperparameter combinations.
# Finished evaluating 569/1024 hyperparameter combinations.
# Finished evaluating 570/1024 hyperparameter combinations.
# Finished evaluating 571/1024 hyperparameter combinations.
# Finished evaluating 572/1024 hyperparameter combinations.
# Finished evaluating 573/1024 hyperparameter combinations.
# Finished evaluating 574/1024 hyperparameter combinations.
# Finished evaluating 575/1024 hyperparameter combinations.
# Finished evaluating 576/1024 hyperparameter combinations.
# Finished evaluating 577/1024 hyperparameter combinations.
# Finished evaluating 578/1024 hyperparameter combinations.
# Finished evaluating 579/1024 hyperparameter combinations.
# Finished evaluating 580/1024 hyperparameter combinations.
# Finished evaluating 581/1024 hyperparameter combinations.
# Finished evaluating 582/1024 hyperparameter combinations.
# Finished evaluating 583/1024 hyperparameter combinations.
# Finished evaluating 584/1024 hyperparameter combinations.
# Finished evaluating 585/1024 hyperparameter combinations.
# Finished evaluating 586/1024 hyperparameter combinations.
# Finished evaluating 587/1024 hyperparameter combinations.
# Finished evaluating 588/1024 hyperparameter combinations.
# Finished evaluating 589/1024 hyperparameter combinations.
# Finished evaluating 590/1024 hyperparameter combinations.
# Finished evaluating 591/1024 hyperparameter combinations.
# Finished evaluating 592/1024 hyperparameter combinations.
# Finished evaluating 593/1024 hyperparameter combinations.
# Finished evaluating 594/1024 hyperparameter combinations.
# Finished evaluating 595/1024 hyperparameter combinations.
# Finished evaluating 596/1024 hyperparameter combinations.
# Finished evaluating 597/1024 hyperparameter combinations.
# Finished evaluating 598/1024 hyperparameter combinations.
# Finished evaluating 599/1024 hyperparameter combinations.
# Finished evaluating 600/1024 hyperparameter combinations.
# Finished evaluating 601/1024 hyperparameter combinations.
# Finished evaluating 602/1024 hyperparameter combinations.
# Finished evaluating 603/1024 hyperparameter combinations.
# Finished evaluating 604/1024 hyperparameter combinations.
# Finished evaluating 605/1024 hyperparameter combinations.
# Finished evaluating 606/1024 hyperparameter combinations.
# Finished evaluating 607/1024 hyperparameter combinations.
# Finished evaluating 608/1024 hyperparameter combinations.
# Finished evaluating 609/1024 hyperparameter combinations.
# Finished evaluating 610/1024 hyperparameter combinations.
# Finished evaluating 611/1024 hyperparameter combinations.
# Finished evaluating 612/1024 hyperparameter combinations.
# Finished evaluating 613/1024 hyperparameter combinations.
# Finished evaluating 614/1024 hyperparameter combinations.
# Finished evaluating 615/1024 hyperparameter combinations.
# Finished evaluating 616/1024 hyperparameter combinations.
# Finished evaluating 617/1024 hyperparameter combinations.
# Finished evaluating 618/1024 hyperparameter combinations.
# Finished evaluating 619/1024 hyperparameter combinations.
# Finished evaluating 620/1024 hyperparameter combinations.
# Finished evaluating 621/1024 hyperparameter combinations.
# Finished evaluating 622/1024 hyperparameter combinations.
# Finished evaluating 623/1024 hyperparameter combinations.
# Finished evaluating 624/1024 hyperparameter combinations.
# Finished evaluating 625/1024 hyperparameter combinations.
# Finished evaluating 626/1024 hyperparameter combinations.
# Finished evaluating 627/1024 hyperparameter combinations.
# Finished evaluating 628/1024 hyperparameter combinations.
# Finished evaluating 629/1024 hyperparameter combinations.
# Finished evaluating 630/1024 hyperparameter combinations.
# Finished evaluating 631/1024 hyperparameter combinations.
# Finished evaluating 632/1024 hyperparameter combinations.
# Finished evaluating 633/1024 hyperparameter combinations.
# Finished evaluating 634/1024 hyperparameter combinations.
# Finished evaluating 635/1024 hyperparameter combinations.
# Finished evaluating 636/1024 hyperparameter combinations.
# Finished evaluating 637/1024 hyperparameter combinations.
# Finished evaluating 638/1024 hyperparameter combinations.
# Finished evaluating 639/1024 hyperparameter combinations.
# Finished evaluating 640/1024 hyperparameter combinations.
# Finished evaluating 641/1024 hyperparameter combinations.
# Finished evaluating 642/1024 hyperparameter combinations.
# Finished evaluating 643/1024 hyperparameter combinations.
# Finished evaluating 644/1024 hyperparameter combinations.
# Finished evaluating 645/1024 hyperparameter combinations.
# Finished evaluating 646/1024 hyperparameter combinations.
# Finished evaluating 647/1024 hyperparameter combinations.
# Finished evaluating 648/1024 hyperparameter combinations.
# Finished evaluating 649/1024 hyperparameter combinations.
# Finished evaluating 650/1024 hyperparameter combinations.
# Finished evaluating 651/1024 hyperparameter combinations.
# Finished evaluating 652/1024 hyperparameter combinations.
# Finished evaluating 653/1024 hyperparameter combinations.
# Finished evaluating 654/1024 hyperparameter combinations.
# Finished evaluating 655/1024 hyperparameter combinations.
# Finished evaluating 656/1024 hyperparameter combinations.
# Finished evaluating 657/1024 hyperparameter combinations.
# Finished evaluating 658/1024 hyperparameter combinations.
# Finished evaluating 659/1024 hyperparameter combinations.
# Finished evaluating 660/1024 hyperparameter combinations.
# Finished evaluating 661/1024 hyperparameter combinations.
# Finished evaluating 662/1024 hyperparameter combinations.
# Finished evaluating 663/1024 hyperparameter combinations.
# Finished evaluating 664/1024 hyperparameter combinations.
# Finished evaluating 665/1024 hyperparameter combinations.
# Finished evaluating 666/1024 hyperparameter combinations.
# Finished evaluating 667/1024 hyperparameter combinations.
# Finished evaluating 668/1024 hyperparameter combinations.
# Finished evaluating 669/1024 hyperparameter combinations.
# Finished evaluating 670/1024 hyperparameter combinations.
# Finished evaluating 671/1024 hyperparameter combinations.
# Finished evaluating 672/1024 hyperparameter combinations.
# Finished evaluating 673/1024 hyperparameter combinations.
# Finished evaluating 674/1024 hyperparameter combinations.
# Finished evaluating 675/1024 hyperparameter combinations.
# Finished evaluating 676/1024 hyperparameter combinations.
# Finished evaluating 677/1024 hyperparameter combinations.
# Finished evaluating 678/1024 hyperparameter combinations.
# Finished evaluating 679/1024 hyperparameter combinations.
# Finished evaluating 680/1024 hyperparameter combinations.
# Finished evaluating 681/1024 hyperparameter combinations.
# Finished evaluating 682/1024 hyperparameter combinations.
# Finished evaluating 683/1024 hyperparameter combinations.
# Finished evaluating 684/1024 hyperparameter combinations.
# Finished evaluating 685/1024 hyperparameter combinations.
# Finished evaluating 686/1024 hyperparameter combinations.
# Finished evaluating 687/1024 hyperparameter combinations.
# Finished evaluating 688/1024 hyperparameter combinations.
# Finished evaluating 689/1024 hyperparameter combinations.
# Finished evaluating 690/1024 hyperparameter combinations.
# Finished evaluating 691/1024 hyperparameter combinations.
# Finished evaluating 692/1024 hyperparameter combinations.
# Finished evaluating 693/1024 hyperparameter combinations.
# Finished evaluating 694/1024 hyperparameter combinations.
# Finished evaluating 695/1024 hyperparameter combinations.
# Finished evaluating 696/1024 hyperparameter combinations.
# Finished evaluating 697/1024 hyperparameter combinations.
# Finished evaluating 698/1024 hyperparameter combinations.
# Finished evaluating 699/1024 hyperparameter combinations.
# Finished evaluating 700/1024 hyperparameter combinations.
# Finished evaluating 701/1024 hyperparameter combinations.
# Finished evaluating 702/1024 hyperparameter combinations.
# Finished evaluating 703/1024 hyperparameter combinations.
# Finished evaluating 704/1024 hyperparameter combinations.
# Finished evaluating 705/1024 hyperparameter combinations.
# Finished evaluating 706/1024 hyperparameter combinations.
# Finished evaluating 707/1024 hyperparameter combinations.
# Finished evaluating 708/1024 hyperparameter combinations.
# Finished evaluating 709/1024 hyperparameter combinations.
# Finished evaluating 710/1024 hyperparameter combinations.
# Finished evaluating 711/1024 hyperparameter combinations.
# Finished evaluating 712/1024 hyperparameter combinations.
# Finished evaluating 713/1024 hyperparameter combinations.
# Finished evaluating 714/1024 hyperparameter combinations.
# Finished evaluating 715/1024 hyperparameter combinations.
# Finished evaluating 716/1024 hyperparameter combinations.
# Finished evaluating 717/1024 hyperparameter combinations.
# Finished evaluating 718/1024 hyperparameter combinations.
# Finished evaluating 719/1024 hyperparameter combinations.
# Finished evaluating 720/1024 hyperparameter combinations.
# Finished evaluating 721/1024 hyperparameter combinations.
# Finished evaluating 722/1024 hyperparameter combinations.
# Finished evaluating 723/1024 hyperparameter combinations.
# Finished evaluating 724/1024 hyperparameter combinations.
# Finished evaluating 725/1024 hyperparameter combinations.
# Finished evaluating 726/1024 hyperparameter combinations.
# Finished evaluating 727/1024 hyperparameter combinations.
# Finished evaluating 728/1024 hyperparameter combinations.
# Finished evaluating 729/1024 hyperparameter combinations.
# Finished evaluating 730/1024 hyperparameter combinations.
# Finished evaluating 731/1024 hyperparameter combinations.
# Finished evaluating 732/1024 hyperparameter combinations.
# Finished evaluating 733/1024 hyperparameter combinations.
# Finished evaluating 734/1024 hyperparameter combinations.
# Finished evaluating 735/1024 hyperparameter combinations.
# Finished evaluating 736/1024 hyperparameter combinations.
# Finished evaluating 737/1024 hyperparameter combinations.
# Finished evaluating 738/1024 hyperparameter combinations.
# Finished evaluating 739/1024 hyperparameter combinations.
# Finished evaluating 740/1024 hyperparameter combinations.
# Finished evaluating 741/1024 hyperparameter combinations.
# Finished evaluating 742/1024 hyperparameter combinations.
# Finished evaluating 743/1024 hyperparameter combinations.
# Finished evaluating 744/1024 hyperparameter combinations.
# Finished evaluating 745/1024 hyperparameter combinations.
# Finished evaluating 746/1024 hyperparameter combinations.
# Finished evaluating 747/1024 hyperparameter combinations.
# Finished evaluating 748/1024 hyperparameter combinations.
# Finished evaluating 749/1024 hyperparameter combinations.
# Finished evaluating 750/1024 hyperparameter combinations.
# Finished evaluating 751/1024 hyperparameter combinations.
# Finished evaluating 752/1024 hyperparameter combinations.
# Finished evaluating 753/1024 hyperparameter combinations.
# Finished evaluating 754/1024 hyperparameter combinations.
# Finished evaluating 755/1024 hyperparameter combinations.
# Finished evaluating 756/1024 hyperparameter combinations.
# Finished evaluating 757/1024 hyperparameter combinations.
# Finished evaluating 758/1024 hyperparameter combinations.
# Finished evaluating 759/1024 hyperparameter combinations.
# Finished evaluating 760/1024 hyperparameter combinations.
# Finished evaluating 761/1024 hyperparameter combinations.
# Finished evaluating 762/1024 hyperparameter combinations.
# Finished evaluating 763/1024 hyperparameter combinations.
# Finished evaluating 764/1024 hyperparameter combinations.
# Finished evaluating 765/1024 hyperparameter combinations.
# Finished evaluating 766/1024 hyperparameter combinations.
# Finished evaluating 767/1024 hyperparameter combinations.
# Finished evaluating 768/1024 hyperparameter combinations.
# Finished evaluating 769/1024 hyperparameter combinations.
# Finished evaluating 770/1024 hyperparameter combinations.
# Finished evaluating 771/1024 hyperparameter combinations.
# Finished evaluating 772/1024 hyperparameter combinations.
# Finished evaluating 773/1024 hyperparameter combinations.
# Finished evaluating 774/1024 hyperparameter combinations.
# Finished evaluating 775/1024 hyperparameter combinations.
# Finished evaluating 776/1024 hyperparameter combinations.
# Finished evaluating 777/1024 hyperparameter combinations.
# Finished evaluating 778/1024 hyperparameter combinations.
# Finished evaluating 779/1024 hyperparameter combinations.
# Finished evaluating 780/1024 hyperparameter combinations.
# Finished evaluating 781/1024 hyperparameter combinations.
# Finished evaluating 782/1024 hyperparameter combinations.
# Finished evaluating 783/1024 hyperparameter combinations.
# Finished evaluating 784/1024 hyperparameter combinations.
# Finished evaluating 785/1024 hyperparameter combinations.
# Finished evaluating 786/1024 hyperparameter combinations.
# Finished evaluating 787/1024 hyperparameter combinations.
# Finished evaluating 788/1024 hyperparameter combinations.
# Finished evaluating 789/1024 hyperparameter combinations.
# Finished evaluating 790/1024 hyperparameter combinations.
# Finished evaluating 791/1024 hyperparameter combinations.
# Finished evaluating 792/1024 hyperparameter combinations.
# Finished evaluating 793/1024 hyperparameter combinations.
# Finished evaluating 794/1024 hyperparameter combinations.
# Finished evaluating 795/1024 hyperparameter combinations.
# Finished evaluating 796/1024 hyperparameter combinations.
# Finished evaluating 797/1024 hyperparameter combinations.
# Finished evaluating 798/1024 hyperparameter combinations.
# Finished evaluating 799/1024 hyperparameter combinations.
# Finished evaluating 800/1024 hyperparameter combinations.
# Finished evaluating 801/1024 hyperparameter combinations.
# Finished evaluating 802/1024 hyperparameter combinations.
# Finished evaluating 803/1024 hyperparameter combinations.
# Finished evaluating 804/1024 hyperparameter combinations.
# Finished evaluating 805/1024 hyperparameter combinations.
# Finished evaluating 806/1024 hyperparameter combinations.
# Finished evaluating 807/1024 hyperparameter combinations.
# Finished evaluating 808/1024 hyperparameter combinations.
# Finished evaluating 809/1024 hyperparameter combinations.
# Finished evaluating 810/1024 hyperparameter combinations.
# Finished evaluating 811/1024 hyperparameter combinations.
# Finished evaluating 812/1024 hyperparameter combinations.
# Finished evaluating 813/1024 hyperparameter combinations.
# Finished evaluating 814/1024 hyperparameter combinations.
# Finished evaluating 815/1024 hyperparameter combinations.
# Finished evaluating 816/1024 hyperparameter combinations.
# Finished evaluating 817/1024 hyperparameter combinations.
# Finished evaluating 818/1024 hyperparameter combinations.
# Finished evaluating 819/1024 hyperparameter combinations.
# Finished evaluating 820/1024 hyperparameter combinations.
# Finished evaluating 821/1024 hyperparameter combinations.
# Finished evaluating 822/1024 hyperparameter combinations.
# Finished evaluating 823/1024 hyperparameter combinations.
# Finished evaluating 824/1024 hyperparameter combinations.
# Finished evaluating 825/1024 hyperparameter combinations.
# Finished evaluating 826/1024 hyperparameter combinations.
# Finished evaluating 827/1024 hyperparameter combinations.
# Finished evaluating 828/1024 hyperparameter combinations.
# Finished evaluating 829/1024 hyperparameter combinations.
# Finished evaluating 830/1024 hyperparameter combinations.
# Finished evaluating 831/1024 hyperparameter combinations.
# Finished evaluating 832/1024 hyperparameter combinations.
# Finished evaluating 833/1024 hyperparameter combinations.
# Finished evaluating 834/1024 hyperparameter combinations.
# Finished evaluating 835/1024 hyperparameter combinations.
# Finished evaluating 836/1024 hyperparameter combinations.
# Finished evaluating 837/1024 hyperparameter combinations.
# Finished evaluating 838/1024 hyperparameter combinations.
# Finished evaluating 839/1024 hyperparameter combinations.
# Finished evaluating 840/1024 hyperparameter combinations.
# Finished evaluating 841/1024 hyperparameter combinations.
# Finished evaluating 842/1024 hyperparameter combinations.
# Finished evaluating 843/1024 hyperparameter combinations.
# Finished evaluating 844/1024 hyperparameter combinations.
# Finished evaluating 845/1024 hyperparameter combinations.
# Finished evaluating 846/1024 hyperparameter combinations.
# Finished evaluating 847/1024 hyperparameter combinations.
# Finished evaluating 848/1024 hyperparameter combinations.
# Finished evaluating 849/1024 hyperparameter combinations.
# Finished evaluating 850/1024 hyperparameter combinations.
# Finished evaluating 851/1024 hyperparameter combinations.
# Finished evaluating 852/1024 hyperparameter combinations.
# Finished evaluating 853/1024 hyperparameter combinations.
# Finished evaluating 854/1024 hyperparameter combinations.
# Finished evaluating 855/1024 hyperparameter combinations.
# Finished evaluating 856/1024 hyperparameter combinations.
# Finished evaluating 857/1024 hyperparameter combinations.
# Finished evaluating 858/1024 hyperparameter combinations.
# Finished evaluating 859/1024 hyperparameter combinations.
# Finished evaluating 860/1024 hyperparameter combinations.
# Finished evaluating 861/1024 hyperparameter combinations.
# Finished evaluating 862/1024 hyperparameter combinations.
# Finished evaluating 863/1024 hyperparameter combinations.
# Finished evaluating 864/1024 hyperparameter combinations.
# Finished evaluating 865/1024 hyperparameter combinations.
# Finished evaluating 866/1024 hyperparameter combinations.
# Finished evaluating 867/1024 hyperparameter combinations.
# Finished evaluating 868/1024 hyperparameter combinations.
# Finished evaluating 869/1024 hyperparameter combinations.
# Finished evaluating 870/1024 hyperparameter combinations.
# Finished evaluating 871/1024 hyperparameter combinations.
# Finished evaluating 872/1024 hyperparameter combinations.
# Finished evaluating 873/1024 hyperparameter combinations.
# Finished evaluating 874/1024 hyperparameter combinations.
# Finished evaluating 875/1024 hyperparameter combinations.
# Finished evaluating 876/1024 hyperparameter combinations.
# Finished evaluating 877/1024 hyperparameter combinations.
# Finished evaluating 878/1024 hyperparameter combinations.
# Finished evaluating 879/1024 hyperparameter combinations.
# Finished evaluating 880/1024 hyperparameter combinations.
# Finished evaluating 881/1024 hyperparameter combinations.
# Finished evaluating 882/1024 hyperparameter combinations.
# Finished evaluating 883/1024 hyperparameter combinations.
# Finished evaluating 884/1024 hyperparameter combinations.
# Finished evaluating 885/1024 hyperparameter combinations.
# Finished evaluating 886/1024 hyperparameter combinations.
# Finished evaluating 887/1024 hyperparameter combinations.
# Finished evaluating 888/1024 hyperparameter combinations.
# Finished evaluating 889/1024 hyperparameter combinations.
# Finished evaluating 890/1024 hyperparameter combinations.
# Finished evaluating 891/1024 hyperparameter combinations.
# Finished evaluating 892/1024 hyperparameter combinations.
# Finished evaluating 893/1024 hyperparameter combinations.
# Finished evaluating 894/1024 hyperparameter combinations.
# Finished evaluating 895/1024 hyperparameter combinations.
# Finished evaluating 896/1024 hyperparameter combinations.
# Finished evaluating 897/1024 hyperparameter combinations.
# Finished evaluating 898/1024 hyperparameter combinations.
# Finished evaluating 899/1024 hyperparameter combinations.
# Finished evaluating 900/1024 hyperparameter combinations.
# Finished evaluating 901/1024 hyperparameter combinations.
# Finished evaluating 902/1024 hyperparameter combinations.
# Finished evaluating 903/1024 hyperparameter combinations.
# Finished evaluating 904/1024 hyperparameter combinations.
# Finished evaluating 905/1024 hyperparameter combinations.
# Finished evaluating 906/1024 hyperparameter combinations.
# Finished evaluating 907/1024 hyperparameter combinations.
# Finished evaluating 908/1024 hyperparameter combinations.
# Finished evaluating 909/1024 hyperparameter combinations.
# Finished evaluating 910/1024 hyperparameter combinations.
# Finished evaluating 911/1024 hyperparameter combinations.
# Finished evaluating 912/1024 hyperparameter combinations.
# Finished evaluating 913/1024 hyperparameter combinations.
# Finished evaluating 914/1024 hyperparameter combinations.
# Finished evaluating 915/1024 hyperparameter combinations.
# Finished evaluating 916/1024 hyperparameter combinations.
# Finished evaluating 917/1024 hyperparameter combinations.
# Finished evaluating 918/1024 hyperparameter combinations.
# Finished evaluating 919/1024 hyperparameter combinations.
# Finished evaluating 920/1024 hyperparameter combinations.
# Finished evaluating 921/1024 hyperparameter combinations.
# Finished evaluating 922/1024 hyperparameter combinations.
# Finished evaluating 923/1024 hyperparameter combinations.
# Finished evaluating 924/1024 hyperparameter combinations.
# Finished evaluating 925/1024 hyperparameter combinations.
# Finished evaluating 926/1024 hyperparameter combinations.
# Finished evaluating 927/1024 hyperparameter combinations.
# Finished evaluating 928/1024 hyperparameter combinations.
# Finished evaluating 929/1024 hyperparameter combinations.
# Finished evaluating 930/1024 hyperparameter combinations.
# Finished evaluating 931/1024 hyperparameter combinations.
# Finished evaluating 932/1024 hyperparameter combinations.
# Finished evaluating 933/1024 hyperparameter combinations.
# Finished evaluating 934/1024 hyperparameter combinations.
# Finished evaluating 935/1024 hyperparameter combinations.
# Finished evaluating 936/1024 hyperparameter combinations.
# Finished evaluating 937/1024 hyperparameter combinations.
# Finished evaluating 938/1024 hyperparameter combinations.
# Finished evaluating 939/1024 hyperparameter combinations.
# Finished evaluating 940/1024 hyperparameter combinations.
# Finished evaluating 941/1024 hyperparameter combinations.
# Finished evaluating 942/1024 hyperparameter combinations.
# Finished evaluating 943/1024 hyperparameter combinations.
# Finished evaluating 944/1024 hyperparameter combinations.
# Finished evaluating 945/1024 hyperparameter combinations.
# Finished evaluating 946/1024 hyperparameter combinations.
# Finished evaluating 947/1024 hyperparameter combinations.
# Finished evaluating 948/1024 hyperparameter combinations.
# Finished evaluating 949/1024 hyperparameter combinations.
# Finished evaluating 950/1024 hyperparameter combinations.
# Finished evaluating 951/1024 hyperparameter combinations.
# Finished evaluating 952/1024 hyperparameter combinations.
# Finished evaluating 953/1024 hyperparameter combinations.
# Finished evaluating 954/1024 hyperparameter combinations.
# Finished evaluating 955/1024 hyperparameter combinations.
# Finished evaluating 956/1024 hyperparameter combinations.
# Finished evaluating 957/1024 hyperparameter combinations.
# Finished evaluating 958/1024 hyperparameter combinations.
# Finished evaluating 959/1024 hyperparameter combinations.
# Finished evaluating 960/1024 hyperparameter combinations.
# Finished evaluating 961/1024 hyperparameter combinations.
# Finished evaluating 962/1024 hyperparameter combinations.
# Finished evaluating 963/1024 hyperparameter combinations.
# Finished evaluating 964/1024 hyperparameter combinations.
# Finished evaluating 965/1024 hyperparameter combinations.
# Finished evaluating 966/1024 hyperparameter combinations.
# Finished evaluating 967/1024 hyperparameter combinations.
# Finished evaluating 968/1024 hyperparameter combinations.
# Finished evaluating 969/1024 hyperparameter combinations.
# Finished evaluating 970/1024 hyperparameter combinations.
# Finished evaluating 971/1024 hyperparameter combinations.
# Finished evaluating 972/1024 hyperparameter combinations.
# Finished evaluating 973/1024 hyperparameter combinations.
# Finished evaluating 974/1024 hyperparameter combinations.
# Finished evaluating 975/1024 hyperparameter combinations.
# Finished evaluating 976/1024 hyperparameter combinations.
# Finished evaluating 977/1024 hyperparameter combinations.
# Finished evaluating 978/1024 hyperparameter combinations.
# Finished evaluating 979/1024 hyperparameter combinations.
# Finished evaluating 980/1024 hyperparameter combinations.
# Finished evaluating 981/1024 hyperparameter combinations.
# Finished evaluating 982/1024 hyperparameter combinations.
# Finished evaluating 983/1024 hyperparameter combinations.
# Finished evaluating 984/1024 hyperparameter combinations.
# Finished evaluating 985/1024 hyperparameter combinations.
# Finished evaluating 986/1024 hyperparameter combinations.
# Finished evaluating 987/1024 hyperparameter combinations.
# Finished evaluating 988/1024 hyperparameter combinations.
# Finished evaluating 989/1024 hyperparameter combinations.
# Finished evaluating 990/1024 hyperparameter combinations.
# Finished evaluating 991/1024 hyperparameter combinations.
# Finished evaluating 992/1024 hyperparameter combinations.
# Finished evaluating 993/1024 hyperparameter combinations.
# Finished evaluating 994/1024 hyperparameter combinations.
# Finished evaluating 995/1024 hyperparameter combinations.
# Finished evaluating 996/1024 hyperparameter combinations.
# Finished evaluating 997/1024 hyperparameter combinations.
# Finished evaluating 998/1024 hyperparameter combinations.
# Finished evaluating 999/1024 hyperparameter combinations.
# Finished evaluating 1000/1024 hyperparameter combinations.
# Finished evaluating 1001/1024 hyperparameter combinations.
# Finished evaluating 1002/1024 hyperparameter combinations.
# Finished evaluating 1003/1024 hyperparameter combinations.
# Finished evaluating 1004/1024 hyperparameter combinations.
# Finished evaluating 1005/1024 hyperparameter combinations.
# Finished evaluating 1006/1024 hyperparameter combinations.
# Finished evaluating 1007/1024 hyperparameter combinations.
# Finished evaluating 1008/1024 hyperparameter combinations.
# Finished evaluating 1009/1024 hyperparameter combinations.
# Finished evaluating 1010/1024 hyperparameter combinations.
# Finished evaluating 1011/1024 hyperparameter combinations.
# Finished evaluating 1012/1024 hyperparameter combinations.
# Finished evaluating 1013/1024 hyperparameter combinations.
# Finished evaluating 1014/1024 hyperparameter combinations.
# Finished evaluating 1015/1024 hyperparameter combinations.
# Finished evaluating 1016/1024 hyperparameter combinations.
# Finished evaluating 1017/1024 hyperparameter combinations.
# Finished evaluating 1018/1024 hyperparameter combinations.
# Finished evaluating 1019/1024 hyperparameter combinations.
# Finished evaluating 1020/1024 hyperparameter combinations.
# Finished evaluating 1021/1024 hyperparameter combinations.
# Finished evaluating 1022/1024 hyperparameter combinations.
# Finished evaluating 1023/1024 hyperparameter combinations.
# Finished evaluating 1024/1024 hyperparameter combinations.
# Elapsed time in sec:  973.3379423750002

# %%
print('Using only physical features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_xgb_self, param_xgb_self))
# Out:
# Using only physical features, the best CV score during hyper-parameter search is 0.7339814814073162, while the selected hyper-parameters are: {'UniSlct__percentile': 80, 'est__gamma': 1e-08, 'est__learning_rate': 1e-07, 'est__max_depth': 30, 'est__reg_lambda': 0.01}

# %% [markdown]
# ## 3. Estimator = Logistic Regression

# %% [markdown]
# ### Using all features

# %%
rng = np.random.RandomState(0)

lg_param_grid = {
 "UniSlct__percentile" : [5, 10, 25, 50, 75],
    "est__penalty": ['l1', 'l2'],
    "est__C": [1e-4, 1e-3, 1e-2, 1e-1, 1]
}

lg_estimator = LogisticRegression(max_iter = 500, solver = 'liblinear', random_state = rng)

lg_steps = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", lg_estimator)
]

lg_clf_pl = Pipeline(steps = lg_steps)

start_time_lg = time.perf_counter()
cv_table_lg,score_lg, std_lg,param_lg,pipeline_lg = cv_evaluation(lg_clf_pl, lg_param_grid, X_train_spatial, y_train, X_cv_train_spatial_lst,y_cv_train_lst,X_cv_val_spatial_lst,y_cv_val_lst)
end_time_lg = time.perf_counter()
elapsed_time_lg = end_time_lg - start_time_lg
print("Elapsed time in sec: ", elapsed_time_lg)
# Out:
# Finished evaluating 1/50 hyperparameter combinations.
# Finished evaluating 2/50 hyperparameter combinations.
# Finished evaluating 3/50 hyperparameter combinations.
# Finished evaluating 4/50 hyperparameter combinations.
# Finished evaluating 5/50 hyperparameter combinations.
# Finished evaluating 6/50 hyperparameter combinations.
# Finished evaluating 7/50 hyperparameter combinations.
# Finished evaluating 8/50 hyperparameter combinations.
# Finished evaluating 9/50 hyperparameter combinations.
# Finished evaluating 10/50 hyperparameter combinations.
# Finished evaluating 11/50 hyperparameter combinations.
# Finished evaluating 12/50 hyperparameter combinations.
# Finished evaluating 13/50 hyperparameter combinations.
# Finished evaluating 14/50 hyperparameter combinations.
# Finished evaluating 15/50 hyperparameter combinations.
# Finished evaluating 16/50 hyperparameter combinations.
# Finished evaluating 17/50 hyperparameter combinations.
# Finished evaluating 18/50 hyperparameter combinations.
# Finished evaluating 19/50 hyperparameter combinations.
# Finished evaluating 20/50 hyperparameter combinations.
# Finished evaluating 21/50 hyperparameter combinations.
# Finished evaluating 22/50 hyperparameter combinations.
# Finished evaluating 23/50 hyperparameter combinations.
# Finished evaluating 24/50 hyperparameter combinations.
# Finished evaluating 25/50 hyperparameter combinations.
# Finished evaluating 26/50 hyperparameter combinations.
# Finished evaluating 27/50 hyperparameter combinations.
# Finished evaluating 28/50 hyperparameter combinations.
# Finished evaluating 29/50 hyperparameter combinations.
# Finished evaluating 30/50 hyperparameter combinations.
# Finished evaluating 31/50 hyperparameter combinations.
# Finished evaluating 32/50 hyperparameter combinations.
# Finished evaluating 33/50 hyperparameter combinations.
# Finished evaluating 34/50 hyperparameter combinations.
# Finished evaluating 35/50 hyperparameter combinations.
# Finished evaluating 36/50 hyperparameter combinations.
# Finished evaluating 37/50 hyperparameter combinations.
# Finished evaluating 38/50 hyperparameter combinations.
# Finished evaluating 39/50 hyperparameter combinations.
# Finished evaluating 40/50 hyperparameter combinations.
# Finished evaluating 41/50 hyperparameter combinations.
# Finished evaluating 42/50 hyperparameter combinations.
# Finished evaluating 43/50 hyperparameter combinations.
# Finished evaluating 44/50 hyperparameter combinations.
# Finished evaluating 45/50 hyperparameter combinations.
# Finished evaluating 46/50 hyperparameter combinations.
# Finished evaluating 47/50 hyperparameter combinations.
# Finished evaluating 48/50 hyperparameter combinations.
# Finished evaluating 49/50 hyperparameter combinations.
# Finished evaluating 50/50 hyperparameter combinations.
# Elapsed time in sec:  7.43006966700068

# %%
print('Using physical and geospatial features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_lg, param_lg))
# Out:
# Using physical and geospatial features, the best CV score during hyper-parameter search is 0.7382648771596221, while the selected hyper-parameters are: {'UniSlct__percentile': 25, 'est__C': 0.01, 'est__penalty': 'l2'}

# %% [markdown]
# ### Excluding geospatial features

# %%
rng = np.random.RandomState(0)

lg_param_grid_self = {
 "UniSlct__percentile" : [5, 10, 25, 50, 75],
    "est__penalty": ['l1', 'l2'],
    "est__C": [1e-3, 1e-2, 1e-1, 1, 10]
}

lg_estimator_self = LogisticRegression(max_iter = 500, solver = 'liblinear', random_state = rng)

lg_steps_self = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", lg_estimator_self)
]

lg_clf_pl_self = Pipeline(steps = lg_steps_self)

start_time_lg_self = time.perf_counter()
cv_table_lg_self, score_lg_self, std_lg_self,param_lg_self,pipeline_lg_self = cv_evaluation(lg_clf_pl_self, lg_param_grid_self, X_train_self, y_train, X_cv_train_self_lst,y_cv_train_lst,X_cv_val_self_lst,y_cv_val_lst)
end_time_lg_self = time.perf_counter()
elapsed_time_lg_self = end_time_lg_self - start_time_lg_self
print("Elapsed time in sec: ", elapsed_time_lg_self)
# Out:
# Finished evaluating 1/50 hyperparameter combinations.
# Finished evaluating 2/50 hyperparameter combinations.
# Finished evaluating 3/50 hyperparameter combinations.
# Finished evaluating 4/50 hyperparameter combinations.
# Finished evaluating 5/50 hyperparameter combinations.
# Finished evaluating 6/50 hyperparameter combinations.
# Finished evaluating 7/50 hyperparameter combinations.
# Finished evaluating 8/50 hyperparameter combinations.
# Finished evaluating 9/50 hyperparameter combinations.
# Finished evaluating 10/50 hyperparameter combinations.
# Finished evaluating 11/50 hyperparameter combinations.
# Finished evaluating 12/50 hyperparameter combinations.
# Finished evaluating 13/50 hyperparameter combinations.
# Finished evaluating 14/50 hyperparameter combinations.
# Finished evaluating 15/50 hyperparameter combinations.
# Finished evaluating 16/50 hyperparameter combinations.
# Finished evaluating 17/50 hyperparameter combinations.
# Finished evaluating 18/50 hyperparameter combinations.
# Finished evaluating 19/50 hyperparameter combinations.
# Finished evaluating 20/50 hyperparameter combinations.
# Finished evaluating 21/50 hyperparameter combinations.
# Finished evaluating 22/50 hyperparameter combinations.
# Finished evaluating 23/50 hyperparameter combinations.
# Finished evaluating 24/50 hyperparameter combinations.
# Finished evaluating 25/50 hyperparameter combinations.
# Finished evaluating 26/50 hyperparameter combinations.
# Finished evaluating 27/50 hyperparameter combinations.
# Finished evaluating 28/50 hyperparameter combinations.
# Finished evaluating 29/50 hyperparameter combinations.
# Finished evaluating 30/50 hyperparameter combinations.
# Finished evaluating 31/50 hyperparameter combinations.
# Finished evaluating 32/50 hyperparameter combinations.
# Finished evaluating 33/50 hyperparameter combinations.
# Finished evaluating 34/50 hyperparameter combinations.
# Finished evaluating 35/50 hyperparameter combinations.
# Finished evaluating 36/50 hyperparameter combinations.
# Finished evaluating 37/50 hyperparameter combinations.
# Finished evaluating 38/50 hyperparameter combinations.
# Finished evaluating 39/50 hyperparameter combinations.
# Finished evaluating 40/50 hyperparameter combinations.
# Finished evaluating 41/50 hyperparameter combinations.
# Finished evaluating 42/50 hyperparameter combinations.
# Finished evaluating 43/50 hyperparameter combinations.
# Finished evaluating 44/50 hyperparameter combinations.
# Finished evaluating 45/50 hyperparameter combinations.
# Finished evaluating 46/50 hyperparameter combinations.
# Finished evaluating 47/50 hyperparameter combinations.
# Finished evaluating 48/50 hyperparameter combinations.
# Finished evaluating 49/50 hyperparameter combinations.
# Finished evaluating 50/50 hyperparameter combinations.
# Elapsed time in sec:  10.05405758300003

# %%
print('Using only physical features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_lg_self, param_lg_self))
# Out:
# Using only physical features, the best CV score during hyper-parameter search is 0.6932023215746083, while the selected hyper-parameters are: {'UniSlct__percentile': 50, 'est__C': 0.001, 'est__penalty': 'l2'}

# %% [markdown]
# ## 4. Estimator = Logistic Regression with Interaction Terms

# %% [markdown]
# ### Using all features

# %%
rng = np.random.RandomState(0)

lgp_estimator = LogisticRegression(max_iter = 500, solver = 'liblinear', random_state = rng)

lgp_steps = [
     ("pre", create_preprocessor()),
     ('poly', PolynomialFeatures(degree = 2)),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectKBest(f_classif)),
     ("est", lgp_estimator)
]

lgp_param_grid = [{
 "UniSlct__k" : [10, 50, 100, 500],
    "est__penalty": ['l1', 'l2'],
    "est__C": [1e-4,1e-2, 1e0,1e2, 1e4]

},{
 "UniSlct__k" : [500, 1000,3000,5000,7000],
    "est__penalty": ['l1', 'l2'],
    "est__C": [1e-8,1e-6,1e-4,1e-2]

}]

lgp_clf_pl = Pipeline(steps = lgp_steps)

start_time_lgp = time.perf_counter()
cv_table_lgp, score_lgp, std_lgp,param_lgp,pipeline_lgp = cv_evaluation(lgp_clf_pl, lgp_param_grid, X_train_spatial, y_train, X_cv_train_spatial_lst,y_cv_train_lst,X_cv_val_spatial_lst,y_cv_val_lst)
end_time_lgp = time.perf_counter()
elapsed_time_lgp = end_time_lgp - start_time_lgp
print("Elapsed time in sec: ", elapsed_time_lgp)
# Out:
# Finished evaluating 1/80 hyperparameter combinations.
# Finished evaluating 2/80 hyperparameter combinations.
# Finished evaluating 3/80 hyperparameter combinations.
# Finished evaluating 4/80 hyperparameter combinations.
# Finished evaluating 5/80 hyperparameter combinations.
# Finished evaluating 6/80 hyperparameter combinations.
# Finished evaluating 7/80 hyperparameter combinations.
# Finished evaluating 8/80 hyperparameter combinations.
# Finished evaluating 9/80 hyperparameter combinations.
# Finished evaluating 10/80 hyperparameter combinations.
# Finished evaluating 11/80 hyperparameter combinations.
# Finished evaluating 12/80 hyperparameter combinations.
# Finished evaluating 13/80 hyperparameter combinations.
# Finished evaluating 14/80 hyperparameter combinations.
# Finished evaluating 15/80 hyperparameter combinations.
# Finished evaluating 16/80 hyperparameter combinations.
# Finished evaluating 17/80 hyperparameter combinations.
# Finished evaluating 18/80 hyperparameter combinations.
# Finished evaluating 19/80 hyperparameter combinations.
# Finished evaluating 20/80 hyperparameter combinations.
# Finished evaluating 21/80 hyperparameter combinations.
# Finished evaluating 22/80 hyperparameter combinations.
# Finished evaluating 23/80 hyperparameter combinations.
# Finished evaluating 24/80 hyperparameter combinations.
# Finished evaluating 25/80 hyperparameter combinations.
# Finished evaluating 26/80 hyperparameter combinations.
# Finished evaluating 27/80 hyperparameter combinations.
# Finished evaluating 28/80 hyperparameter combinations.
# Finished evaluating 29/80 hyperparameter combinations.
# Finished evaluating 30/80 hyperparameter combinations.
# Finished evaluating 31/80 hyperparameter combinations.
# Finished evaluating 32/80 hyperparameter combinations.
# Finished evaluating 33/80 hyperparameter combinations.
# Finished evaluating 34/80 hyperparameter combinations.
# Finished evaluating 35/80 hyperparameter combinations.
# Finished evaluating 36/80 hyperparameter combinations.
# Finished evaluating 37/80 hyperparameter combinations.
# Finished evaluating 38/80 hyperparameter combinations.
# Finished evaluating 39/80 hyperparameter combinations.
# Finished evaluating 40/80 hyperparameter combinations.
# Finished evaluating 41/80 hyperparameter combinations.
# Finished evaluating 42/80 hyperparameter combinations.
# Finished evaluating 43/80 hyperparameter combinations.
# Finished evaluating 44/80 hyperparameter combinations.
# Finished evaluating 45/80 hyperparameter combinations.
# Finished evaluating 46/80 hyperparameter combinations.
# Finished evaluating 47/80 hyperparameter combinations.
# Finished evaluating 48/80 hyperparameter combinations.
# Finished evaluating 49/80 hyperparameter combinations.
# Finished evaluating 50/80 hyperparameter combinations.
# Finished evaluating 51/80 hyperparameter combinations.
# Finished evaluating 52/80 hyperparameter combinations.
# Finished evaluating 53/80 hyperparameter combinations.
# Finished evaluating 54/80 hyperparameter combinations.
# Finished evaluating 55/80 hyperparameter combinations.
# Finished evaluating 56/80 hyperparameter combinations.
# Finished evaluating 57/80 hyperparameter combinations.
# Finished evaluating 58/80 hyperparameter combinations.
# Finished evaluating 59/80 hyperparameter combinations.
# Finished evaluating 60/80 hyperparameter combinations.
# Finished evaluating 61/80 hyperparameter combinations.
# Finished evaluating 62/80 hyperparameter combinations.
# Finished evaluating 63/80 hyperparameter combinations.
# Finished evaluating 64/80 hyperparameter combinations.
# Finished evaluating 65/80 hyperparameter combinations.
# Finished evaluating 66/80 hyperparameter combinations.
# Finished evaluating 67/80 hyperparameter combinations.
# Finished evaluating 68/80 hyperparameter combinations.
# Finished evaluating 69/80 hyperparameter combinations.
# Finished evaluating 70/80 hyperparameter combinations.
# Finished evaluating 71/80 hyperparameter combinations.
# Finished evaluating 72/80 hyperparameter combinations.
# Finished evaluating 73/80 hyperparameter combinations.
# Finished evaluating 74/80 hyperparameter combinations.
# Finished evaluating 75/80 hyperparameter combinations.
# Finished evaluating 76/80 hyperparameter combinations.
# Finished evaluating 77/80 hyperparameter combinations.
# Finished evaluating 78/80 hyperparameter combinations.
# Finished evaluating 79/80 hyperparameter combinations.
# Finished evaluating 80/80 hyperparameter combinations.
# Elapsed time in sec:  514.6028226669996

# %%
print('Using physical and geospatial features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_lgp, param_lgp))
# Out:
# Using physical and geospatial features, the best CV score during hyper-parameter search is 0.7367043494458564, while the selected hyper-parameters are: {'UniSlct__k': 3000, 'est__C': 0.0001, 'est__penalty': 'l2'}

# %% [markdown]
# ### Excluding geospatial features

# %%
rng = np.random.RandomState(0)

lgp_param_grid_self = [{
 "UniSlct__k" : [10, 50, 100, 500],
    "est__penalty": ['l1', 'l2'],
    "est__C": [1e-4,1e-2, 1e0,1e2, 1e4]

},{
 "UniSlct__k" : [500, 1000, 3000,5000, 7000],
    "est__penalty": ['l1', 'l2'],
    "est__C": [1e-8,1e-6,1e-4, 1e-2, 1]
}]

lgp_estimator_self = LogisticRegression(max_iter = 500, solver = 'liblinear', random_state = rng)

lgp_steps_self = [
     ("pre", create_preprocessor()),
     ('poly', PolynomialFeatures(degree = 2)),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectKBest(f_classif)),
     ("est", lgp_estimator_self)
]

lgp_clf_pl_self = Pipeline(steps = lgp_steps_self)

start_time_lgp_self = time.perf_counter()
cv_table_lgp_self, score_lgp_self, std_lgp_self,param_lgp_self,pipeline_lgp_self = cv_evaluation(lgp_clf_pl_self, lgp_param_grid_self, X_train_self, y_train, X_cv_train_self_lst,y_cv_train_lst,X_cv_val_self_lst,y_cv_val_lst)
end_time_lgp_self = time.perf_counter()
elapsed_time_lgp_self = end_time_lgp_self - start_time_lgp_self
print("Elapsed time in sec: ", elapsed_time_lgp_self)
# Out:
# Finished evaluating 1/90 hyperparameter combinations.
# Finished evaluating 2/90 hyperparameter combinations.
# Finished evaluating 3/90 hyperparameter combinations.
# Finished evaluating 4/90 hyperparameter combinations.
# Finished evaluating 5/90 hyperparameter combinations.
# Finished evaluating 6/90 hyperparameter combinations.
# Finished evaluating 7/90 hyperparameter combinations.
# Finished evaluating 8/90 hyperparameter combinations.
# Finished evaluating 9/90 hyperparameter combinations.
# Finished evaluating 10/90 hyperparameter combinations.
# Finished evaluating 11/90 hyperparameter combinations.
# Finished evaluating 12/90 hyperparameter combinations.
# Finished evaluating 13/90 hyperparameter combinations.
# Finished evaluating 14/90 hyperparameter combinations.
# Finished evaluating 15/90 hyperparameter combinations.
# Finished evaluating 16/90 hyperparameter combinations.
# Finished evaluating 17/90 hyperparameter combinations.
# Finished evaluating 18/90 hyperparameter combinations.
# Finished evaluating 19/90 hyperparameter combinations.
# Finished evaluating 20/90 hyperparameter combinations.
# Finished evaluating 21/90 hyperparameter combinations.
# Finished evaluating 22/90 hyperparameter combinations.
# Finished evaluating 23/90 hyperparameter combinations.
# Finished evaluating 24/90 hyperparameter combinations.
# Finished evaluating 25/90 hyperparameter combinations.
# Finished evaluating 26/90 hyperparameter combinations.
# Finished evaluating 27/90 hyperparameter combinations.
# Finished evaluating 28/90 hyperparameter combinations.
# Finished evaluating 29/90 hyperparameter combinations.
# Finished evaluating 30/90 hyperparameter combinations.
# Finished evaluating 31/90 hyperparameter combinations.
# Finished evaluating 32/90 hyperparameter combinations.
# Finished evaluating 33/90 hyperparameter combinations.
# Finished evaluating 34/90 hyperparameter combinations.
# Finished evaluating 35/90 hyperparameter combinations.
# Finished evaluating 36/90 hyperparameter combinations.
# Finished evaluating 37/90 hyperparameter combinations.
# Finished evaluating 38/90 hyperparameter combinations.
# Finished evaluating 39/90 hyperparameter combinations.
# Finished evaluating 40/90 hyperparameter combinations.
# Finished evaluating 41/90 hyperparameter combinations.
# Finished evaluating 42/90 hyperparameter combinations.
# Finished evaluating 43/90 hyperparameter combinations.
# Finished evaluating 44/90 hyperparameter combinations.
# Finished evaluating 45/90 hyperparameter combinations.
# Finished evaluating 46/90 hyperparameter combinations.
# Finished evaluating 47/90 hyperparameter combinations.
# Finished evaluating 48/90 hyperparameter combinations.
# Finished evaluating 49/90 hyperparameter combinations.
# Finished evaluating 50/90 hyperparameter combinations.
# Finished evaluating 51/90 hyperparameter combinations.
# Finished evaluating 52/90 hyperparameter combinations.
# Finished evaluating 53/90 hyperparameter combinations.
# Finished evaluating 54/90 hyperparameter combinations.
# Finished evaluating 55/90 hyperparameter combinations.
# Finished evaluating 56/90 hyperparameter combinations.
# Finished evaluating 57/90 hyperparameter combinations.
# Finished evaluating 58/90 hyperparameter combinations.
# Finished evaluating 59/90 hyperparameter combinations.
# Finished evaluating 60/90 hyperparameter combinations.
# Finished evaluating 61/90 hyperparameter combinations.
# Finished evaluating 62/90 hyperparameter combinations.
# Finished evaluating 63/90 hyperparameter combinations.
# Finished evaluating 64/90 hyperparameter combinations.
# Finished evaluating 65/90 hyperparameter combinations.
# Finished evaluating 66/90 hyperparameter combinations.
# Finished evaluating 67/90 hyperparameter combinations.
# Finished evaluating 68/90 hyperparameter combinations.
# Finished evaluating 69/90 hyperparameter combinations.
# Finished evaluating 70/90 hyperparameter combinations.
# Finished evaluating 71/90 hyperparameter combinations.
# Finished evaluating 72/90 hyperparameter combinations.
# Finished evaluating 73/90 hyperparameter combinations.
# Finished evaluating 74/90 hyperparameter combinations.
# Finished evaluating 75/90 hyperparameter combinations.
# Finished evaluating 76/90 hyperparameter combinations.
# Finished evaluating 77/90 hyperparameter combinations.
# Finished evaluating 78/90 hyperparameter combinations.
# Finished evaluating 79/90 hyperparameter combinations.
# Finished evaluating 80/90 hyperparameter combinations.
# Finished evaluating 81/90 hyperparameter combinations.
# Finished evaluating 82/90 hyperparameter combinations.
# Finished evaluating 83/90 hyperparameter combinations.
# Finished evaluating 84/90 hyperparameter combinations.
# Finished evaluating 85/90 hyperparameter combinations.
# Finished evaluating 86/90 hyperparameter combinations.
# Finished evaluating 87/90 hyperparameter combinations.
# Finished evaluating 88/90 hyperparameter combinations.
# Finished evaluating 89/90 hyperparameter combinations.
# Finished evaluating 90/90 hyperparameter combinations.
# Elapsed time in sec:  525.478103167

# %%
print('Using only physical features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_lgp_self, param_lgp_self))
# Out:
# Using only physical features, the best CV score during hyper-parameter search is 0.6931468177715764, while the selected hyper-parameters are: {'UniSlct__k': 7000, 'est__C': 0.0001, 'est__penalty': 'l2'}

# %% [markdown]
# ## 5. Estimator = Support Vector Machine

# %% [markdown]
# ### Using all features

# %%
rng = np.random.RandomState(0)

default_gamma = 1/X_train.shape[1] #~ 0.01

svm_estimator = svm.SVC(cache_size = 2000, kernel = 'rbf', probability=True, random_state=rng)

svm_steps = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", svm_estimator)
]

svm_clf_pl = Pipeline(steps = svm_steps)

svm_param_grid = {"UniSlct__percentile": [1, 5, 10, 25, 50, 75],
    "est__C": [0.1, 1, 10, 100, 1000],
    "est__gamma":[default_gamma*0.001,default_gamma*0.01,default_gamma*0.1,default_gamma*1,default_gamma*10]}

start_time_svm = time.perf_counter()
cv_table_svm,score_svm, std_svm,param_svm,pipeline_svm = cv_evaluation(svm_clf_pl, svm_param_grid, X_train_spatial, y_train, X_cv_train_spatial_lst,y_cv_train_lst,X_cv_val_spatial_lst,y_cv_val_lst)
end_time_svm = time.perf_counter()
elapsed_time_svm = end_time_svm - start_time_svm
print("Elapsed time in sec: ", elapsed_time_svm)
# Out:
# Finished evaluating 1/150 hyperparameter combinations.
# Finished evaluating 2/150 hyperparameter combinations.
# Finished evaluating 3/150 hyperparameter combinations.
# Finished evaluating 4/150 hyperparameter combinations.
# Finished evaluating 5/150 hyperparameter combinations.
# Finished evaluating 6/150 hyperparameter combinations.
# Finished evaluating 7/150 hyperparameter combinations.
# Finished evaluating 8/150 hyperparameter combinations.
# Finished evaluating 9/150 hyperparameter combinations.
# Finished evaluating 10/150 hyperparameter combinations.
# Finished evaluating 11/150 hyperparameter combinations.
# Finished evaluating 12/150 hyperparameter combinations.
# Finished evaluating 13/150 hyperparameter combinations.
# Finished evaluating 14/150 hyperparameter combinations.
# Finished evaluating 15/150 hyperparameter combinations.
# Finished evaluating 16/150 hyperparameter combinations.
# Finished evaluating 17/150 hyperparameter combinations.
# Finished evaluating 18/150 hyperparameter combinations.
# Finished evaluating 19/150 hyperparameter combinations.
# Finished evaluating 20/150 hyperparameter combinations.
# Finished evaluating 21/150 hyperparameter combinations.
# Finished evaluating 22/150 hyperparameter combinations.
# Finished evaluating 23/150 hyperparameter combinations.
# Finished evaluating 24/150 hyperparameter combinations.
# Finished evaluating 25/150 hyperparameter combinations.
# Finished evaluating 26/150 hyperparameter combinations.
# Finished evaluating 27/150 hyperparameter combinations.
# Finished evaluating 28/150 hyperparameter combinations.
# Finished evaluating 29/150 hyperparameter combinations.
# Finished evaluating 30/150 hyperparameter combinations.
# Finished evaluating 31/150 hyperparameter combinations.
# Finished evaluating 32/150 hyperparameter combinations.
# Finished evaluating 33/150 hyperparameter combinations.
# Finished evaluating 34/150 hyperparameter combinations.
# Finished evaluating 35/150 hyperparameter combinations.
# Finished evaluating 36/150 hyperparameter combinations.
# Finished evaluating 37/150 hyperparameter combinations.
# Finished evaluating 38/150 hyperparameter combinations.
# Finished evaluating 39/150 hyperparameter combinations.
# Finished evaluating 40/150 hyperparameter combinations.
# Finished evaluating 41/150 hyperparameter combinations.
# Finished evaluating 42/150 hyperparameter combinations.
# Finished evaluating 43/150 hyperparameter combinations.
# Finished evaluating 44/150 hyperparameter combinations.
# Finished evaluating 45/150 hyperparameter combinations.
# Finished evaluating 46/150 hyperparameter combinations.
# Finished evaluating 47/150 hyperparameter combinations.
# Finished evaluating 48/150 hyperparameter combinations.
# Finished evaluating 49/150 hyperparameter combinations.
# Finished evaluating 50/150 hyperparameter combinations.
# Finished evaluating 51/150 hyperparameter combinations.
# Finished evaluating 52/150 hyperparameter combinations.
# Finished evaluating 53/150 hyperparameter combinations.
# Finished evaluating 54/150 hyperparameter combinations.
# Finished evaluating 55/150 hyperparameter combinations.
# Finished evaluating 56/150 hyperparameter combinations.
# Finished evaluating 57/150 hyperparameter combinations.
# Finished evaluating 58/150 hyperparameter combinations.
# Finished evaluating 59/150 hyperparameter combinations.
# Finished evaluating 60/150 hyperparameter combinations.
# Finished evaluating 61/150 hyperparameter combinations.
# Finished evaluating 62/150 hyperparameter combinations.
# Finished evaluating 63/150 hyperparameter combinations.
# Finished evaluating 64/150 hyperparameter combinations.
# Finished evaluating 65/150 hyperparameter combinations.
# Finished evaluating 66/150 hyperparameter combinations.
# Finished evaluating 67/150 hyperparameter combinations.
# Finished evaluating 68/150 hyperparameter combinations.
# Finished evaluating 69/150 hyperparameter combinations.
# Finished evaluating 70/150 hyperparameter combinations.
# Finished evaluating 71/150 hyperparameter combinations.
# Finished evaluating 72/150 hyperparameter combinations.
# Finished evaluating 73/150 hyperparameter combinations.
# Finished evaluating 74/150 hyperparameter combinations.
# Finished evaluating 75/150 hyperparameter combinations.
# Finished evaluating 76/150 hyperparameter combinations.
# Finished evaluating 77/150 hyperparameter combinations.
# Finished evaluating 78/150 hyperparameter combinations.
# Finished evaluating 79/150 hyperparameter combinations.
# Finished evaluating 80/150 hyperparameter combinations.
# Finished evaluating 81/150 hyperparameter combinations.
# Finished evaluating 82/150 hyperparameter combinations.
# Finished evaluating 83/150 hyperparameter combinations.
# Finished evaluating 84/150 hyperparameter combinations.
# Finished evaluating 85/150 hyperparameter combinations.
# Finished evaluating 86/150 hyperparameter combinations.
# Finished evaluating 87/150 hyperparameter combinations.
# Finished evaluating 88/150 hyperparameter combinations.
# Finished evaluating 89/150 hyperparameter combinations.
# Finished evaluating 90/150 hyperparameter combinations.
# Finished evaluating 91/150 hyperparameter combinations.
# Finished evaluating 92/150 hyperparameter combinations.
# Finished evaluating 93/150 hyperparameter combinations.
# Finished evaluating 94/150 hyperparameter combinations.
# Finished evaluating 95/150 hyperparameter combinations.
# Finished evaluating 96/150 hyperparameter combinations.
# Finished evaluating 97/150 hyperparameter combinations.
# Finished evaluating 98/150 hyperparameter combinations.
# Finished evaluating 99/150 hyperparameter combinations.
# Finished evaluating 100/150 hyperparameter combinations.
# Finished evaluating 101/150 hyperparameter combinations.
# Finished evaluating 102/150 hyperparameter combinations.
# Finished evaluating 103/150 hyperparameter combinations.
# Finished evaluating 104/150 hyperparameter combinations.
# Finished evaluating 105/150 hyperparameter combinations.
# Finished evaluating 106/150 hyperparameter combinations.
# Finished evaluating 107/150 hyperparameter combinations.
# Finished evaluating 108/150 hyperparameter combinations.
# Finished evaluating 109/150 hyperparameter combinations.
# Finished evaluating 110/150 hyperparameter combinations.
# Finished evaluating 111/150 hyperparameter combinations.
# Finished evaluating 112/150 hyperparameter combinations.
# Finished evaluating 113/150 hyperparameter combinations.
# Finished evaluating 114/150 hyperparameter combinations.
# Finished evaluating 115/150 hyperparameter combinations.
# Finished evaluating 116/150 hyperparameter combinations.
# Finished evaluating 117/150 hyperparameter combinations.
# Finished evaluating 118/150 hyperparameter combinations.
# Finished evaluating 119/150 hyperparameter combinations.
# Finished evaluating 120/150 hyperparameter combinations.
# Finished evaluating 121/150 hyperparameter combinations.
# Finished evaluating 122/150 hyperparameter combinations.
# Finished evaluating 123/150 hyperparameter combinations.
# Finished evaluating 124/150 hyperparameter combinations.
# Finished evaluating 125/150 hyperparameter combinations.
# Finished evaluating 126/150 hyperparameter combinations.
# Finished evaluating 127/150 hyperparameter combinations.
# Finished evaluating 128/150 hyperparameter combinations.
# Finished evaluating 129/150 hyperparameter combinations.
# Finished evaluating 130/150 hyperparameter combinations.
# Finished evaluating 131/150 hyperparameter combinations.
# Finished evaluating 132/150 hyperparameter combinations.
# Finished evaluating 133/150 hyperparameter combinations.
# Finished evaluating 134/150 hyperparameter combinations.
# Finished evaluating 135/150 hyperparameter combinations.
# Finished evaluating 136/150 hyperparameter combinations.
# Finished evaluating 137/150 hyperparameter combinations.
# Finished evaluating 138/150 hyperparameter combinations.
# Finished evaluating 139/150 hyperparameter combinations.
# Finished evaluating 140/150 hyperparameter combinations.
# Finished evaluating 141/150 hyperparameter combinations.
# Finished evaluating 142/150 hyperparameter combinations.
# Finished evaluating 143/150 hyperparameter combinations.
# Finished evaluating 144/150 hyperparameter combinations.
# Finished evaluating 145/150 hyperparameter combinations.
# Finished evaluating 146/150 hyperparameter combinations.
# Finished evaluating 147/150 hyperparameter combinations.
# Finished evaluating 148/150 hyperparameter combinations.
# Finished evaluating 149/150 hyperparameter combinations.
# Finished evaluating 150/150 hyperparameter combinations.
# Elapsed time in sec:  137.13336608400095

# %%
print('Using physical and geospatial features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_svm, param_svm))
# Out:
# Using physical and geospatial features, the best CV score during hyper-parameter search is 0.73352159148222, while the selected hyper-parameters are: {'UniSlct__percentile': 25, 'est__C': 1, 'est__gamma': 0.008264462809917356}

# %% [markdown]
# ### Excluding geospatial features

# %%
rng = np.random.RandomState(0)

default_gamma = 1/X_train_self.shape[1] # ~ 0.011

svm_estimator_self = svm.SVC(cache_size = 2000, kernel = 'rbf',probability=True, random_state=rng)

svm_steps_self = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", svm_estimator_self)
]

svm_clf_pl_self = Pipeline(steps = svm_steps_self)

svm_param_grid_self = {
    "UniSlct__percentile": [5, 10, 25, 50, 75],
    "est__C": [0.1, 1, 10, 100, 1000],
    "est__gamma":[default_gamma*0.001, default_gamma*0.01, default_gamma*0.1,default_gamma*1]
}

start_time_svm_self = time.perf_counter()
cv_table_svm_self,score_svm_self, std_svm_self,param_svm_self,pipeline_svm_self = cv_evaluation(svm_clf_pl_self, svm_param_grid_self, X_train_self, y_train, X_cv_train_self_lst,y_cv_train_lst,X_cv_val_self_lst,y_cv_val_lst)
end_time_svm_self = time.perf_counter()
elapsed_time_svm_self = end_time_svm_self - start_time_svm_self
print("Elapsed time in sec: ", elapsed_time_svm)
# Out:
# Finished evaluating 1/100 hyperparameter combinations.
# Finished evaluating 2/100 hyperparameter combinations.
# Finished evaluating 3/100 hyperparameter combinations.
# Finished evaluating 4/100 hyperparameter combinations.
# Finished evaluating 5/100 hyperparameter combinations.
# Finished evaluating 6/100 hyperparameter combinations.
# Finished evaluating 7/100 hyperparameter combinations.
# Finished evaluating 8/100 hyperparameter combinations.
# Finished evaluating 9/100 hyperparameter combinations.
# Finished evaluating 10/100 hyperparameter combinations.
# Finished evaluating 11/100 hyperparameter combinations.
# Finished evaluating 12/100 hyperparameter combinations.
# Finished evaluating 13/100 hyperparameter combinations.
# Finished evaluating 14/100 hyperparameter combinations.
# Finished evaluating 15/100 hyperparameter combinations.
# Finished evaluating 16/100 hyperparameter combinations.
# Finished evaluating 17/100 hyperparameter combinations.
# Finished evaluating 18/100 hyperparameter combinations.
# Finished evaluating 19/100 hyperparameter combinations.
# Finished evaluating 20/100 hyperparameter combinations.
# Finished evaluating 21/100 hyperparameter combinations.
# Finished evaluating 22/100 hyperparameter combinations.
# Finished evaluating 23/100 hyperparameter combinations.
# Finished evaluating 24/100 hyperparameter combinations.
# Finished evaluating 25/100 hyperparameter combinations.
# Finished evaluating 26/100 hyperparameter combinations.
# Finished evaluating 27/100 hyperparameter combinations.
# Finished evaluating 28/100 hyperparameter combinations.
# Finished evaluating 29/100 hyperparameter combinations.
# Finished evaluating 30/100 hyperparameter combinations.
# Finished evaluating 31/100 hyperparameter combinations.
# Finished evaluating 32/100 hyperparameter combinations.
# Finished evaluating 33/100 hyperparameter combinations.
# Finished evaluating 34/100 hyperparameter combinations.
# Finished evaluating 35/100 hyperparameter combinations.
# Finished evaluating 36/100 hyperparameter combinations.
# Finished evaluating 37/100 hyperparameter combinations.
# Finished evaluating 38/100 hyperparameter combinations.
# Finished evaluating 39/100 hyperparameter combinations.
# Finished evaluating 40/100 hyperparameter combinations.
# Finished evaluating 41/100 hyperparameter combinations.
# Finished evaluating 42/100 hyperparameter combinations.
# Finished evaluating 43/100 hyperparameter combinations.
# Finished evaluating 44/100 hyperparameter combinations.
# Finished evaluating 45/100 hyperparameter combinations.
# Finished evaluating 46/100 hyperparameter combinations.
# Finished evaluating 47/100 hyperparameter combinations.
# Finished evaluating 48/100 hyperparameter combinations.
# Finished evaluating 49/100 hyperparameter combinations.
# Finished evaluating 50/100 hyperparameter combinations.
# Finished evaluating 51/100 hyperparameter combinations.
# Finished evaluating 52/100 hyperparameter combinations.
# Finished evaluating 53/100 hyperparameter combinations.
# Finished evaluating 54/100 hyperparameter combinations.
# Finished evaluating 55/100 hyperparameter combinations.
# Finished evaluating 56/100 hyperparameter combinations.
# Finished evaluating 57/100 hyperparameter combinations.
# Finished evaluating 58/100 hyperparameter combinations.
# Finished evaluating 59/100 hyperparameter combinations.
# Finished evaluating 60/100 hyperparameter combinations.
# Finished evaluating 61/100 hyperparameter combinations.
# Finished evaluating 62/100 hyperparameter combinations.
# Finished evaluating 63/100 hyperparameter combinations.
# Finished evaluating 64/100 hyperparameter combinations.
# Finished evaluating 65/100 hyperparameter combinations.
# Finished evaluating 66/100 hyperparameter combinations.
# Finished evaluating 67/100 hyperparameter combinations.
# Finished evaluating 68/100 hyperparameter combinations.
# Finished evaluating 69/100 hyperparameter combinations.
# Finished evaluating 70/100 hyperparameter combinations.
# Finished evaluating 71/100 hyperparameter combinations.
# Finished evaluating 72/100 hyperparameter combinations.
# Finished evaluating 73/100 hyperparameter combinations.
# Finished evaluating 74/100 hyperparameter combinations.
# Finished evaluating 75/100 hyperparameter combinations.
# Finished evaluating 76/100 hyperparameter combinations.
# Finished evaluating 77/100 hyperparameter combinations.
# Finished evaluating 78/100 hyperparameter combinations.
# Finished evaluating 79/100 hyperparameter combinations.
# Finished evaluating 80/100 hyperparameter combinations.
# Finished evaluating 81/100 hyperparameter combinations.
# Finished evaluating 82/100 hyperparameter combinations.
# Finished evaluating 83/100 hyperparameter combinations.
# Finished evaluating 84/100 hyperparameter combinations.
# Finished evaluating 85/100 hyperparameter combinations.
# Finished evaluating 86/100 hyperparameter combinations.
# Finished evaluating 87/100 hyperparameter combinations.
# Finished evaluating 88/100 hyperparameter combinations.
# Finished evaluating 89/100 hyperparameter combinations.
# Finished evaluating 90/100 hyperparameter combinations.
# Finished evaluating 91/100 hyperparameter combinations.
# Finished evaluating 92/100 hyperparameter combinations.
# Finished evaluating 93/100 hyperparameter combinations.
# Finished evaluating 94/100 hyperparameter combinations.
# Finished evaluating 95/100 hyperparameter combinations.
# Finished evaluating 96/100 hyperparameter combinations.
# Finished evaluating 97/100 hyperparameter combinations.
# Finished evaluating 98/100 hyperparameter combinations.
# Finished evaluating 99/100 hyperparameter combinations.
# Finished evaluating 100/100 hyperparameter combinations.
# Elapsed time in sec:  137.13336608400095

# %%
print('Using only physical features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_svm_self, param_svm_self))
# Out:
# Using only physical features, the best CV score during hyper-parameter search is 0.689081263210132, while the selected hyper-parameters are: {'UniSlct__percentile': 50, 'est__C': 1, 'est__gamma': 0.0008547008547008548}

# %% [markdown]
# ## 6. Estimator = K-Nearest Neighbour

# %% [markdown]
# ### Using all features

# %%
knn_estimator = KNeighborsClassifier(n_jobs=-1)

knn_steps = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", knn_estimator)
]
knn_clf_pl = Pipeline(steps = knn_steps)

knn_param_grid = {
    "UniSlct__percentile": [ 10, 25, 50, 75, 100],
    "est__weights": ['uniform', 'distance'],
    "est__n_neighbors": [10,20, 30, 40, 50]
}

start_time_knn = time.perf_counter()
cv_table_knn,score_knn, std_knn,param_knn,pipeline_knn = cv_evaluation(knn_clf_pl, knn_param_grid, X_train_spatial, y_train, X_cv_train_spatial_lst,y_cv_train_lst,X_cv_val_spatial_lst,y_cv_val_lst)
end_time_knn = time.perf_counter()
elapsed_time_knn = end_time_knn - start_time_knn
print("Elapsed time in sec: ", elapsed_time_knn)
# Out:
# Finished evaluating 1/50 hyperparameter combinations.
# Finished evaluating 2/50 hyperparameter combinations.
# Finished evaluating 3/50 hyperparameter combinations.
# Finished evaluating 4/50 hyperparameter combinations.
# Finished evaluating 5/50 hyperparameter combinations.
# Finished evaluating 6/50 hyperparameter combinations.
# Finished evaluating 7/50 hyperparameter combinations.
# Finished evaluating 8/50 hyperparameter combinations.
# Finished evaluating 9/50 hyperparameter combinations.
# Finished evaluating 10/50 hyperparameter combinations.
# Finished evaluating 11/50 hyperparameter combinations.
# Finished evaluating 12/50 hyperparameter combinations.
# Finished evaluating 13/50 hyperparameter combinations.
# Finished evaluating 14/50 hyperparameter combinations.
# Finished evaluating 15/50 hyperparameter combinations.
# Finished evaluating 16/50 hyperparameter combinations.
# Finished evaluating 17/50 hyperparameter combinations.
# Finished evaluating 18/50 hyperparameter combinations.
# Finished evaluating 19/50 hyperparameter combinations.
# Finished evaluating 20/50 hyperparameter combinations.
# Finished evaluating 21/50 hyperparameter combinations.
# Finished evaluating 22/50 hyperparameter combinations.
# Finished evaluating 23/50 hyperparameter combinations.
# Finished evaluating 24/50 hyperparameter combinations.
# Finished evaluating 25/50 hyperparameter combinations.
# Finished evaluating 26/50 hyperparameter combinations.
# Finished evaluating 27/50 hyperparameter combinations.
# Finished evaluating 28/50 hyperparameter combinations.
# Finished evaluating 29/50 hyperparameter combinations.
# Finished evaluating 30/50 hyperparameter combinations.
# Finished evaluating 31/50 hyperparameter combinations.
# Finished evaluating 32/50 hyperparameter combinations.
# Finished evaluating 33/50 hyperparameter combinations.
# Finished evaluating 34/50 hyperparameter combinations.
# Finished evaluating 35/50 hyperparameter combinations.
# Finished evaluating 36/50 hyperparameter combinations.
# Finished evaluating 37/50 hyperparameter combinations.
# Finished evaluating 38/50 hyperparameter combinations.
# Finished evaluating 39/50 hyperparameter combinations.
# Finished evaluating 40/50 hyperparameter combinations.
# Finished evaluating 41/50 hyperparameter combinations.
# Finished evaluating 42/50 hyperparameter combinations.
# Finished evaluating 43/50 hyperparameter combinations.
# Finished evaluating 44/50 hyperparameter combinations.
# Finished evaluating 45/50 hyperparameter combinations.
# Finished evaluating 46/50 hyperparameter combinations.
# Finished evaluating 47/50 hyperparameter combinations.
# Finished evaluating 48/50 hyperparameter combinations.
# Finished evaluating 49/50 hyperparameter combinations.
# Finished evaluating 50/50 hyperparameter combinations.
# Elapsed time in sec:  8.66808625000067

# %%
print('Using physical and geospatial features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_knn, param_knn))
# Out:
# Using physical and geospatial features, the best CV score during hyper-parameter search is 0.7175341288537274, while the selected hyper-parameters are: {'UniSlct__percentile': 25, 'est__n_neighbors': 40, 'est__weights': 'distance'}

# %% [markdown]
# ### Excluding geospatial features

# %%
knn_estimator_self = KNeighborsClassifier(n_jobs=-1)

knn_steps_self = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", knn_estimator_self)
]
knn_clf_pl_self = Pipeline(steps = knn_steps_self)

knn_param_grid_self = {
    "UniSlct__percentile": [10, 25, 50, 75, 100],
    "est__weights": ['uniform', 'distance'],
    "est__n_neighbors": [  30, 50, 70, 90, 110, 130]
}

start_time_knn_self = time.perf_counter()
cv_table_knn_self,score_knn_self, std_knn_self,param_knn_self,pipeline_knn_self = cv_evaluation(knn_clf_pl_self, knn_param_grid_self, X_train_self, y_train, X_cv_train_self_lst,y_cv_train_lst,X_cv_val_self_lst,y_cv_val_lst)
end_time_knn_self = time.perf_counter()
elapsed_time_knn_self = end_time_knn_self - start_time_knn_self
print("Elapsed time in sec: ", elapsed_time_knn_self)
# Out:
# Finished evaluating 1/60 hyperparameter combinations.
# Finished evaluating 2/60 hyperparameter combinations.
# Finished evaluating 3/60 hyperparameter combinations.
# Finished evaluating 4/60 hyperparameter combinations.
# Finished evaluating 5/60 hyperparameter combinations.
# Finished evaluating 6/60 hyperparameter combinations.
# Finished evaluating 7/60 hyperparameter combinations.
# Finished evaluating 8/60 hyperparameter combinations.
# Finished evaluating 9/60 hyperparameter combinations.
# Finished evaluating 10/60 hyperparameter combinations.
# Finished evaluating 11/60 hyperparameter combinations.
# Finished evaluating 12/60 hyperparameter combinations.
# Finished evaluating 13/60 hyperparameter combinations.
# Finished evaluating 14/60 hyperparameter combinations.
# Finished evaluating 15/60 hyperparameter combinations.
# Finished evaluating 16/60 hyperparameter combinations.
# Finished evaluating 17/60 hyperparameter combinations.
# Finished evaluating 18/60 hyperparameter combinations.
# Finished evaluating 19/60 hyperparameter combinations.
# Finished evaluating 20/60 hyperparameter combinations.
# Finished evaluating 21/60 hyperparameter combinations.
# Finished evaluating 22/60 hyperparameter combinations.
# Finished evaluating 23/60 hyperparameter combinations.
# Finished evaluating 24/60 hyperparameter combinations.
# Finished evaluating 25/60 hyperparameter combinations.
# Finished evaluating 26/60 hyperparameter combinations.
# Finished evaluating 27/60 hyperparameter combinations.
# Finished evaluating 28/60 hyperparameter combinations.
# Finished evaluating 29/60 hyperparameter combinations.
# Finished evaluating 30/60 hyperparameter combinations.
# Finished evaluating 31/60 hyperparameter combinations.
# Finished evaluating 32/60 hyperparameter combinations.
# Finished evaluating 33/60 hyperparameter combinations.
# Finished evaluating 34/60 hyperparameter combinations.
# Finished evaluating 35/60 hyperparameter combinations.
# Finished evaluating 36/60 hyperparameter combinations.
# Finished evaluating 37/60 hyperparameter combinations.
# Finished evaluating 38/60 hyperparameter combinations.
# Finished evaluating 39/60 hyperparameter combinations.
# Finished evaluating 40/60 hyperparameter combinations.
# Finished evaluating 41/60 hyperparameter combinations.
# Finished evaluating 42/60 hyperparameter combinations.
# Finished evaluating 43/60 hyperparameter combinations.
# Finished evaluating 44/60 hyperparameter combinations.
# Finished evaluating 45/60 hyperparameter combinations.
# Finished evaluating 46/60 hyperparameter combinations.
# Finished evaluating 47/60 hyperparameter combinations.
# Finished evaluating 48/60 hyperparameter combinations.
# Finished evaluating 49/60 hyperparameter combinations.
# Finished evaluating 50/60 hyperparameter combinations.
# Finished evaluating 51/60 hyperparameter combinations.
# Finished evaluating 52/60 hyperparameter combinations.
# Finished evaluating 53/60 hyperparameter combinations.
# Finished evaluating 54/60 hyperparameter combinations.
# Finished evaluating 55/60 hyperparameter combinations.
# Finished evaluating 56/60 hyperparameter combinations.
# Finished evaluating 57/60 hyperparameter combinations.
# Finished evaluating 58/60 hyperparameter combinations.
# Finished evaluating 59/60 hyperparameter combinations.
# Finished evaluating 60/60 hyperparameter combinations.
# Elapsed time in sec:  9.436381167000036

# %%
print('Using only physical features, the best CV score during hyper-parameter search is {}, while the selected hyper-parameters are: {}'.format(score_knn_self, param_knn_self))
# Out:
# Using only physical features, the best CV score during hyper-parameter search is 0.7080477443953975, while the selected hyper-parameters are: {'UniSlct__percentile': 50, 'est__n_neighbors': 90, 'est__weights': 'distance'}

# %% [markdown]
# # Plot the cross-validation score of each model

# %%
models = ['RF', 'XGB', 'LR', 'LR-IA', 'SVM','KNN']

mean_scores_best_models = {
    'All features':np.array([score_rf, score_xgb, score_lg, score_lgp, score_svm, score_knn]),
    'No geospatial features':np.array([score_rf_self, score_xgb_self, score_lg_self, score_lgp_self,score_svm_self,score_knn_self])
}

std_scores_best_models = {
    'All features':np.array([std_rf, std_xgb, std_lg, std_lgp,std_svm,std_knn]),
    'No geospatial features':np.array([std_rf_self, std_xgb_self, std_lg_self, std_lgp_self,std_svm_self, std_knn_self])
}

# %%
x = np.arange(len(models))  # the label locations
width = 0.4  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(1,1, figsize=(3.4,3.2))

for feature_choice, score in mean_scores_best_models.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, score, width, label=feature_choice)
    ax.bar_label(rects, padding=1, fmt = '%.2f', size=8,  rotation = 45)
    error = std_scores_best_models[feature_choice]
    ax.errorbar(x + offset, score, yerr = error, fmt = 'none',color = 'black', capsize = 1, capthick = 0.5,elinewidth=0.5, alpha = 0.7)
    multiplier += 1

ax.set_ylabel('ROC AUC', size = 9)
ax.set_xlabel('ML Models', size = 9)
ax.set_xticks(ticks = x + 0.5*width)
ax.set_xticklabels(models)
ax.tick_params(labelrotation=15,axis='x', which='major', labelsize=9)
ax.tick_params(axis='y', which='major', labelsize=9)
#handles, labels = ax.get_legend_handles_labels()
ax.legend(loc='upper left', ncol=1, fontsize = 9, bbox_to_anchor=(-0.02, 1.22))
ax.set_ylim(0.5, 0.8)

plt.savefig('./Figures/main_text/models_cv_comparison.png',bbox_inches='tight',dpi=300)

# %% [markdown]
# # Plot ROC of each model. Fit and evaluate on the first CV split

# %%
colors = ['red', 'orange', 'yellow', 'black', 'blue', 'purple']

best_models_spatial = [pipeline_rf,pipeline_xgb,pipeline_lg,pipeline_lgp,pipeline_svm,pipeline_knn] # including spatial features
best_models_self = [pipeline_rf_self,pipeline_xgb_self,pipeline_lg_self,pipeline_lgp_self,pipeline_svm_self,pipeline_knn_self] # excluding spatial features

rng = np.random.RandomState(0)
rng_self = np.random.RandomState(0)

X_cv_train_spatial_1 = X_cv_train_spatial_lst[0]
X_cv_val_spatial_1 = X_cv_val_spatial_lst[0]
X_cv_train_self_1 = X_cv_train_self_lst[0]
X_cv_val_self_1 = X_cv_val_self_lst[0]
y_cv_train_1 = y_cv_train_lst[0]
y_cv_val_1 = y_cv_val_lst[0]

fig, axes = plt.subplots(1,2, figsize = (12,6))

fpr_spatial_lst = []
tpr_spatial_lst = []
thresholds_spatial_lst = []
roc_auc_spatial_lst = []

fpr_self_lst = []
tpr_self_lst = []
thresholds_self_lst = []
roc_auc_self_lst = []

for i in np.arange(len(models)):
    model_name = models[i]
    #For including spatial features:
    
    model_spatial = best_models_spatial[i]
    if model_name != 'KNN':
        model_spatial = model_spatial.set_params(**{'est__random_state':rng})
    model_spatial.fit(X_cv_train_spatial_1, y_cv_train_1)
    y_cv_val_1_pred_proba_spatial = model_spatial.predict_proba(X_cv_val_spatial_1)[:,1]
    
    fpr, tpr, thresholds = roc_curve(y_cv_val_1, y_cv_val_1_pred_proba_spatial)
    roc_auc_spatial = roc_auc_score(y_cv_val_1, y_cv_val_1_pred_proba_spatial)
    
    fpr_spatial_lst.append(fpr)
    tpr_spatial_lst.append(tpr)
    thresholds_spatial_lst.append(thresholds)
    roc_auc_spatial_lst.append(roc_auc_spatial)
    
    print("ROC AUC of {} using all features including geospatial ones is: {}".format(model_name, roc_auc_spatial))
    axes[0].plot(fpr, tpr, color = colors[i], label = model_name+'_all_features')
    axes[0].set_xlabel('False Positive Rate', fontsize=12)
    axes[0].set_ylabel('True Positive Rate', fontsize=12)
    axes[0].tick_params(axis='both', which='major', labelsize=12)
    axes[0].legend(loc='lower right', fontsize = 12)
    axes[0].text(-0.1, 1, 'A', transform=axes[0].transAxes, fontsize=15, fontweight='bold',va='top', ha='right')
    
    # For excluding spatial features:
    model_self = best_models_self[i]
    if model_name != 'KNN':
        model_self = model_self.set_params(**{'est__random_state':rng_self})
    model_self.fit(X_cv_train_self_1, y_cv_train_1)
    y_cv_val_1_pred_proba_self = model_self.predict_proba(X_cv_val_self_1)[:,1]
    
    fpr, tpr, thresholds = roc_curve(y_cv_val_1, y_cv_val_1_pred_proba_self)
    roc_auc_self = roc_auc_score(y_cv_val_1, y_cv_val_1_pred_proba_self)
    
    fpr_self_lst.append(fpr)
    tpr_self_lst.append(tpr)
    thresholds_self_lst.append(thresholds)
    roc_auc_self_lst.append(roc_auc_self)
    
    print("ROC AUC of {} excluding geospatial features is: {}".format(model_name, roc_auc_self))
    axes[1].plot(fpr, tpr, '--', color=colors[i],label = model_name + '_no_geospatial_features', alpha = 0.8)
    axes[1].set_xlabel('False Positive Rate', fontsize=12)
    axes[1].set_ylabel('True Positive Rate', fontsize=12)
    axes[1].tick_params(axis='both', which='major', labelsize=12)
    axes[1].legend(loc='lower right', fontsize = 12)
    axes[1].text(-0.1, 1, 'B', transform=axes[1].transAxes, fontsize=15, fontweight='bold',va='top', ha='right')
    
plt.savefig('./Figures/SI/ROC_curves.png',bbox_inches='tight',dpi=300)
# Out:
# ROC AUC of RF using all features including geospatial ones is: 0.7342624491074224
# ROC AUC of RF excluding geospatial features is: 0.7202735149806869
# ROC AUC of XGB using all features including geospatial ones is: 0.7095730243240421
# ROC AUC of XGB excluding geospatial features is: 0.7022653721682849
# ROC AUC of LR using all features including geospatial ones is: 0.6726171834220692
# ROC AUC of LR excluding geospatial features is: 0.6371228729512475
# ROC AUC of LR-IA using all features including geospatial ones is: 0.6725127883912725
# ROC AUC of LR-IA excluding geospatial features is: 0.6400459338135505
# ROC AUC of SVM using all features including geospatial ones is: 0.6718864182064934
# ROC AUC of SVM excluding geospatial features is: 0.623342728886105
# ROC AUC of KNN using all features including geospatial ones is: 0.6837874517172983
# ROC AUC of KNN excluding geospatial features is: 0.6755402442843721

# %% [markdown]
# # Select the optimal threshold for the RF model

# %%
fpr_rf = fpr_spatial_lst[0]
tpr_rf = tpr_spatial_lst[0]
thresholds_rf = thresholds_spatial_lst[0]
opt_idx_rf = np.argmax(tpr_rf - fpr_rf)
thres_opt_rf = thresholds_rf[opt_idx_rf]

fpr_rf_self = fpr_self_lst[0]
tpr_rf_self = tpr_self_lst[0]
thresholds_rf_self = thresholds_self_lst[0]
opt_idx_rf_self = np.argmax(tpr_rf_self - fpr_rf_self)
thres_opt_rf_self = thresholds_rf_self[opt_idx_rf_self]

fig, axes = plt.subplots(1,2, figsize = (12,6))
axes[0].plot(fpr_rf, tpr_rf, color = colors[0], label = models[0]+'_all_features')
axes[0].plot(fpr_rf[opt_idx_rf], tpr_rf[opt_idx_rf], marker = '*', color = 'blue', 
             markersize = 15)# Plot optimal point
axes[0].annotate('Optimal threshold = {:.2f}'.format(thres_opt_rf), (0.25, 0.56),
                ha = 'left', fontsize = 12)
axes[0].set_xlabel('False Positive Rate', fontsize=12)
axes[0].set_ylabel('True Positive Rate', fontsize=12)
axes[0].tick_params(axis='both', which='major', labelsize=12)
axes[0].legend(loc='lower right', fontsize = 12)
axes[0].text(-0.1, 1, 'A', transform=axes[0].transAxes, fontsize=15, fontweight='bold',va='top', ha='right')

axes[1].plot(fpr_rf_self, tpr_rf_self, '--', color=colors[0],label = models[0] + '_no_geospatial_features', alpha = 0.8)
axes[1].plot(fpr_rf_self[opt_idx_rf_self], tpr_rf_self[opt_idx_rf_self], marker = '*', color = 'blue', 
             markersize = 15)# Plot optimal point
axes[1].annotate('Optimal threshold = {:.2f}'.format(thres_opt_rf_self), (0.50, 0.75),
                ha = 'left', fontsize = 12)
axes[1].set_xlabel('False Positive Rate', fontsize=12)
axes[1].set_ylabel('True Positive Rate', fontsize=12)
axes[1].tick_params(axis='both', which='major', labelsize=12)
axes[1].legend(loc='lower right', fontsize = 12)
axes[1].text(-0.1, 1, 'B', transform=axes[1].transAxes, fontsize=15, fontweight='bold',va='top', ha='right')

plt.savefig('./Figures/SI/optimal_threshold.png',bbox_inches='tight',dpi=300)

# %% [markdown]
# # Evaluate the RF model on test set using the optimal threshold

# %%
# define a function to generate predictions using specified threshold
def predict_using_threshold(y_proba_pred, thres):
    y_pred = (y_proba_pred >= thres).astype('int')
    return y_pred

# %%
def test_evaluation(model, threshold, X_test, y_test):
    y_pred_proba = model.predict_proba(X_test)[:,1]
    y_pred = predict_using_threshold(y_pred_proba, threshold)
    cm = confusion_matrix(y_test,y_pred, labels=model.classes_)
    roc_auc = roc_auc_score(y_test,y_pred_proba)
    print(cm)
    print(classification_report(y_test,y_pred))
    print('Accuracy: ',accuracy_score(y_test,y_pred))
    print('ROC_AUC: ', roc_auc)

# %% [markdown]
# ### Using all features

# %%
rng = np.random.RandomState(0)
pipeline_rf = pipeline_rf.set_params(**{'est__random_state':rng})
pipeline_rf.fit(X_train_spatial, y_train) # re-fit on the entire training set
test_evaluation(pipeline_rf, thres_opt_rf, X_test_spatial, y_test)
# Out:
# [[95 34]
#  [45 71]]
#               precision    recall  f1-score   support
#
#        False       0.68      0.74      0.71       129
#         True       0.68      0.61      0.64       116
#
#     accuracy                           0.68       245
#    macro avg       0.68      0.67      0.67       245
# weighted avg       0.68      0.68      0.68       245
#
# Accuracy:  0.6775510204081633
# ROC_AUC:  0.7251069232825448

# %% [markdown]
# ### Excluding geospatial features

# %%
rng_self = np.random.RandomState(0)
pipeline_rf_self = pipeline_rf_self.set_params(**{'est__random_state':rng_self})
pipeline_rf_self.fit(X_train_self, y_train) # re-fit on the entire training set
test_evaluation(pipeline_rf_self, thres_opt_rf_self, X_test_self, y_test)
# Out:
# [[101  28]
#  [ 56  60]]
#               precision    recall  f1-score   support
#
#        False       0.64      0.78      0.71       129
#         True       0.68      0.52      0.59       116
#
#     accuracy                           0.66       245
#    macro avg       0.66      0.65      0.65       245
# weighted avg       0.66      0.66      0.65       245
#
# Accuracy:  0.6571428571428571
# ROC_AUC:  0.7038893344025662

# %% [markdown]
# # Feature importance of the RF model by SHAP values

# %% [markdown]
# ### Using all features

# %%
rng = np.random.RandomState(0)
pipeline_rf = pipeline_rf.set_params(**{'est__random_state':rng})

# Obtain the final column names:
rf_best_pl = pipeline_rf
rf_cols_0 = rf_best_pl['pre'].feature_names_in_
rf_cols_1 = rf_best_pl['pre'].get_feature_names_out(rf_cols_0)
rf_cols_2 = rf_best_pl['scaler'].get_feature_names_out(rf_cols_1)
rf_cols_3 = rf_best_pl['varFilter'].get_feature_names_out(rf_cols_2)
rf_cols_final = rf_best_pl['UniSlct'].get_feature_names_out(rf_cols_3)
rf_cols_final_clean = [i[1] for i in np.char.split(rf_cols_final.astype(str), sep='__')]
rf_cols_final_clean = np.array([s.replace('_' , ' ') for s in rf_cols_final_clean])

# Transform the X data:
X_pre_rf = rf_best_pl['pre'].transform(X_test_spatial) # use test data for SHAP values
X_scaler_rf = rf_best_pl['scaler'].transform(X_pre_rf)
X_varFilter_rf = rf_best_pl['varFilter'].transform(X_scaler_rf)
X_UniSlct_rf = rf_best_pl['UniSlct'].transform(X_varFilter_rf)
X_processed_rf = pd.DataFrame(X_UniSlct_rf, columns = rf_cols_final_clean)

# Calculate SHAP values:
best_rf_model = rf_best_pl['est']
rf_explainer = shap.TreeExplainer(best_rf_model)
shap_values_rf = rf_explainer(X_processed_rf)

# %% [markdown]
# ### Excluding geospatial features

# %%
rng_self = np.random.RandomState(0)
pipeline_rf_self = pipeline_rf_self.set_params(**{'est__random_state':rng_self})

# Obtain the final column names
rf_self_best_pl = pipeline_rf_self
rf_self_cols_0 = rf_self_best_pl['pre'].feature_names_in_
rf_self_cols_1 = rf_self_best_pl['pre'].get_feature_names_out(rf_self_cols_0)
rf_self_cols_2 = rf_self_best_pl['scaler'].get_feature_names_out(rf_self_cols_1)
rf_self_cols_3 = rf_self_best_pl['varFilter'].get_feature_names_out(rf_self_cols_2)
rf_self_cols_final = rf_self_best_pl['UniSlct'].get_feature_names_out(rf_self_cols_3)
rf_self_cols_final_clean = [i[1] for i in np.char.split(rf_self_cols_final.astype(str), sep='__')]
rf_self_cols_final_clean = np.array([s.replace('_' , ' ') for s in rf_self_cols_final_clean])

# Transform the X data
X_pre_rf_self = rf_self_best_pl['pre'].transform(X_test_spatial) # Use test data for SHAP values
X_scaler_rf_self = rf_self_best_pl['scaler'].transform(X_pre_rf_self)
X_varFilter_rf_self = rf_self_best_pl['varFilter'].transform(X_scaler_rf_self)
X_UniSlct_rf_self = rf_self_best_pl['UniSlct'].transform(X_varFilter_rf_self)
X_processed_rf_self = pd.DataFrame(X_UniSlct_rf_self, columns = rf_self_cols_final_clean)

# Calculate SHAP values:
best_rf_self_model = rf_self_best_pl['est']
rf_self_explainer = shap.TreeExplainer(best_rf_self_model)
shap_values_rf_self = rf_self_explainer(X_processed_rf_self)

# %% [markdown]
# ### SHAP Beeswarm plot

# %%
plt.figure(figsize=(10,16))
ax1 = plt.subplot(2,1,1)
shap_sum_plot = shap.summary_plot(shap_values_rf.values[:,:,1], X_processed_rf,max_display=15, show = False)
ax1.tick_params(axis='both', which='major', labelsize=9)
ax1.xaxis.label.set_size(10)
ax1.yaxis.label.set_size(10)
ax1.text(-0.9, 1.1, 'A', transform=ax1.transAxes, fontsize=15, fontweight='bold',va='top', ha='right')

ax2 = plt.subplot(2,1,2)
shap_sum_plot_self = shap.summary_plot(shap_values_rf_self.values[:,:,1], X_processed_rf_self,max_display=15, show = False)
ax2.tick_params(axis='both', which='major', labelsize=9)
ax2.xaxis.label.set_size(10)
ax2.yaxis.label.set_size(10)
ax2.text(-0.9, 1.1, 'B', transform=ax2.transAxes, fontsize=15, fontweight='bold',va='top', ha='right')
plt.savefig('./Figures/main_text/SHAP_beeswarm.png',bbox_inches='tight',dpi=300)

# %% [markdown]
# ### SHAP bar plot

# %%
plt.figure(figsize=(10,16))
ax1 = plt.subplot(2,1,1)
shap_sum_plot = shap.summary_plot(shap_values_rf.values[:,:,1], X_processed_rf,max_display=15, show = False,plot_type = 'bar')
ax1.tick_params(axis='both', which='major', labelsize=9)
ax1.xaxis.label.set_size(10)
ax1.yaxis.label.set_size(10)
ax1.text(-0.7, 1.1, 'A', transform=ax1.transAxes, fontsize=15, fontweight='bold',va='top', ha='right')

ax2 = plt.subplot(2,1,2)
shap_sum_plot_self = shap.summary_plot(shap_values_rf_self.values[:,:,1], X_processed_rf_self,max_display=15, show = False,plot_type = 'bar')
ax2.tick_params(axis='both', which='major', labelsize=9)
ax2.xaxis.label.set_size(10)
ax2.yaxis.label.set_size(10)
ax2.text(-0.7, 1.1, 'B', transform=ax2.transAxes, fontsize=15, fontweight='bold',va='top', ha='right')

plt.savefig('./Figures/SI/SHAP_bar.png',bbox_inches='tight',dpi=300)

# %% [markdown]
# # The impacts of tree number and maximum tree depth on the RF model

# %%
# This function evaluates the pipeline's performance over different hyper-parameter values

def evaluate_cv_test_on_param(param_name,list_params, pipeline, X_train, y_train, X_test, y_test,X_cv_train_lst, y_cv_train_lst, X_cv_val_lst, y_cv_val_lst):
    list_mean_cv_score = []
    list_std_cv_score = []
    list_test_score = []

    for param in list_params:
        list_cv_score = []
        # set parameters:
        param_cur = {param_name: param}
        pipeline_param = pipeline.set_params(**param_cur)
        # Cross Validation: 
        for i in range(len(X_cv_train_lst)):
            pipeline_param_cv = pipeline_param.fit(X_cv_train_lst[i], y_cv_train_lst[i])   
            y_cv_val_pred_prob = pipeline_param_cv.predict_proba(X_cv_val_lst[i])[:,1]
            score_cur = roc_auc_score(y_cv_val_lst[i],y_cv_val_pred_prob)
            list_cv_score.append(score_cur)
        list_cv_score = np.array(list_cv_score)
        mean_cv_score = np.mean(list_cv_score)
        list_mean_cv_score.append(mean_cv_score)
        std_cv_score = np.std(list_cv_score)
        list_std_cv_score.append(std_cv_score)

        # evaluate on test set
        pipeline_param_test = pipeline_param.fit(X_train, y_train)
        y_test_pred_prob = pipeline_param_test.predict_proba(X_test)[:,1]
        score_test = roc_auc_score(y_test, y_test_pred_prob)
        list_test_score.append(score_test)
        
    return np.array(list_mean_cv_score), np.array(list_std_cv_score), np.array(list_test_score)

# %% [markdown]
# ## The impact of tree number

# %%
list_n_estimators = [10,25, 50, 75, 100, 500, 1000, 1500, 2000, 3000]

# %% [markdown]
# ### Including all features

# %%
rng = np.random.RandomState(0)

rf_steps = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", RandomForestClassifier(random_state=rng,n_jobs=-1))
]

rf_pipeline_Nestimator = Pipeline(steps = rf_steps)
rf_params = {'UniSlct__percentile': 100, 'est__max_depth': 200, 'est__max_features': 'log2'}
rf_pipeline_Nestimator = rf_pipeline_Nestimator.set_params(**rf_params)
list_mean_cv_score_rf_Nestimator, list_std_cv_score_rf_Nestimator, list_test_score_rf_Nestimator = evaluate_cv_test_on_param('est__n_estimators',list_n_estimators,rf_pipeline_Nestimator,
                         X_train_spatial, y_train,
                         X_test_spatial, y_test,
                         X_cv_train_spatial_lst, y_cv_train_lst,
                         X_cv_val_spatial_lst,y_cv_val_lst)

# %% [markdown]
# ### Excluding geospatial features

# %%
rng = np.random.RandomState(0)
rf_steps_self = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", RandomForestClassifier(random_state=rng, n_jobs=-1))
]

rf_self_pipeline_Nestimator = Pipeline(steps = rf_steps_self)
rf_self_params = {'UniSlct__percentile': 100, 'est__max_depth': 200, 'est__max_features': 'log2'}
rf_self_pipeline_Nestimator = rf_self_pipeline_Nestimator.set_params(**rf_self_params)
list_mean_cv_score_rf_self_Nestimator, list_std_cv_score_rf_self_Nestimator, list_test_score_rf_self_Nestimator = evaluate_cv_test_on_param('est__n_estimators',list_n_estimators,rf_self_pipeline_Nestimator,
                         X_train_self, y_train,
                         X_test_self, y_test,
                         X_cv_train_self_lst, y_cv_train_lst,
                         X_cv_val_self_lst,y_cv_val_lst)

# %% [markdown]
# ## The impact of maximum tree depth

# %%
list_maxDepth = [1,3,5,10,25, 50, 75, 100,200,500]

# %% [markdown]
# ### Using all features

# %%
rng = np.random.RandomState(0)

rf_steps = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", RandomForestClassifier(random_state=rng,n_jobs=-1))
]

rf_pipeline_maxDepth = Pipeline(steps = rf_steps)
rf_params = {'UniSlct__percentile': 100, 'est__n_estimators': 1000,'est__max_features': 'log2'}
rf_pipeline_maxDepth = rf_pipeline_maxDepth.set_params(**rf_params)
list_mean_cv_score_rf_maxDepth, list_std_cv_score_rf_maxDepth, list_test_score_rf_maxDepth = evaluate_cv_test_on_param('est__max_depth',list_maxDepth,rf_pipeline_maxDepth,
                         X_train_spatial, y_train,
                         X_test_spatial, y_test,
                         X_cv_train_spatial_lst, y_cv_train_lst,
                         X_cv_val_spatial_lst,y_cv_val_lst)

# %% [markdown]
# ### Excluding geospatial features

# %%
rng = np.random.RandomState(0)
rf_steps_self = [
     ("pre", create_preprocessor()),
     ("scaler", StandardScaler()),
     ("varFilter", VarianceThreshold(threshold = 0.0)),
     ("UniSlct", SelectPercentile(f_classif)),
     ("est", RandomForestClassifier(random_state=rng, n_jobs=-1))
]

rf_self_pipeline_maxDepth = Pipeline(steps = rf_steps_self)
rf_self_params = {'UniSlct__percentile': 100, 'est__n_estimators': 1000,'est__max_features': 'log2'}
rf_self_pipeline_maxDepth = rf_self_pipeline_maxDepth.set_params(**rf_self_params)
list_mean_cv_score_rf_self_maxDepth, list_std_cv_score_rf_self_maxDepth, list_test_score_rf_self_maxDepth = evaluate_cv_test_on_param('est__max_depth',list_maxDepth,rf_self_pipeline_maxDepth,
                         X_train_self, y_train,
                         X_test_self, y_test,
                         X_cv_train_self_lst, y_cv_train_lst,
                         X_cv_val_self_lst,y_cv_val_lst)

# %%
print(list_n_estimators)
print(list_mean_cv_score_rf_Nestimator)
# Out:
# [10, 25, 50, 75, 100, 500, 1000, 1500, 2000, 3000]
# [0.72117597 0.74737174 0.74129524 0.74585399 0.74839657 0.75452663
#  0.75693856 0.75673714 0.75794471 0.75778686]

# %%
print(list_maxDepth)
print(list_mean_cv_score_rf_maxDepth)
# Out:
# [1, 3, 5, 10, 25, 50, 75, 100, 200, 500]
# [0.6914315  0.72173979 0.73392976 0.75307207 0.75663586 0.7552198
#  0.75722505 0.7584214  0.75696036 0.75644888]

# %%
fig,axes = plt.subplots(1,2, figsize=(12,6))
axes[0].plot(list_n_estimators, list_mean_cv_score_rf_Nestimator,'.-',label = 'All features')
axes[0].fill_between(list_n_estimators, list_mean_cv_score_rf_Nestimator- list_std_cv_score_rf_Nestimator, 
                    list_mean_cv_score_rf_Nestimator + list_std_cv_score_rf_Nestimator, alpha=0.3)

axes[0].plot(list_n_estimators, list_mean_cv_score_rf_self_Nestimator, '.-',label = 'No geospatial features')
axes[0].fill_between(list_n_estimators, list_mean_cv_score_rf_self_Nestimator - list_std_cv_score_rf_self_Nestimator,
                    list_mean_cv_score_rf_self_Nestimator + list_std_cv_score_rf_self_Nestimator, alpha=0.3)
axes[0].set_ylim(0.6,0.8)
axes[0].tick_params(axis='both', which='major', labelsize=9)
axes[0].xaxis.label.set_size(10)
axes[0].yaxis.label.set_size(10)
axes[0].text(-0.1, 1.1, 'A', transform=axes[0].transAxes, fontsize=15, fontweight='bold',va='top', ha='right')
axes[0].set_xlabel('Number of trees', fontsize = 15)
axes[0].set_ylabel('ROC AUC', fontsize = 15)
axes[0].legend(loc = 'lower right',fontsize = 15)

axes[1].plot(list_maxDepth, list_mean_cv_score_rf_maxDepth,'.-',label = 'All features')
axes[1].fill_between(list_maxDepth,list_mean_cv_score_rf_maxDepth - list_std_cv_score_rf_maxDepth,
            list_mean_cv_score_rf_maxDepth + list_std_cv_score_rf_maxDepth,alpha=0.3)

axes[1].plot(list_maxDepth, list_mean_cv_score_rf_self_maxDepth, '.-',label = 'No geospatial features')
axes[1].fill_between(list_maxDepth, list_mean_cv_score_rf_self_maxDepth - list_std_cv_score_rf_self_maxDepth,
                    list_mean_cv_score_rf_self_maxDepth + list_std_cv_score_rf_self_maxDepth,alpha=0.3)

axes[1].set_ylim(0.6,0.8)
axes[1].tick_params(axis='both', which='major', labelsize=9)
axes[1].xaxis.label.set_size(10)
axes[1].yaxis.label.set_size(10)
axes[1].text(-0.1, 1.1, 'B', transform=axes[1].transAxes, fontsize=15, fontweight='bold',va='top', ha='right')
axes[1].set_xlabel('Maximum tree depth', fontsize = 15)
axes[1].set_ylabel('ROC AUC', fontsize = 15)
axes[1].legend(loc = 'lower right',fontsize = 15)

plt.savefig('./Figures/SI/tree_number_depth.png',bbox_inches='tight',dpi=300)
